# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np
import requests
import csv
import play_scraper as gp
from pprint import pprint

# %%
categories = ["GAME_ACTION", "GAME_ADVENTURE",
              "GAME_ARCADE", "GAME_BOARD", 
              "GAME_CARD", "GAME_CASINO",
              "GAME_CASUAL", "GAME_EDUCATIONAL",
              "GAME_MUSIC",  "GAME_PUZZLE",
              "GAME_RACING", "GAME_ROLE_PLAYING",
              "GAME_SIMULATION", "GAME_SPORTS",
              "GAME_STRATEGY", "GAME_TRIVIA"]

game_category = []
game_list = []
for x in categories:
    paid_games = gp.collection(collection='TOP_PAID', category=x, results=25)
    print(f' --')
    print(f'   *** Getting information for games in the {x} category. ***')
    print(f' --')
    for j in range (0, 25):
        game_info = paid_games[j]['app_id']
        title = paid_games[j]['title']
        game_category.append(x)
        game_list.append(game_info)
        print(f'{j}. Getting the Game ID for {title}.')
# Out:
#  --
#    *** Getting information for games in the GAME_ACTION category. ***
#  --
# 0. Getting the Game ID for Grand Theft Auto: San Andreas.
# 1. Getting the Game ID for Five Nights at Freddy's.
# 2. Getting the Game ID for Five Nights at Freddy's: SL.
# 3. Getting the Game ID for Hitman Sniper.
# 4. Getting the Game ID for Assassin's Creed Identity.
# 5. Getting the Game ID for Five Nights at Freddy's 4.
# 6. Getting the Game ID for Space Marshals.
# 7. Getting the Game ID for Call of Duty:Black Ops Zombies.
# 8. Getting the Game ID for Grand Theft Auto III.
# 9. Getting the Game ID for truTV Impractical Jokers Wheel of Doom.
# 10. Getting the Game ID for Teen Titans GO Figure!.
# 11. Getting the Game ID for Real Steel.
# 12. Getting the Game ID for Five Nights at Freddy's 3.
# 13. Getting the Game ID for Downwell.
# 14. Getting the Game ID for Bloons Supermonkey 2.
# 15. Getting the Game ID for Bully: Anniversary Edition.
# 16. Getting the Game ID for LEGO® Star Wars™:  TCS.
# 17. Getting the Game ID for LEGO ® Marvel Super Heroes.
# 18. Getting the Game ID for Shadow of Death: Stickman Fighting - Dark Knight.
# 19. Getting the Game ID for GTA: Chinatown Wars.
# 20. Getting the Game ID for Battle of Vicksburg.
# 21. Getting the Game ID for PPSSPP Gold - PSP emulator.
# 22. Getting the Game ID for Zombieville USA 2.
# 23. Getting the Game ID for Goat Simulator GoatZ.
# 24. Getting the Game ID for Titan Quest.
#  --
#    *** Getting information for games in the GAME_ADVENTURE category. ***
#  --
# 0. Getting the Game ID for Alien: Blackout.
# 1. Getting the Game ID for Terraria..
# 2. Getting the Game ID for Bendy and the Ink Machine.
# 3. Getting the Game ID for THE GALAXY: SURVIVOR.
# 4. Getting the Game ID for 60 Seconds! Atomic Adventure.
# 5. Getting the Game ID for Don't Starve: Pocket Edition.
# 6. Getting the Game ID for LEGO® Jurassic World™.
# 7. Getting the Game ID for Portal Knights.
# 8. Getting the Game ID for Angry Neighbor.
# 9. Getting the Game ID for Thickety Creek.
# 10. Getting the Game ID for Octodad: Dadliest Catch.
# 11. Getting the Game ID for Sonic Runners Adventure - Fast Action Platformer.
# 12. Getting the Game ID for Crashlands.
# 13. Getting the Game ID for Castle of Illusion.
# 14. Getting the Game ID for Draw a Stickman: EPIC 2.
# 15. Getting the Game ID for Live or Die: Survival Pro.
# 16. Getting the Game ID for Rusty Lake: Roots.
# 17. Getting the Game ID for Survivalcraft 2.
# 18. Getting the Game ID for Rusty Lake Hotel.
# 19. Getting the Game ID for LEGO Harry Potter: Years 1-4.
# 20. Getting the Game ID for GTA: Liberty City Stories.
# 21. Getting the Game ID for FINAL FANTASY IX for Android.
# 22. Getting the Game ID for Don't Starve: Shipwrecked.
# 23. Getting the Game ID for CHUCHEL.
# 24. Getting the Game ID for Sky Dancer Premium.
#  --
#    *** Getting information for games in the GAME_ARCADE category. ***
#  --
# 0. Getting the Game ID for Minecraft.
# 1. Getting the Game ID for Geometry Dash.
# 2. Getting the Game ID for Grand Theft Auto: Vice City.
# 3. Getting the Game ID for Ding Dong XL.
# 4. Getting the Game ID for ePSXe for Android.
# 5. Getting the Game ID for Fruit Ninja Classic.
# 6. Getting the Game ID for My OldBoy! - GBC Emulator.
# 7. Getting the Game ID for Pocket God™.
# 8. Getting the Game ID for Max Payne Mobile.
# 9. Getting the Game ID for Peace, Death!.
# 10. Getting the Game ID for Vector Full.
# 11. Getting the Game ID for SuperRetro16 ( SNES Emulator ).
# 12. Getting the Game ID for Retro N64 Pro - N64 Emulator.
# 13. Getting the Game ID for Retro NES Pro - NES Emulator.
# 14. Getting the Game ID for PAC-MAN Championship Edition DX.
# 15. Getting the Game ID for Worms 3.
# 16. Getting the Game ID for Ms. PAC-MAN.
# 17. Getting the Game ID for Robot Unicorn Attack.
# 18. Getting the Game ID for Marvel Pinball.
# 19. Getting the Game ID for The Impossible Game.
# 20. Getting the Game ID for Granny Smith.
# 21. Getting the Game ID for holedown.
# 22. Getting the Game ID for Shopkins Run!.
# 23. Getting the Game ID for METAL SLUG 3.
# 24. Getting the Game ID for Sonic 4™ Episode I.
#  --
#    *** Getting information for games in the GAME_BOARD category. ***
#  --
# 0. Getting the Game ID for The Game of Life.
# 1. Getting the Game ID for Clue.
# 2. Getting the Game ID for Legends of Andor – The King’s Secret.
# 3. Getting the Game ID for Twice as clever.
# 4. Getting the Game ID for Ticket to Ride.
# 5. Getting the Game ID for Pandemic: The Board Game.
# 6. Getting the Game ID for Catan Classic.
# 7. Getting the Game ID for Carcassonne: Official Board Game -Tiles & Tactics.
# 8. Getting the Game ID for Chess.
# 9. Getting the Game ID for Hasbro's BATTLESHIP.
# 10. Getting the Game ID for Splendor.
# 11. Getting the Game ID for Ganz schön clever.
# 12. Getting the Game ID for Backgammon.
# 13. Getting the Game ID for Through the Ages.
# 14. Getting the Game ID for D&D Lords of Waterdeep.
# 15. Getting the Game ID for Race for the Galaxy.
# 16. Getting the Game ID for Small World 2.
# 17. Getting the Game ID for Stratego® Single Player.
# 18. Getting the Game ID for Elder Sign: Omens.
# 19. Getting the Game ID for Tokaido™.
# 20. Getting the Game ID for Smash Up - The Shufflebuilding Game.
# 21. Getting the Game ID for Galaxy Trucker.
# 22. Getting the Game ID for Sentinels of the Multiverse.
# 23. Getting the Game ID for Talisman.
# 24. Getting the Game ID for Mysterium: A Psychic Clue Game.
#  --
#    *** Getting information for games in the GAME_CARD category. ***
#  --
# 0. Getting the Game ID for Exploding Kittens® - Official.
# 1. Getting the Game ID for Reigns.
# 2. Getting the Game ID for Skip-Bo™.
# 3. Getting the Game ID for Card Wars - Adventure Time.
# 4. Getting the Game ID for Reigns: Game of Thrones.
# 5. Getting the Game ID for Solitaire+.
# 6. Getting the Game ID for Reigns: Her Majesty.
# 7. Getting the Game ID for Meteorfall: Journeys.
# 8. Getting the Game ID for SET Mania.
# 9. Getting the Game ID for Blackbird.
# 10. Getting the Game ID for Card Quest.
# 11. Getting the Game ID for Decked Builder.
# 12. Getting the Game ID for Cribbage Pro Online!.
# 13. Getting the Game ID for Kemono Mahjong.
# 14. Getting the Game ID for Phase 10.
# 15. Getting the Game ID for Spades.
# 16. Getting the Game ID for Solitaire Collection Premium.
# 17. Getting the Game ID for Solitaire MegaPack.
# 18. Getting the Game ID for Spider Solitaire+.
# 19. Getting the Game ID for Gin Rummy.
# 20. Getting the Game ID for Patch Tarot.
# 21. Getting the Game ID for FreeCell Solitaire+.
# 22. Getting the Game ID for Euchre.
# 23. Getting the Game ID for The Game - Play ... as long as you can!.
# 24. Getting the Game ID for Munchkin Level Counter.
#  --
#    *** Getting information for games in the GAME_CASINO category. ***
#  --
# 0. Getting the Game ID for VIP Slots Club ★ VIP Casino.
# 1. Getting the Game ID for Craps Trainer Pro.
# 2. Getting the Game ID for Card Counter.
# 3. Getting the Game ID for Pokertrainer.
# 4. Getting the Game ID for Top Money 💵 Slots (PREMIUM).
# 5. Getting the Game ID for Cleopatra Keno.
# 6. Getting the Game ID for Vintage Pachinko.
# 7. Getting the Game ID for MEGA Money Slots PAID.
# 8. Getting the Game ID for Blackjack Verite Games.
# 9. Getting the Game ID for Super Times Pay Poker.
# 10. Getting the Game ID for Play Perfect Video Poker Pro+.
# 11. Getting the Game ID for Multi-Card Keno.
# 12. Getting the Game ID for Ultimate X Poker.
# 13. Getting the Game ID for Fun Slot Machine Las Vegas Pro.
# 14. Getting the Game ID for Carnival Fiesta Slots PAID.
# 15. Getting the Game ID for Crock O'Gold Rainbow Slots PAID.
# 16. Getting the Game ID for Blackjack Verite Drills.
# 17. Getting the Game ID for Speed Rush Las Vegas VIP Slot.
# 18. Getting the Game ID for Egypt Reels of Luxor Slots PAID.
# 19. Getting the Game ID for Best Hold.
# 20. Getting the Game ID for Baccarat Mastery Pro.
# 21. Getting the Game ID for Play Perfect Video Poker Pro.
# 22. Getting the Game ID for Poker Notes Live - Premium.
# 23. Getting the Game ID for Monkey Money 2 Slots.
# 24. Getting the Game ID for Wild West Faro.
#  --
#    *** Getting information for games in the GAME_CASUAL category. ***
#  --
# 0. Getting the Game ID for Let's Create! Pottery.
# 1. Getting the Game ID for Tamagotchi Classic - Gen1.
# 2. Getting the Game ID for Game Dev Story.
# 3. Getting the Game ID for Meme Soundboard PRO 2019.
# 4. Getting the Game ID for FINAL FANTASY.
# 5. Getting the Game ID for Jazza's Arty Games.
# 6. Getting the Game ID for Hidden Folks.
# 7. Getting the Game ID for My PlayHome : Play Home Doll House.
# 8. Getting the Game ID for Little Inferno.
# 9. Getting the Game ID for SpongeBob's Game Frenzy.
# 10. Getting the Game ID for My PlayHome Hospital.
# 11. Getting the Game ID for My PlayHome Stores.
# 12. Getting the Game ID for My PlayHome School.
# 13. Getting the Game ID for Fieldrunners HD.
# 14. Getting the Game ID for Grow Spaceship VIP - Galaxy Battle.
# 15. Getting the Game ID for supertype.
# 16. Getting the Game ID for Fieldrunners 2.
# 17. Getting the Game ID for Wedding Dash Deluxe.
# 18. Getting the Game ID for SpongeBob Diner Dash Deluxe.
# 19. Getting the Game ID for Brink of Consciousness (Full).
# 20. Getting the Game ID for Burger Shop 2 Deluxe.
# 21. Getting the Game ID for Sand! Premium.
# 22. Getting the Game ID for Hotel Dash Deluxe.
# 23. Getting the Game ID for Virtual Families.
# 24. Getting the Game ID for Haunted Hotel: Death Sentence (Full).
#  --
#    *** Getting information for games in the GAME_EDUCATIONAL category. ***
#  --
# 0. Getting the Game ID for Wonderland : Peter Pan.
# 1. Getting the Game ID for Teach Your Monster to Read - Phonics and Reading.
# 2. Getting the Game ID for Toca Boo.
# 3. Getting the Game ID for Toca Blocks.
# 4. Getting the Game ID for My Town : Hospital.
# 5. Getting the Game ID for Explore Daniel's Neighborhood.
# 6. Getting the Game ID for My Town : Airport.
# 7. Getting the Game ID for Wonderland : Little Mermaid.
# 8. Getting the Game ID for Toca Mystery House.
# 9. Getting the Game ID for Toca Lab: Plants.
# 10. Getting the Game ID for Peppa Pig: Holiday.
# 11. Getting the Game ID for My City : Office.
# 12. Getting the Game ID for Daniel Tiger's Stop & Go Potty.
# 13. Getting the Game ID for My Town : School.
# 14. Getting the Game ID for Learn to Read with Tommy Turtle.
# 15. Getting the Game ID for BRIO World - Railway.
# 16. Getting the Game ID for Numberblocks - Hide and Seek.
# 17. Getting the Game ID for Stack the States® 2.
# 18. Getting the Game ID for My Town : Hotel.
# 19. Getting the Game ID for Dr. Panda Restaurant 2.
# 20. Getting the Game ID for My Town : Best Friends' House.
# 21. Getting the Game ID for My Town : ICEME Amusement Park.
# 22. Getting the Game ID for My City : Dentist visit.
# 23. Getting the Game ID for Second Grade Learning Games.
# 24. Getting the Game ID for PAW Patrol Air and Sea Adventures.
#  --
#    *** Getting information for games in the GAME_MUSIC category. ***
#  --
# 0. Getting the Game ID for Cytus II.
# 1. Getting the Game ID for Incredibox.
# 2. Getting the Game ID for Lowriders Comeback 2: Cruising.
# 3. Getting the Game ID for Muse Dash.
# 4. Getting the Game ID for My Singing Monsters Composer.
# 5. Getting the Game ID for Note Rush: Learn to Read Music.
# 6. Getting the Game ID for Sonar Beat.
# 7. Getting the Game ID for Wonder Parade.
# 8. Getting the Game ID for Beat Bugs: Sing-Along.
# 9. Getting the Game ID for Learn Music Notes.
# 10. Getting the Game ID for Caustic 3.2 HipHop Pack 2.
# 11. Getting the Game ID for Caustic 3.2 DrumSynth Pack 2.
# 12. Getting the Game ID for Caustic 3.2 Tech House Pack 1.
# 13. Getting the Game ID for Caustic 3.2 Techno Pack 3.
# 14. Getting the Game ID for MC Lars: The Video Game.
# 15. Getting the Game ID for Frederic - Evil Strikes Back.
# 16. Getting the Game ID for Black Metal Man.
# 17. Getting the Game ID for Piano Master.
# 18. Getting the Game ID for Piano Flashcards.
# 19. Getting the Game ID for Drum Pad Beats.
# 20. Getting the Game ID for Caustic 3.2 Minimal Pack 2.
# 21. Getting the Game ID for Note Fighter Unlimited.
# 22. Getting the Game ID for A Dance of Fire and Ice.
# 23. Getting the Game ID for Beat Beat Vocaloid.
# 24. Getting the Game ID for Meow Music.
#  --
#    *** Getting information for games in the GAME_PUZZLE category. ***
#  --
# 0. Getting the Game ID for Scribblenauts Remix.
# 1. Getting the Game ID for The Room.
# 2. Getting the Game ID for Scribblenauts Unlimited.
# 3. Getting the Game ID for The Room: Old Sins.
# 4. Getting the Game ID for Agent A: A puzzle in disguise.
# 5. Getting the Game ID for The Room Two.
# 6. Getting the Game ID for Florence.
# 7. Getting the Game ID for Monument Valley.
# 8. Getting the Game ID for The Room Three.
# 9. Getting the Game ID for The House of Da Vinci.
# 10. Getting the Game ID for Monument Valley 2.
# 11. Getting the Game ID for Bridge Constructor Portal.
# 12. Getting the Game ID for Hitman GO.
# 13. Getting the Game ID for Lara Croft GO.
# 14. Getting the Game ID for Where's My Water?.
# 15. Getting the Game ID for Doodle God™.
# 16. Getting the Game ID for Legacy 3 - The Hidden Relic.
# 17. Getting the Game ID for Doodle God™ HD.
# 18. Getting the Game ID for Please, Don't Touch Anything.
# 19. Getting the Game ID for Human Resource Machine.
# 20. Getting the Game ID for Cut the Rope GOLD.
# 21. Getting the Game ID for Gorogoa.
# 22. Getting the Game ID for Scalak.
# 23. Getting the Game ID for Doodle Devil™ HD.
# 24. Getting the Game ID for Deus Ex GO.
#  --
#    *** Getting information for games in the GAME_RACING category. ***
#  --
# 0. Getting the Game ID for Earn to Die.
# 1. Getting the Game ID for Bike Race Pro by T. F. Games.
# 2. Getting the Game ID for Real Drift Car Racing.
# 3. Getting the Game ID for Need for Speed Most Wanted.
# 4. Getting the Game ID for Motorsport Manager Mobile 3.
# 5. Getting the Game ID for TRAIL CLIMB.
# 6. Getting the Game ID for Dirt Trackin.
# 7. Getting the Game ID for Riptide GP: Renegade.
# 8. Getting the Game ID for PJ Masks: Racing Heroes.
# 9. Getting the Game ID for Rush Rally 2.
# 10. Getting the Game ID for Dirt Trackin Sprint Cars.
# 11. Getting the Game ID for Drag Racing 3D.
# 12. Getting the Game ID for Need for Speed Hot Pursuit.
# 13. Getting the Game ID for Ricky Carmichael's Motocross.
# 14. Getting the Game ID for Bike Mayhem Mountain Racing.
# 15. Getting the Game ID for Reckless Racing 3.
# 16. Getting the Game ID for Riptide GP2.
# 17. Getting the Game ID for ULTRA4 Offroad Racing.
# 18. Getting the Game ID for Outlaws - Sprint Car Racing.
# 19. Getting the Game ID for Draw Rider Plus.
# 20. Getting the Game ID for Riptide GP.
# 21. Getting the Game ID for F1 2016.
# 22. Getting the Game ID for Dirt Racing Mobile 3D.
# 23. Getting the Game ID for Pocket Rally.
# 24. Getting the Game ID for Repulze.
#  --
#    *** Getting information for games in the GAME_ROLE_PLAYING category. ***
#  --
# 0. Getting the Game ID for Evoland.
# 1. Getting the Game ID for Star Wars™: KOTOR.
# 2. Getting the Game ID for Doom & Destiny Advanced.
# 3. Getting the Game ID for EvoCreo.
# 4. Getting the Game ID for Attack the Light.
# 5. Getting the Game ID for Neverwinter Nights: Enhanced Edition.
# 6. Getting the Game ID for Monster Hunter Stories.
# 7. Getting the Game ID for FINAL FANTASY VII.
# 8. Getting the Game ID for Alter Ego.
# 9. Getting the Game ID for 80 Days.
# 10. Getting the Game ID for Baldur's Gate: Enhanced Edition.
# 11. Getting the Game ID for CHRONO TRIGGER (Upgrade Ver.).
# 12. Getting the Game ID for The Bard's Tale.
# 13. Getting the Game ID for Evoland 2.
# 14. Getting the Game ID for Day R Premium.
# 15. Getting the Game ID for ICEY.
# 16. Getting the Game ID for Rogue Hearts.
# 17. Getting the Game ID for DRAGON QUEST.
# 18. Getting the Game ID for Pocket Rogues: Ultimate.
# 19. Getting the Game ID for Goat Simulator MMO Simulator.
# 20. Getting the Game ID for Hardboiled.
# 21. Getting the Game ID for Battleheart Legacy.
# 22. Getting the Game ID for Guild of Dungeoneering.
# 23. Getting the Game ID for Neo Monsters.
# 24. Getting the Game ID for A Dark Room ®.
#  --
#    *** Getting information for games in the GAME_SIMULATION category. ***
#  --
# 0. Getting the Game ID for Mini Metro.
# 1. Getting the Game ID for Poly Bridge.
# 2. Getting the Game ID for Farming Simulator 18.
# 3. Getting the Game ID for Goat Simulator.
# 4. Getting the Game ID for Game Dev Tycoon.
# 5. Getting the Game ID for Pocket City.
# 6. Getting the Game ID for FINAL FANTASY TACTICS : WotL.
# 7. Getting the Game ID for Infinite Flight - Flight Simulator.
# 8. Getting the Game ID for Goat Simulator Payday.
# 9. Getting the Game ID for Project Highrise.
# 10. Getting the Game ID for Getting Over It with Bennett Foddy.
# 11. Getting the Game ID for Youtubers Life: Gaming Channel.
# 12. Getting the Game ID for Goat Simulator Waste of Space.
# 13. Getting the Game ID for Pocket Aquarium.
# 14. Getting the Game ID for Farming Simulator 16.
# 15. Getting the Game ID for Construction Simulator 2.
# 16. Getting the Game ID for This Is the Police.
# 17. Getting the Game ID for One Hour One Life for Mobile.
# 18. Getting the Game ID for SimplePlanes.
# 19. Getting the Game ID for Farming USA 2.
# 20. Getting the Game ID for Truck Simulator PRO 2.
# 21. Getting the Game ID for 911 Operator.
# 22. Getting the Game ID for SPACEPLAN.
# 23. Getting the Game ID for Construction Simulator 2014.
# 24. Getting the Game ID for Ultimate Wolf Simulator.
#  --
#    *** Getting information for games in the GAME_SPORTS category. ***
#  --
# 0. Getting the Game ID for NBA 2K19.
# 1. Getting the Game ID for True Skate.
# 2. Getting the Game ID for NBA JAM  by EA SPORTS™.
# 3. Getting the Game ID for Football Manager 2019 Mobile.
# 4. Getting the Game ID for WWE 2K.
# 5. Getting the Game ID for Skater.
# 6. Getting the Game ID for Dude Perfect.
# 7. Getting the Game ID for Clay Hunt PRO.
# 8. Getting the Game ID for OK Golf.
# 9. Getting the Game ID for Flick Golf!.
# 10. Getting the Game ID for R.B.I. Baseball 18.
# 11. Getting the Game ID for Duck Life: Space.
# 12. Getting the Game ID for Sumotori Dreams.
# 13. Getting the Game ID for Ice Fishing Derby Premium.
# 14. Getting the Game ID for Pumped BMX 3.
# 15. Getting the Game ID for MLB Manager 2018.
# 16. Getting the Game ID for Fish-o-niric.
# 17. Getting the Game ID for Duck Life: Retro Pack.
# 18. Getting the Game ID for Pro Strategy Football 2018.
# 19. Getting the Game ID for Home Run High.
# 20. Getting the Game ID for College BBALL Coach.
# 21. Getting the Game ID for CN Superstar Soccer: Goal!!!.
# 22. Getting the Game ID for Shred! 2 - Freeride Mountain Biking.
# 23. Getting the Game ID for Disc Golf Game.
# 24. Getting the Game ID for Athletics 2: Summer Sports.
#  --
#    *** Getting information for games in the GAME_STRATEGY category. ***
#  --
# 0. Getting the Game ID for Bloons TD 6.
# 1. Getting the Game ID for Kingdom Rush Vengeance.
# 2. Getting the Game ID for Bloons TD 5.
# 3. Getting the Game ID for Age of Civilizations II.
# 4. Getting the Game ID for Papa's Freezeria To Go!.
# 5. Getting the Game ID for The Escapists: Prison Escape.
# 6. Getting the Game ID for Five Nights at Freddy's 2.
# 7. Getting the Game ID for ROME: Total War.
# 8. Getting the Game ID for Rusted Warfare - RTS Strategy.
# 9. Getting the Game ID for Civilization Revolution 2.
# 10. Getting the Game ID for First Strike: Final Hour.
# 11. Getting the Game ID for Papa's Scooperia To Go!.
# 12. Getting the Game ID for Kingdom Rush Frontiers.
# 13. Getting the Game ID for Papa's Burgeria To Go!.
# 14. Getting the Game ID for Uciana.
# 15. Getting the Game ID for XCOM®: Enemy Within.
# 16. Getting the Game ID for Papa's Pancakeria To Go!.
# 17. Getting the Game ID for Papa's Pizzeria To Go!.
# 18. Getting the Game ID for Kingdom Rush Origins.
# 19. Getting the Game ID for Door Kickers.
# 20. Getting the Game ID for Papa's Cupcakeria To Go!.
# 21. Getting the Game ID for Warhammer 40,000: Regicide.
# 22. Getting the Game ID for Teeny Titans - Teen Titans Go!.
# 23. Getting the Game ID for Rebuild 3: Gangs of Deadsville.
# 24. Getting the Game ID for Organ Trail: Director's Cut.
#  --
#    *** Getting information for games in the GAME_TRIVIA category. ***
#  --
# 0. Getting the Game ID for Trivia Crack (No Ads).
# 1. Getting the Game ID for Sporcle.
# 2. Getting the Game ID for BLeBRiTY.
# 3. Getting the Game ID for The Jackbox Party Pack.
# 4. Getting the Game ID for The Jackbox Party Pack 5.
# 5. Getting the Game ID for Bible Bowl Prep 2019.
# 6. Getting the Game ID for The Jackbox Party Pack 3.
# 7. Getting the Game ID for The 7 Second Challenge.
# 8. Getting the Game ID for The Jackbox Party Pack 2.
# 9. Getting the Game ID for The Black Card Game.
# 10. Getting the Game ID for 4 Player Reactor (Multiplayer).
# 11. Getting the Game ID for Pointless Quiz.
# 12. Getting the Game ID for The Jackbox Party Pack 4.
# 13. Getting the Game ID for Quizoid Pro: Category Trivia with 5 Game modes.
# 14. Getting the Game ID for Penny Dell Jumbo Crosswords.
# 15. Getting the Game ID for Einstein™ Brain Training.
# 16. Getting the Game ID for Text Twist 2019.
# 17. Getting the Game ID for Lets get wasted 18+ ;).
# 18. Getting the Game ID for SHAPE - the picture trivia quiz.
# 19. Getting the Game ID for QuizBash - Party Games in Your Pocket!.
# 20. Getting the Game ID for The Ultimate Trivia Challenge.
# 21. Getting the Game ID for Quizio PRO: Quiz game.
# 22. Getting the Game ID for Wer Wird Millionär?.
# 23. Getting the Game ID for The Office Fan Quiz (No Ads).
# 24. Getting the Game ID for HQ Trivia Helper Unlimited.

# %%
#print(len(game_list)) #debug statement

# %%
i = 0
game_titles = []
game_scores = []
game_reviews = []
game_prices = []
game_installs = []
game_developers = []
game_urls = []

for game in game_list:
    game_details = gp.details(game_list[i])
    title_info = game_details['title']
    game_titles.append(title_info)
    game_scores.append(game_details['score'])
    game_reviews.append(game_details['reviews'])
    game_prices.append(game_details['price'])
    game_installs.append(game_details['installs'])
    game_developers.append(game_details['developer'])
    game_urls.append(game_details['url'])
    print(f'Getting information for {title_info}.')
    i += 1
print(f'All done! The loop processed a total of {len(game_titles)} results.')
# Out:
# Getting information for Grand Theft Auto: San Andreas.
# Getting information for Five Nights at Freddy's.
# Getting information for Five Nights at Freddy's: SL.
# Getting information for Hitman Sniper.
# Getting information for Assassin's Creed Identity.
# Getting information for Five Nights at Freddy's 4.
# Getting information for Space Marshals.
# Getting information for Call of Duty:Black Ops Zombies.
# Getting information for Grand Theft Auto III.
# Getting information for truTV Impractical Jokers Wheel of Doom.
# Getting information for Teen Titans GO Figure!.
# Getting information for Real Steel.
# Getting information for Five Nights at Freddy's 3.
# Getting information for Downwell.
# Getting information for Bloons Supermonkey 2.
# Getting information for Bully: Anniversary Edition.
# Getting information for LEGO® Star Wars™:  TCS.
# Getting information for LEGO ® Marvel Super Heroes.
# Getting information for Shadow of Death: Stickman Fighting - Dark Knight.
# Getting information for GTA: Chinatown Wars.
# Getting information for Battle of Vicksburg.
# Getting information for PPSSPP Gold - PSP emulator.
# Getting information for Zombieville USA 2.
# Getting information for Goat Simulator GoatZ.
# Getting information for Titan Quest.
# Getting information for Alien: Blackout.
# Getting information for Terraria..
# Getting information for Bendy and the Ink Machine.
# Getting information for THE GALAXY: SURVIVOR.
# Getting information for 60 Seconds! Atomic Adventure.
# Getting information for Don't Starve: Pocket Edition.
# Getting information for LEGO® Jurassic World™.
# Getting information for Portal Knights.
# Getting information for Angry Neighbor.
# Getting information for Thickety Creek.
# Getting information for Octodad: Dadliest Catch.
# Getting information for Sonic Runners Adventure - Fast Action Platformer.
# Getting information for Crashlands.
# Getting information for Castle of Illusion.
# Getting information for Draw a Stickman: EPIC 2.
# Getting information for Live or Die: Survival Pro.
# Getting information for Rusty Lake: Roots.
# Getting information for Survivalcraft 2.
# Getting information for Rusty Lake Hotel.
# Getting information for LEGO Harry Potter: Years 1-4.
# Getting information for GTA: Liberty City Stories.
# Getting information for FINAL FANTASY IX for Android.
# Getting information for Don't Starve: Shipwrecked.
# Getting information for CHUCHEL.
# Getting information for Sky Dancer Premium.
# Getting information for Minecraft.
# Getting information for Geometry Dash.
# Getting information for Grand Theft Auto: Vice City.
# Getting information for Ding Dong XL.
# Getting information for ePSXe for Android.
# Getting information for Fruit Ninja Classic.
# Getting information for My OldBoy! - GBC Emulator.
# Getting information for Pocket God™.
# Getting information for Max Payne Mobile.
# Getting information for Peace, Death!.
# Getting information for Vector Full.
# Getting information for SuperRetro16 ( SNES Emulator ).
# Getting information for Retro N64 Pro - N64 Emulator.
# Getting information for Retro NES Pro - NES Emulator.
# Getting information for PAC-MAN Championship Edition DX.
# Getting information for Worms 3.
# Getting information for Ms. PAC-MAN.
# Getting information for Robot Unicorn Attack.
# Getting information for Marvel Pinball.
# Getting information for The Impossible Game.
# Getting information for Granny Smith.
# Getting information for holedown.
# Getting information for Shopkins Run!.
# Getting information for METAL SLUG 3.
# Getting information for Sonic 4™ Episode I.
# Getting information for The Game of Life.
# Getting information for Clue.
# Getting information for Legends of Andor – The King’s Secret.
# Getting information for Twice as clever.
# Getting information for Ticket to Ride.
# Getting information for Pandemic: The Board Game.
# Getting information for Catan Classic.
# Getting information for Carcassonne: Official Board Game -Tiles & Tactics.
# Getting information for Chess.
# Getting information for Hasbro's BATTLESHIP.
# Getting information for Splendor.
# Getting information for Ganz schön clever.
# Getting information for Backgammon.
# Getting information for Through the Ages.
# Getting information for D&D Lords of Waterdeep.
# Getting information for Race for the Galaxy.
# Getting information for Small World 2.
# Getting information for Stratego® Single Player.
# Getting information for Elder Sign: Omens.
# Getting information for Tokaido™.
# Getting information for Smash Up - The Shufflebuilding Game.
# Getting information for Galaxy Trucker.
# Getting information for Sentinels of the Multiverse.
# Getting information for Talisman.
# Getting information for Mysterium: A Psychic Clue Game.
# Getting information for Exploding Kittens® - Official.
# Getting information for Reigns.
# Getting information for Skip-Bo™.
# Getting information for Card Wars - Adventure Time.
# Getting information for Reigns: Game of Thrones.
# Getting information for Solitaire+.
# Getting information for Reigns: Her Majesty.
# Getting information for Meteorfall: Journeys.
# Getting information for SET Mania.
# Getting information for Blackbird.
# Getting information for Card Quest.
# Getting information for Decked Builder.
# Getting information for Cribbage Pro Online!.
# Getting information for Kemono Mahjong.
# Getting information for Phase 10.
# Getting information for Spades.
# Getting information for Solitaire Collection Premium.
# Getting information for Solitaire MegaPack.
# Getting information for Spider Solitaire+.
# Getting information for Gin Rummy.
# Getting information for Patch Tarot.
# Getting information for FreeCell Solitaire+.
# Getting information for Euchre.
# Getting information for The Game - Play ... as long as you can!.
# Getting information for Munchkin Level Counter.
# Getting information for VIP Slots Club ★ VIP Casino.
# Getting information for Craps Trainer Pro.
# Getting information for Card Counter.
# Getting information for Pokertrainer.
# Getting information for Top Money 💵 Slots (PREMIUM).
# Getting information for Cleopatra Keno.
# Getting information for Vintage Pachinko.
# Getting information for MEGA Money Slots PAID.
# Getting information for Blackjack Verite Games.
# Getting information for Super Times Pay Poker.
# Getting information for Play Perfect Video Poker Pro+.
# Getting information for Multi-Card Keno.
# Getting information for Ultimate X Poker.
# Getting information for Fun Slot Machine Las Vegas Pro.
# Getting information for Carnival Fiesta Slots PAID.
# Getting information for Crock O'Gold Rainbow Slots PAID.
# Getting information for Blackjack Verite Drills.
# Getting information for Speed Rush Las Vegas VIP Slot.
# Getting information for Egypt Reels of Luxor Slots PAID.
# Getting information for Best Hold.
# Getting information for Baccarat Mastery Pro.
# Getting information for Play Perfect Video Poker Pro.
# Getting information for Poker Notes Live - Premium.
# Getting information for Monkey Money 2 Slots.
# Getting information for Wild West Faro.
# Getting information for Let's Create! Pottery.
# Getting information for Tamagotchi Classic - Gen1.
# Getting information for Game Dev Story.
# Getting information for Meme Soundboard PRO 2019.
# Getting information for FINAL FANTASY.
# Getting information for Jazza's Arty Games.
# Getting information for Hidden Folks.
# Getting information for My PlayHome : Play Home Doll House.
# Getting information for Little Inferno.
# Getting information for SpongeBob's Game Frenzy.
# Getting information for My PlayHome Hospital.
# Getting information for My PlayHome Stores.
# Getting information for My PlayHome School.
# Getting information for Fieldrunners HD.
# Getting information for Grow Spaceship VIP - Galaxy Battle.
# Getting information for supertype.
# Getting information for Fieldrunners 2.
# Getting information for Wedding Dash Deluxe.
# Getting information for SpongeBob Diner Dash Deluxe.
# Getting information for Brink of Consciousness (Full).
# Getting information for Burger Shop 2 Deluxe.
# Getting information for Sand! Premium.
# Getting information for Hotel Dash Deluxe.
# Getting information for Virtual Families.
# Getting information for Haunted Hotel: Death Sentence (Full).
# Getting information for Wonderland : Peter Pan.
# Getting information for Teach Your Monster to Read - Phonics and Reading.
# Getting information for Toca Boo.
# Getting information for Toca Blocks.
# Getting information for My Town : Hospital.
# Getting information for Explore Daniel's Neighborhood.
# Getting information for My Town : Airport.
# Getting information for Wonderland : Little Mermaid.
# Getting information for Toca Mystery House.
# Getting information for Toca Lab: Plants.
# Getting information for Peppa Pig: Holiday.
# Getting information for My City : Office.
# Getting information for Daniel Tiger's Stop & Go Potty.
# Getting information for My Town : School.
# Getting information for Learn to Read with Tommy Turtle.
# Getting information for BRIO World - Railway.
# Getting information for Numberblocks - Hide and Seek.
# Getting information for Stack the States® 2.
# Getting information for My Town : Hotel.
# Getting information for Dr. Panda Restaurant 2.
# Getting information for My Town : Best Friends' House.
# Getting information for My Town : ICEME Amusement Park.
# Getting information for My City : Dentist visit.
# Getting information for Second Grade Learning Games.
# Getting information for PAW Patrol Air and Sea Adventures.
# Getting information for Cytus II.
# Getting information for Incredibox.
# Getting information for Lowriders Comeback 2: Cruising.
# Getting information for Muse Dash.
# Getting information for My Singing Monsters Composer.
# Getting information for Note Rush: Learn to Read Music.
# Getting information for Sonar Beat.
# Getting information for Wonder Parade.
# Getting information for Beat Bugs: Sing-Along.
# Getting information for Learn Music Notes.
# Getting information for Caustic 3.2 HipHop Pack 2.
# Getting information for Caustic 3.2 DrumSynth Pack 2.
# Getting information for Caustic 3.2 Tech House Pack 1.
# Getting information for Caustic 3.2 Techno Pack 3.
# Getting information for MC Lars: The Video Game.
# Getting information for Frederic - Evil Strikes Back.
# Getting information for Black Metal Man.
# Getting information for Piano Master.
# Getting information for Piano Flashcards.
# Getting information for Drum Pad Beats.
# Getting information for Caustic 3.2 Minimal Pack 2.
# Getting information for Note Fighter Unlimited.
# Getting information for A Dance of Fire and Ice.
# Getting information for Beat Beat Vocaloid.
# Getting information for Meow Music.
# Getting information for Scribblenauts Remix.
# Getting information for The Room.
# Getting information for Scribblenauts Unlimited.
# Getting information for The Room: Old Sins.
# Getting information for Agent A: A puzzle in disguise.
# Getting information for The Room Two.
# Getting information for Florence.
# Getting information for Monument Valley.
# Getting information for The Room Three.
# Getting information for The House of Da Vinci.
# Getting information for Monument Valley 2.
# Getting information for Bridge Constructor Portal.
# Getting information for Hitman GO.
# Getting information for Lara Croft GO.
# Getting information for Where's My Water?.
# Getting information for Doodle God™.
# Getting information for Legacy 3 - The Hidden Relic.
# Getting information for Doodle God™ HD.
# Getting information for Please, Don't Touch Anything.
# Getting information for Human Resource Machine.
# Getting information for Cut the Rope GOLD.
# Getting information for Gorogoa.
# Getting information for Scalak.
# Getting information for Doodle Devil™ HD.
# Getting information for Deus Ex GO.
# Getting information for Earn to Die.
# Getting information for Bike Race Pro by T. F. Games.
# Getting information for Real Drift Car Racing.
# Getting information for Need for Speed Most Wanted.
# Getting information for Motorsport Manager Mobile 3.
# Getting information for TRAIL CLIMB.
# Getting information for Dirt Trackin.
# Getting information for Riptide GP: Renegade.
# Getting information for PJ Masks: Racing Heroes.
# Getting information for Rush Rally 2.
# Getting information for Dirt Trackin Sprint Cars.
# Getting information for Drag Racing 3D.
# Getting information for Need for Speed Hot Pursuit.
# Getting information for Ricky Carmichael's Motocross.
# Getting information for Bike Mayhem Mountain Racing.
# Getting information for Reckless Racing 3.
# Getting information for Riptide GP2.
# Getting information for ULTRA4 Offroad Racing.
# Getting information for Outlaws - Sprint Car Racing.
# Getting information for Draw Rider Plus.
# Getting information for Riptide GP.
# Getting information for F1 2016.
# Getting information for Dirt Racing Mobile 3D.
# Getting information for Pocket Rally.
# Getting information for Repulze.
# Getting information for Evoland.
# Getting information for Star Wars™: KOTOR.
# Getting information for Doom & Destiny Advanced.
# Getting information for EvoCreo.
# Getting information for Attack the Light.
# Getting information for Neverwinter Nights: Enhanced Edition.
# Getting information for Monster Hunter Stories.
# Getting information for FINAL FANTASY VII.
# Getting information for Alter Ego.
# Getting information for 80 Days.
# Getting information for Baldur's Gate: Enhanced Edition.
# Getting information for CHRONO TRIGGER (Upgrade Ver.).
# Getting information for The Bard's Tale.
# Getting information for Evoland 2.
# Getting information for Day R Premium.
# Getting information for ICEY.
# Getting information for Rogue Hearts.
# Getting information for DRAGON QUEST.
# Getting information for Pocket Rogues: Ultimate.
# Getting information for Goat Simulator MMO Simulator.
# Getting information for Hardboiled.
# Getting information for Battleheart Legacy.
# Getting information for Guild of Dungeoneering.
# Getting information for Neo Monsters.
# Getting information for A Dark Room ®.
# Getting information for Mini Metro.
# Getting information for Poly Bridge.
# Getting information for Farming Simulator 18.
# Getting information for Goat Simulator.
# Getting information for Game Dev Tycoon.
# Getting information for Pocket City.
# Getting information for FINAL FANTASY TACTICS : WotL.
# Getting information for Infinite Flight - Flight Simulator.
# Getting information for Goat Simulator Payday.
# Getting information for Project Highrise.
# Getting information for Getting Over It with Bennett Foddy.
# Getting information for Youtubers Life: Gaming Channel.
# Getting information for Goat Simulator Waste of Space.
# Getting information for Pocket Aquarium.
# Getting information for Farming Simulator 16.
# Getting information for Construction Simulator 2.
# Getting information for This Is the Police.
# Getting information for One Hour One Life for Mobile.
# Getting information for SimplePlanes.
# Getting information for Farming USA 2.
# Getting information for Truck Simulator PRO 2.
# Getting information for 911 Operator.
# Getting information for SPACEPLAN.
# Getting information for Construction Simulator 2014.
# Getting information for Ultimate Wolf Simulator.
# Getting information for NBA 2K19.
# Getting information for True Skate.
# Getting information for NBA JAM  by EA SPORTS™.
# Getting information for Football Manager 2019 Mobile.
# Getting information for WWE 2K.
# Getting information for Skater.
# Getting information for Dude Perfect.
# Getting information for Clay Hunt PRO.
# Getting information for OK Golf.
# Getting information for Flick Golf!.
# Getting information for R.B.I. Baseball 18.
# Getting information for Duck Life: Space.
# Getting information for Sumotori Dreams.
# Getting information for Ice Fishing Derby Premium.
# Getting information for Pumped BMX 3.
# Getting information for MLB Manager 2018.
# Getting information for Fish-o-niric.
# Getting information for Duck Life: Retro Pack.
# Getting information for Pro Strategy Football 2018.
# Getting information for Home Run High.
# Getting information for College BBALL Coach.
# Getting information for CN Superstar Soccer: Goal!!!.
# Getting information for Shred! 2 - Freeride Mountain Biking.
# Getting information for Disc Golf Game.
# Getting information for Athletics 2: Summer Sports.
# Getting information for Bloons TD 6.
# Getting information for Kingdom Rush Vengeance.
# Getting information for Bloons TD 5.
# Getting information for Age of Civilizations II.
# Getting information for Papa's Freezeria To Go!.
# Getting information for The Escapists: Prison Escape.
# Getting information for Five Nights at Freddy's 2.
# Getting information for ROME: Total War.
# Getting information for Rusted Warfare - RTS Strategy.
# Getting information for Civilization Revolution 2.
# Getting information for First Strike: Final Hour.
# Getting information for Papa's Scooperia To Go!.
# Getting information for Kingdom Rush Frontiers.
# Getting information for Papa's Burgeria To Go!.
# Getting information for Uciana.
# Getting information for XCOM®: Enemy Within.
# Getting information for Papa's Pancakeria To Go!.
# Getting information for Papa's Pizzeria To Go!.
# Getting information for Kingdom Rush Origins.
# Getting information for Door Kickers.
# Getting information for Papa's Cupcakeria To Go!.
# Getting information for Warhammer 40,000: Regicide.
# Getting information for Teeny Titans - Teen Titans Go!.
# Getting information for Rebuild 3: Gangs of Deadsville.
# Getting information for Organ Trail: Director's Cut.
# Getting information for Trivia Crack (No Ads).
# Getting information for Sporcle.
# Getting information for BLeBRiTY.
# Getting information for The Jackbox Party Pack.
# Getting information for The Jackbox Party Pack 5.
# Getting information for Bible Bowl Prep 2019.
# Getting information for The Jackbox Party Pack 3.
# Getting information for The 7 Second Challenge.
# Getting information for The Jackbox Party Pack 2.
# Getting information for The Black Card Game.
# Getting information for 4 Player Reactor (Multiplayer).
# Getting information for Pointless Quiz.
# Getting information for The Jackbox Party Pack 4.
# Getting information for Quizoid Pro: Category Trivia with 5 Game modes.
# Getting information for Penny Dell Jumbo Crosswords.
# Getting information for Einstein™ Brain Training.
# Getting information for Text Twist 2019.
# Getting information for Lets get wasted 18+ ;).
# Getting information for SHAPE - the picture trivia quiz.
# Getting information for QuizBash - Party Games in Your Pocket!.
# Getting information for The Ultimate Trivia Challenge.
# Getting information for Quizio PRO: Quiz game.
# Getting information for Wer Wird Millionär?.
# Getting information for The Office Fan Quiz (No Ads).
# Getting information for HQ Trivia Helper Unlimited.
# All done! The loop processed a total of 400 results.

# %%
games_master = {
    "Game Title": game_titles,
    "Game Category": game_category,
    "Game Score": game_scores,
    "Number of Reviews": game_reviews,
    "Price": game_prices,
    "Number of Installs": game_installs,
    "Developer": game_developers,
    "Play Store URL": game_urls
    
}
games_df = pd.DataFrame(games_master)
games_df.head(20)
# Out:
#                                           Game Title Game Category Game Score  \
# 0                      Grand Theft Auto: San Andreas   GAME_ACTION        4.3
# 1                            Five Nights at Freddy's   GAME_ACTION        4.6
# 2                        Five Nights at Freddy's: SL   GAME_ACTION        4.5
# 3                                      Hitman Sniper   GAME_ACTION        4.6
# 4                          Assassin's Creed Identity   GAME_ACTION        3.8
# 5                          Five Nights at Freddy's 4   GAME_ACTION        4.6
# 6                                     Space Marshals   GAME_ACTION        4.8
# 7                     Call of Duty:Black Ops Zombies   GAME_ACTION        4.2
# 8                               Grand Theft Auto III   GAME_ACTION        4.0
# 9             truTV Impractical Jokers Wheel of Doom   GAME_ACTION        4.3
# 10                            Teen Titans GO Figure!   GAME_ACTION        4.5
# 11                                        Real Steel   GAME_ACTION        4.1
# 12                         Five Nights at Freddy's 3   GAME_ACTION        4.7
# 13                                          Downwell   GAME_ACTION        4.7
# 14                              Bloons Supermonkey 2   GAME_ACTION        4.6
# 15                        Bully: Anniversary Edition   GAME_ACTION        4.5
# 16                            LEGO® Star Wars™:  TCS   GAME_ACTION        3.7
# 17                        LEGO ® Marvel Super Heroes   GAME_ACTION        4.1
# 18  Shadow of Death: Stickman Fighting - Dark Knight   GAME_ACTION        4.6
# 19                               GTA: Chinatown Wars   GAME_ACTION        4.3
#
#     Number of Reviews  Price Number of Installs  \
# 0              387897  $6.99         1,000,000+
# 1              103826  $2.99         1,000,000+
# 2               17369  $2.99           100,000+
# 3              592148  $0.99        10,000,000+
# 4               50021  $1.99           500,000+
# 5               21580  $2.99           100,000+
# 6                7931  $0.99            50,000+
# 7               14006  $6.99           100,000+
# 8               96670  $4.99         1,000,000+
# 9                 170  $2.99             5,000+
# 10               4578  $3.99            50,000+
# 11              26201  $0.99           500,000+
# 12              28214  $2.99           100,000+
# 13               4561  $2.99           100,000+
# 14              15580  $0.99           500,000+
# 15              13488  $6.99           100,000+
# 16              16810  $6.99           100,000+
# 17              16461  $4.99           100,000+
# 18              59018  $0.99         1,000,000+
# 19              25398  $4.99           100,000+
#
#                                           Developer  \
# 0                                    Rockstar Games
# 1                                     Scott Cawthon
# 2                                     Scott Cawthon
# 3                                   SQUARE ENIX Ltd
# 4                             Ubisoft Entertainment
# 5                                     Scott Cawthon
# 6                                         Pixelbite
# 7                       Activision Publishing, Inc.
# 8                                    Rockstar Games
# 9                                      truTVnetwork
# 10                                  Cartoon Network
# 11  Reliance Big Entertainment (UK) Private Limited
# 12                                    Scott Cawthon
# 13                                  DevolverDigital
# 14                                       ninja kiwi
# 15                                   Rockstar Games
# 16           Warner Bros. International Enterprises
# 17           Warner Bros. International Enterprises
# 18                               Zonmob Game Studio
# 19                                   Rockstar Games
#
#                                        Play Store URL
# 0   https://play.google.com/store/apps/details?id=...
# 1   https://play.google.com/store/apps/details?id=...
# 2   https://play.google.com/store/apps/details?id=...
# 3   https://play.google.com/store/apps/details?id=...
# 4   https://play.google.com/store/apps/details?id=...
# 5   https://play.google.com/store/apps/details?id=...
# 6   https://play.google.com/store/apps/details?id=...
# 7   https://play.google.com/store/apps/details?id=...
# 8   https://play.google.com/store/apps/details?id=...
# 9   https://play.google.com/store/apps/details?id=...
# 10  https://play.google.com/store/apps/details?id=...
# 11  https://play.google.com/store/apps/details?id=...
# 12  https://play.google.com/store/apps/details?id=...
# 13  https://play.google.com/store/apps/details?id=...
# 14  https://play.google.com/store/apps/details?id=...
# 15  https://play.google.com/store/apps/details?id=...
# 16  https://play.google.com/store/apps/details?id=...
# 17  https://play.google.com/store/apps/details?id=...
# 18  https://play.google.com/store/apps/details?id=...
# 19  https://play.google.com/store/apps/details?id=...

# %%
# check the data types
#games_df.info()  #debug statement

# %%
# Cleans up and formats the data
games_df['Number of Installs'] = games_df['Number of Installs'].str.replace('+', '')
games_df['Number of Installs'] = games_df['Number of Installs'].str.replace(',', '')
games_df['Number of Installs'] = pd.to_numeric(games_df['Number of Installs'], errors='coerce')
games_df['Game Score'] = pd.to_numeric(games_df['Game Score'], errors='coerce')
games_df['Price'] = games_df['Price'].str.replace('$', '')
games_df['Price'] = pd.to_numeric(games_df['Price'], errors='coerce')
games_df.head()
# Out:
#                       Game Title Game Category  Game Score  Number of Reviews  \
# 0  Grand Theft Auto: San Andreas   GAME_ACTION         4.3             387897
# 1        Five Nights at Freddy's   GAME_ACTION         4.6             103826
# 2    Five Nights at Freddy's: SL   GAME_ACTION         4.5              17369
# 3                  Hitman Sniper   GAME_ACTION         4.6             592148
# 4      Assassin's Creed Identity   GAME_ACTION         3.8              50021
#
#    Price  Number of Installs              Developer  \
# 0   6.99             1000000         Rockstar Games
# 1   2.99             1000000          Scott Cawthon
# 2   2.99              100000          Scott Cawthon
# 3   0.99            10000000        SQUARE ENIX Ltd
# 4   1.99              500000  Ubisoft Entertainment
#
#                                       Play Store URL
# 0  https://play.google.com/store/apps/details?id=...
# 1  https://play.google.com/store/apps/details?id=...
# 2  https://play.google.com/store/apps/details?id=...
# 3  https://play.google.com/store/apps/details?id=...
# 4  https://play.google.com/store/apps/details?id=...

# %%
games_df["Total Download Revenue ($)"] = games_df["Price"]*games_df["Number of Installs"]

# %%
#games_df.dtypes #debug statement

# %%
games_df.to_csv("Games_df.csv")

# %%
#segregating the data by category from main DF

arcade_game = games_df.loc[games_df["Game Category"]=="GAME_ARCADE"]
sports_game = games_df.loc[games_df["Game Category"]=="GAME_SPORTS"]
racing_game = games_df.loc[games_df["Game Category"]=="GAME_RACING"]
music_game = games_df.loc[games_df["Game Category"]=="GAME_MUSIC"]
educational_game = games_df.loc[games_df["Game Category"]== "GAME_EDUCATIONAL"]
board_game = games_df.loc[games_df["Game Category"]=="GAME_BOARD"]
casino_game = games_df.loc[games_df["Game Category"]=="GAME_CASINO"]
action_game = games_df.loc[games_df["Game Category"]=="GAME_ACTION"]
trivia_game = games_df.loc[games_df["Game Category"]=="GAME_TRIVIA"]
simulation_game = games_df.loc[games_df["Game Category"]=="GAME_SIMULATION"]
adventure_game = games_df.loc[games_df["Game Category"]=="GAME_ADVENTURE"]
puzzle_game = games_df.loc[games_df["Game Category"]=="GAME_PUZZLE"]
card_game = games_df.loc[games_df["Game Category"]=="GAME_CARD"]
casual_game = games_df.loc[games_df["Game Category"]=="GAME_CASUAL"]
strategy_game = games_df.loc[games_df["Game Category"]=="GAME_STRATEGY"]                       
roleplay_game = games_df.loc[games_df["Game Category"]=="GAME_ROLE_PLAYING"]
word_game = games_df.loc[games_df["Game Category"]=="GAME_WORD"]

# %%
# Although action game and arcade games receive similar amount of dls, arcade games receives 3x of
# total revenue. Therefore, based on the finding from Greg's group_sums and game_inst_sums DFs,
# it appears arcade_game generates most of the revenue out of all sub-catergories. The analysis from here will be
# focusing on arcade catergory only.

arcade_game = arcade_game.sort_values(by='Total Download Revenue ($)', ascending=False)
#arcade_game  #debug statement

# %%
#bar chart by revenue.
tick_location = np.arange(len(arcade_game))
plt.bar(tick_location,arcade_game["Total Download Revenue ($)"], align="center")
plt.xticks(tick_location,arcade_game["Game Title"], rotation=90)
plt.xticks()
plt.title("Revenues Generated from Top 25 Paid Arcade Games")
plt.xlim(-1, len(arcade_game)-1)
plt.ylim(0,max(arcade_game["Total Download Revenue ($)"]+5000000))
plt.ylabel("Total Download Revenue (million)")
plt.tight_layout()

# %%
#bar chart by # of dl.
tick_location = np.arange(len(arcade_game))
plt.bar(tick_location,arcade_game["Number of Installs"], align="center")
plt.xticks(tick_location,arcade_game["Game Title"], rotation=90)
plt.xlim(-1, len(arcade_game)-1)
plt.ylim(0,max(arcade_game["Number of Installs"]+500000))
plt.ylabel("Number of Installs (10 millions)")
plt.title("Number of Download of Top 25 Paid Arcade Games")
plt.tight_layout()

# %%
# in comparsion, let's extract 3 top paid games from each catergory
top_games = games_df.groupby('Game Category', group_keys=False).apply(lambda x: x.nlargest(3, 'Total Download Revenue ($)'))

# %%
top_games = top_games.sort_values(by='Total Download Revenue ($)', ascending=False)
#top_games  #debug statement

# %%
#showing the data with a scatter plot

arcade = top_games.loc[top_games["Game Category"]=="GAME_ARCADE"]
sports = top_games.loc[top_games["Game Category"]=="GAME_SPORTS"]
racing = top_games.loc[top_games["Game Category"]=="GAME_RACING"]
music = top_games.loc[top_games["Game Category"]=="GAME_MUSIC"]
educational = top_games.loc[top_games["Game Category"]== "GAME_EDUCATIONAL"]
board = top_games.loc[top_games["Game Category"]=="GAME_BOARD"]
casino = top_games.loc[top_games["Game Category"]=="GAME_CASINO"]
action = top_games.loc[top_games["Game Category"]=="GAME_ACTION"]
trivia = top_games.loc[top_games["Game Category"]=="GAME_TRIVIA"]
simulation = top_games.loc[top_games["Game Category"]=="GAME_SIMULATION"]
adventure = top_games.loc[top_games["Game Category"]=="GAME_ADVENTURE"]
puzzle = top_games.loc[top_games["Game Category"]=="GAME_PUZZLE"]
card = top_games.loc[top_games["Game Category"]=="GAME_CARD"]
casual = top_games.loc[top_games["Game Category"]=="GAME_CASUAL"]
strategy = top_games.loc[top_games["Game Category"]=="GAME_STRATEGY"]                       
roleplay = top_games.loc[top_games["Game Category"]=="GAME_ROLE_PLAYING"]
word = top_games.loc[top_games["Game Category"]=="GAME_WORD"]

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Number of Installs"], arcade["Total Download Revenue ($)"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Number of Installs"], sports["Total Download Revenue ($)"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Number of Installs"], racing["Total Download Revenue ($)"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Number of Installs"], music["Total Download Revenue ($)"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Number of Installs"], educational["Total Download Revenue ($)"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Number of Installs"], board["Total Download Revenue ($)"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Number of Installs"], casino["Total Download Revenue ($)"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Number of Installs"], action["Total Download Revenue ($)"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Number of Installs"], trivia["Total Download Revenue ($)"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Number of Installs"], simulation["Total Download Revenue ($)"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Number of Installs"], adventure["Total Download Revenue ($)"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Number of Installs"], puzzle["Total Download Revenue ($)"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Number of Installs"], card["Total Download Revenue ($)"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Number of Installs"], casual["Total Download Revenue ($)"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Number of Installs"], strategy["Total Download Revenue ($)"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Number of Installs"], roleplay["Total Download Revenue ($)"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Number of Installs"], word["Total Download Revenue ($)"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Number of Installs")
plt.ylabel("Total Download Revenue ($10 Millions)")
plt.title("Top Paid Games")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
arcade = games_df.loc[games_df["Game Category"]=="GAME_ARCADE"]
sports = games_df.loc[games_df["Game Category"]=="GAME_SPORTS"]
racing = games_df.loc[games_df["Game Category"]=="GAME_RACING"]
music = games_df.loc[games_df["Game Category"]=="GAME_MUSIC"]
educational = games_df.loc[games_df["Game Category"]== "GAME_EDUCATIONAL"]
board = games_df.loc[games_df["Game Category"]=="GAME_BOARD"]
casino = games_df.loc[games_df["Game Category"]=="GAME_CASINO"]
action = games_df.loc[games_df["Game Category"]=="GAME_ACTION"]
trivia = games_df.loc[games_df["Game Category"]=="GAME_TRIVIA"]
simulation = games_df.loc[games_df["Game Category"]=="GAME_SIMULATION"]
adventure = games_df.loc[games_df["Game Category"]=="GAME_ADVENTURE"]
puzzle = games_df.loc[games_df["Game Category"]=="GAME_PUZZLE"]
card = games_df.loc[games_df["Game Category"]=="GAME_CARD"]
casual = games_df.loc[games_df["Game Category"]=="GAME_CASUAL"]
strategy = games_df.loc[games_df["Game Category"]=="GAME_STRATEGY"]                       
roleplay = games_df.loc[games_df["Game Category"]=="GAME_ROLE_PLAYING"]
word = games_df.loc[games_df["Game Category"]=="GAME_WORD"]

# %%
arcade_p = plt.scatter(arcade["Number of Installs"], arcade["Total Download Revenue ($)"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Number of Installs"], sports["Total Download Revenue ($)"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Number of Installs"], racing["Total Download Revenue ($)"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Number of Installs"], music["Total Download Revenue ($)"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Number of Installs"], educational["Total Download Revenue ($)"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Number of Installs"], board["Total Download Revenue ($)"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Number of Installs"], casino["Total Download Revenue ($)"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Number of Installs"], action["Total Download Revenue ($)"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Number of Installs"], trivia["Total Download Revenue ($)"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Number of Installs"], simulation["Total Download Revenue ($)"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Number of Installs"], adventure["Total Download Revenue ($)"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Number of Installs"], puzzle["Total Download Revenue ($)"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Number of Installs"], card["Total Download Revenue ($)"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Number of Installs"], casual["Total Download Revenue ($)"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Number of Installs"], strategy["Total Download Revenue ($)"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Number of Installs"], roleplay["Total Download Revenue ($)"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Number of Installs"], word["Total Download Revenue ($)"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Number of Installs")
plt.ylabel("Total Download Revenue ($10 Millions)")
plt.title("Top Paid Games")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Number of Installs"], arcade["Price"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Number of Installs"], sports["Price"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Number of Installs"], racing["Price"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Number of Installs"], music["Price"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Number of Installs"], educational["Price"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Number of Installs"], board["Price"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Number of Installs"], casino["Price"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Number of Installs"], action["Price"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Number of Installs"], trivia["Price"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Number of Installs"], simulation["Price"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Number of Installs"], adventure["Price"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Number of Installs"], puzzle["Price"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Number of Installs"], card["Price"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Number of Installs"], casual["Price"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Number of Installs"], strategy["Price"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Number of Installs"], roleplay["Price"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Number of Installs"], word["Price"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Number of Installs")
plt.ylabel("Price")
plt.title("Downloads Vs. Price")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Price"], arcade["Total Download Revenue ($)"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Price"], sports["Total Download Revenue ($)"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Price"], racing["Total Download Revenue ($)"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Price"], music["Total Download Revenue ($)"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Price"], educational["Total Download Revenue ($)"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Price"], board["Total Download Revenue ($)"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Price"], casino["Total Download Revenue ($)"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Price"], action["Total Download Revenue ($)"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Price"], trivia["Total Download Revenue ($)"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Price"], simulation["Total Download Revenue ($)"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Price"], adventure["Total Download Revenue ($)"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Price"], puzzle["Total Download Revenue ($)"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Price"], card["Total Download Revenue ($)"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Price"], casual["Total Download Revenue ($)"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Price"], strategy["Total Download Revenue ($)"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Price"], roleplay["Total Download Revenue ($)"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Price"], word["Total Download Revenue ($)"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Price")
plt.ylabel("Total Download Revenue ($10 Millions)")
plt.title("Price to Revenue")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Game Score"], arcade["Total Download Revenue ($)"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Game Score"], sports["Total Download Revenue ($)"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Game Score"], racing["Total Download Revenue ($)"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Game Score"], music["Total Download Revenue ($)"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Game Score"], educational["Total Download Revenue ($)"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Game Score"], board["Total Download Revenue ($)"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Game Score"], casino["Total Download Revenue ($)"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Game Score"], action["Total Download Revenue ($)"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Game Score"], trivia["Total Download Revenue ($)"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Game Score"], simulation["Total Download Revenue ($)"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Game Score"], adventure["Total Download Revenue ($)"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Game Score"], puzzle["Total Download Revenue ($)"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Game Score"], card["Total Download Revenue ($)"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Game Score"], casual["Total Download Revenue ($)"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Game Score"], strategy["Total Download Revenue ($)"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Game Score"], roleplay["Total Download Revenue ($)"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Game Score"], word["Total Download Revenue ($)"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Game Score")
plt.ylabel("Total Download Revenue ($10 Millions)")
plt.title("Game Score Vs Revenue")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))


fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('Images/GameScoreVsRevenue', bbox_inches="tight")

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Game Score"], arcade["Number of Reviews"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Game Score"], sports["Number of Reviews"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Game Score"], racing["Number of Reviews"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Game Score"], music["Number of Reviews"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Game Score"], educational["Number of Reviews"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Game Score"], board["Number of Reviews"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Game Score"], casino["Number of Reviews"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Game Score"], action["Number of Reviews"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Game Score"], trivia["Number of Reviews"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Game Score"], simulation["Number of Reviews"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Game Score"], adventure["Number of Reviews"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Game Score"], puzzle["Number of Reviews"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Game Score"], card["Number of Reviews"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Game Score"], casual["Number of Reviews"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Game Score"], strategy["Number of Reviews"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Game Score"], roleplay["Number of Reviews"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Game Score"], word["Number of Reviews"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Game Score")
plt.ylabel("Number of Reviews")
plt.title("Game Score Vs Reviews")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
games_df = games_df.sort_values("Total Download Revenue ($)", ascending=False)
#games_df  #debug statement

# %%
games_df2 = games_df.drop(games_df.index[0])
games_df2 = games_df2.drop(games_df2.index[0])
#games_df2  #debug statement

# %%
arcade = games_df2.loc[games_df2["Game Category"]=="GAME_ARCADE"]
sports = games_df2.loc[games_df2["Game Category"]=="GAME_SPORTS"]
racing = games_df2.loc[games_df2["Game Category"]=="GAME_RACING"]
music = games_df2.loc[games_df2["Game Category"]=="GAME_MUSIC"]
educational = games_df2.loc[games_df2["Game Category"]== "GAME_EDUCATIONAL"]
board = games_df2.loc[games_df2["Game Category"]=="GAME_BOARD"]
casino = games_df2.loc[games_df2["Game Category"]=="GAME_CASINO"]
action = games_df2.loc[games_df2["Game Category"]=="GAME_ACTION"]
trivia = games_df2.loc[games_df2["Game Category"]=="GAME_TRIVIA"]
simulation = games_df2.loc[games_df2["Game Category"]=="GAME_SIMULATION"]
adventure = games_df2.loc[games_df2["Game Category"]=="GAME_ADVENTURE"]
puzzle = games_df2.loc[games_df2["Game Category"]=="GAME_PUZZLE"]
card = games_df2.loc[games_df2["Game Category"]=="GAME_CARD"]
casual = games_df2.loc[games_df2["Game Category"]=="GAME_CASUAL"]
strategy = games_df2.loc[games_df2["Game Category"]=="GAME_STRATEGY"]                       
roleplay = games_df2.loc[games_df2["Game Category"]=="GAME_ROLE_PLAYING"]
word = games_df2.loc[games_df2["Game Category"]=="GAME_WORD"]

# %%
arcade_p = plt.scatter(arcade["Number of Installs"], arcade["Total Download Revenue ($)"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Number of Installs"], sports["Total Download Revenue ($)"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Number of Installs"], racing["Total Download Revenue ($)"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Number of Installs"], music["Total Download Revenue ($)"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Number of Installs"], educational["Total Download Revenue ($)"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Number of Installs"], board["Total Download Revenue ($)"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Number of Installs"], casino["Total Download Revenue ($)"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Number of Installs"], action["Total Download Revenue ($)"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Number of Installs"], trivia["Total Download Revenue ($)"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Number of Installs"], simulation["Total Download Revenue ($)"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Number of Installs"], adventure["Total Download Revenue ($)"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Number of Installs"], puzzle["Total Download Revenue ($)"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Number of Installs"], card["Total Download Revenue ($)"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Number of Installs"], casual["Total Download Revenue ($)"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Number of Installs"], strategy["Total Download Revenue ($)"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Number of Installs"], roleplay["Total Download Revenue ($)"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Number of Installs"], word["Total Download Revenue ($)"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Number of Installs")
plt.ylabel("Total Download Revenue ($10 Millions)")
plt.title("Top Paid Games")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
##Scatter plots based on 'Games_df'###

#showing the data with a scatter plot

arcade = games_df.loc[games_df["Game Category"]=="GAME_ARCADE"]
sports = games_df.loc[games_df["Game Category"]=="GAME_SPORTS"]
racing = games_df.loc[games_df["Game Category"]=="GAME_RACING"]
music = games_df.loc[games_df["Game Category"]=="GAME_MUSIC"]
educational = games_df.loc[games_df["Game Category"]== "GAME_EDUCATIONAL"]
board = games_df.loc[games_df["Game Category"]=="GAME_BOARD"]
casino = games_df.loc[games_df["Game Category"]=="GAME_CASINO"]
action = games_df.loc[games_df["Game Category"]=="GAME_ACTION"]
trivia = games_df.loc[games_df["Game Category"]=="GAME_TRIVIA"]
simulation = games_df.loc[games_df["Game Category"]=="GAME_SIMULATION"]
adventure = games_df.loc[games_df["Game Category"]=="GAME_ADVENTURE"]
puzzle = games_df.loc[games_df["Game Category"]=="GAME_PUZZLE"]
card = games_df.loc[games_df["Game Category"]=="GAME_CARD"]
casual = games_df.loc[games_df["Game Category"]=="GAME_CASUAL"]
strategy = games_df.loc[games_df["Game Category"]=="GAME_STRATEGY"]                       
roleplay = games_df.loc[games_df["Game Category"]=="GAME_ROLE_PLAYING"]
word = games_df.loc[games_df["Game Category"]=="GAME_WORD"]

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Number of Installs"], arcade["Total Download Revenue ($)"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Number of Installs"], sports["Total Download Revenue ($)"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Number of Installs"], racing["Total Download Revenue ($)"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Number of Installs"], music["Total Download Revenue ($)"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Number of Installs"], educational["Total Download Revenue ($)"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Number of Installs"], board["Total Download Revenue ($)"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Number of Installs"], casino["Total Download Revenue ($)"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Number of Installs"], action["Total Download Revenue ($)"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Number of Installs"], trivia["Total Download Revenue ($)"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Number of Installs"], simulation["Total Download Revenue ($)"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Number of Installs"], adventure["Total Download Revenue ($)"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Number of Installs"], puzzle["Total Download Revenue ($)"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Number of Installs"], card["Total Download Revenue ($)"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Number of Installs"], casual["Total Download Revenue ($)"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Number of Installs"], strategy["Total Download Revenue ($)"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Number of Installs"], roleplay["Total Download Revenue ($)"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Number of Installs"], word["Total Download Revenue ($)"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Number of Installs")
plt.ylabel("Total Download Revenue ($10 Millions)")
plt.title("Installs Vs Revenue (All Games)")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Number of Installs"], arcade["Price"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Number of Installs"], sports["Price"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Number of Installs"], racing["Price"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Number of Installs"], music["Price"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Number of Installs"], educational["Price"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Number of Installs"], board["Price"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Number of Installs"], casino["Price"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Number of Installs"], action["Price"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Number of Installs"], trivia["Price"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Number of Installs"], simulation["Price"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Number of Installs"], adventure["Price"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Number of Installs"], puzzle["Price"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Number of Installs"], card["Price"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Number of Installs"], casual["Price"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Number of Installs"], strategy["Price"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Number of Installs"], roleplay["Price"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Number of Installs"], word["Price"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Number of Installs")
plt.ylabel("Price")
plt.title("Downloads Vs. Price (All Games)")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Price"], arcade["Total Download Revenue ($)"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Price"], sports["Total Download Revenue ($)"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Price"], racing["Total Download Revenue ($)"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Price"], music["Total Download Revenue ($)"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Price"], educational["Total Download Revenue ($)"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Price"], board["Total Download Revenue ($)"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Price"], casino["Total Download Revenue ($)"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Price"], action["Total Download Revenue ($)"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Price"], trivia["Total Download Revenue ($)"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Price"], simulation["Total Download Revenue ($)"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Price"], adventure["Total Download Revenue ($)"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Price"], puzzle["Total Download Revenue ($)"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Price"], card["Total Download Revenue ($)"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Price"], casual["Total Download Revenue ($)"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Price"], strategy["Total Download Revenue ($)"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Price"], roleplay["Total Download Revenue ($)"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Price"], word["Total Download Revenue ($)"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Price")
plt.ylabel("Total Download Revenue ($10 Millions)")
plt.title("Price to Revenue (All Games)")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.savefig("Images/PriceVsRevenue.png")

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Game Score"], arcade["Total Download Revenue ($)"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Game Score"], sports["Total Download Revenue ($)"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Game Score"], racing["Total Download Revenue ($)"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Game Score"], music["Total Download Revenue ($)"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Game Score"], educational["Total Download Revenue ($)"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Game Score"], board["Total Download Revenue ($)"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Game Score"], casino["Total Download Revenue ($)"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Game Score"], action["Total Download Revenue ($)"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Game Score"], trivia["Total Download Revenue ($)"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Game Score"], simulation["Total Download Revenue ($)"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Game Score"], adventure["Total Download Revenue ($)"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Game Score"], puzzle["Total Download Revenue ($)"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Game Score"], card["Total Download Revenue ($)"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Game Score"], casual["Total Download Revenue ($)"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Game Score"], strategy["Total Download Revenue ($)"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Game Score"], roleplay["Total Download Revenue ($)"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Game Score"], word["Total Download Revenue ($)"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Game Score")
plt.ylabel("Total Download Revenue ($10 Millions)")
plt.title("Game Score Vs Revenue (All Games)")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.show()
plt.savefig("Images/GameScoreVsRevenue.png")

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Game Score"], arcade["Number of Reviews"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Game Score"], sports["Number of Reviews"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Game Score"], racing["Number of Reviews"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Game Score"], music["Number of Reviews"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Game Score"], educational["Number of Reviews"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Game Score"], board["Number of Reviews"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Game Score"], casino["Number of Reviews"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Game Score"], action["Number of Reviews"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Game Score"], trivia["Number of Reviews"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Game Score"], simulation["Number of Reviews"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Game Score"], adventure["Number of Reviews"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Game Score"], puzzle["Number of Reviews"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Game Score"], card["Number of Reviews"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Game Score"], casual["Number of Reviews"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Game Score"], strategy["Number of Reviews"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Game Score"], roleplay["Number of Reviews"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Game Score"], word["Number of Reviews"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Game Score")
plt.ylabel("Number of Reviews")
plt.title("Game Score Vs Reviews (All Games)")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
###Reviews to Price Plot

arcade_p = plt.scatter(arcade["Price"], arcade["Number of Reviews"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Price"], sports["Number of Reviews"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Price"], racing["Number of Reviews"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Price"], music["Number of Reviews"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Price"], educational["Number of Reviews"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Price"], board["Number of Reviews"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Price"], casino["Number of Reviews"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Price"], action["Number of Reviews"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Price"], trivia["Number of Reviews"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Price"], simulation["Number of Reviews"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Price"], adventure["Number of Reviews"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Price"], puzzle["Number of Reviews"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Price"], card["Number of Reviews"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Price"], casual["Number of Reviews"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Price"], strategy["Number of Reviews"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Price"], roleplay["Number of Reviews"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Price"], word["Number of Reviews"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Price ($)")
plt.ylabel("Number of Reviews")
plt.title("Price Vs. Number of Reviews (All Games)")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.savefig("Images/PriceVsReviews.png", bbox_inches="tight")

# %%
###Reviews to Total Revenue Plot

arcade_p = plt.scatter(arcade["Total Download Revenue ($)"], arcade["Number of Reviews"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Total Download Revenue ($)"], sports["Number of Reviews"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Total Download Revenue ($)"], racing["Number of Reviews"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Total Download Revenue ($)"], music["Number of Reviews"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Total Download Revenue ($)"], educational["Number of Reviews"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Total Download Revenue ($)"], board["Number of Reviews"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Total Download Revenue ($)"], casino["Number of Reviews"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Total Download Revenue ($)"], action["Number of Reviews"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Total Download Revenue ($)"], trivia["Number of Reviews"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Total Download Revenue ($)"], simulation["Number of Reviews"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Total Download Revenue ($)"], adventure["Number of Reviews"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Total Download Revenue ($)"], puzzle["Number of Reviews"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Total Download Revenue ($)"], card["Number of Reviews"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Total Download Revenue ($)"], casual["Number of Reviews"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Total Download Revenue ($)"], strategy["Number of Reviews"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Total Download Revenue ($)"], roleplay["Number of Reviews"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Total Download Revenue ($)"], word["Number of Reviews"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Total Download Revenue ($)")
plt.ylabel("Number of Reviews")
plt.title("Revenue Vs. Number of Reviews (All Games)")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.savefig("Images/RevenueVsReviews.png", bbox_inches="tight")

# %%
#Create DF withOUT Minecraft
no_mine_df = games_df.copy()
#no_mine_df = no_mine_df

no_mine_df.drop(no_mine_df.index[50], inplace=True)


#####
##Scatter plots based on 'no_mine_df'###

#showing the data with a scatter plot

arcade_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_ARCADE"]
sports_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_SPORTS"]
racing_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_RACING"]
music_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_MUSIC"]
educational_nm = no_mine_df.loc[no_mine_df["Game Category"]== "GAME_EDUCATIONAL"]
board_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_BOARD"]
casino_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_CASINO"]
action_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_ACTION"]
trivia_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_TRIVIA"]
simulation_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_SIMULATION"]
adventure_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_ADVENTURE"]
puzzle_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_PUZZLE"]
card_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_CARD"]
casual_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_CASUAL"]
strategy_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_STRATEGY"]                       
roleplay_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_ROLE_PLAYING"]
word_nm = no_mine_df.loc[no_mine_df["Game Category"]=="GAME_WORD"]

# %%
####Price Vs Reviews Scatter Plot (WithOUT Minecraft)
plt.figure(figsize=(20,12))
plt.rcParams['axes.facecolor'] = '#eaeaf2'
plt.grid(color='w')
arcade_nm5 = plt.scatter(arcade_nm["Price"], arcade_nm["Number of Reviews"], s=200, marker="o", label="Arcade Games", color="red", alpha=0.75)
sports_nm5 = plt.scatter(sports_nm["Price"], sports_nm["Number of Reviews"], s=200, marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_nm5 = plt.scatter(racing_nm["Price"], racing_nm["Number of Reviews"], s=200, marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_nm5 = plt.scatter(music_nm["Price"], music_nm["Number of Reviews"], s=200, marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_nm5 = plt.scatter(educational_nm["Price"], educational_nm["Number of Reviews"], s=200, marker="o", 
                        label="Educational Games", color="darkgreen", alpha=0.75)
board_nm5 = plt.scatter(board_nm["Price"], board_nm["Number of Reviews"], s=200, marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_nm5 = plt.scatter(casino_nm["Price"], casino_nm["Number of Reviews"], s=200, marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_nm5 = plt.scatter(action_nm["Price"], action_nm["Number of Reviews"], s=200, marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_nm5 = plt.scatter(trivia_nm["Price"], trivia_nm["Number of Reviews"], s=200, marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_nm5 = plt.scatter(simulation_nm["Price"], simulation_nm["Number of Reviews"], s=200, marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_nm5 = plt.scatter(adventure_nm["Price"], adventure_nm["Number of Reviews"], s=200, marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_nm5 = plt.scatter(puzzle_nm["Price"], puzzle_nm["Number of Reviews"], s=200, marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_nm5 = plt.scatter(card_nm["Price"], card_nm["Number of Reviews"], s=200, marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_nm5 = plt.scatter(casual_nm["Price"], casual_nm["Number of Reviews"], s=200, marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_nm5 = plt.scatter(strategy_nm["Price"], strategy_nm["Number of Reviews"], s=200, marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_nm5 = plt.scatter(roleplay_nm["Price"], roleplay_nm["Number of Reviews"], s=200, marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_nm5 = plt.scatter(word_nm["Price"], word_nm["Number of Reviews"], s=200, marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Price", fontsize=30)
plt.ylabel("Number of Reviews", fontsize=30)
plt.title("Price Vs Reviews (No Minecraft)",  fontsize=30)
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.savefig("Images/PriceVsReviewsNM.png", bbox_inches="tight")

# %%
####Downloads Vs Revenue Scatter Plot (WithOUT Minecraft)
plt.figure(figsize=(20,12))
plt.rcParams['axes.facecolor'] = '#eaeaf2'
plt.grid(color='w')
plt.rcParams['axes.axisbelow'] = True

arcade_nm1 = plt.scatter(arcade_nm["Number of Installs"], arcade_nm["Total Download Revenue ($)"],s=200, marker="o",
                        label="Arcade Games", color="red", alpha=0.75)
sports_nm1 = plt.scatter(sports_nm["Number of Installs"], sports_nm["Total Download Revenue ($)"],s=200, marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_nm1 = plt.scatter(racing_nm["Number of Installs"], racing_nm["Total Download Revenue ($)"],s=200, marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_nm1 = plt.scatter(music_nm["Number of Installs"], music_nm["Total Download Revenue ($)"],s=200, marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_nm1 = plt.scatter(educational_nm["Number of Installs"], educational_nm["Total Download Revenue ($)"],s=200,
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_nm1 = plt.scatter(board_nm["Number of Installs"], board_nm["Total Download Revenue ($)"],s=200, marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_nm1 = plt.scatter(casino_nm["Number of Installs"], casino_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_nm1 = plt.scatter(action_nm["Number of Installs"], action_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_nm1 = plt.scatter(trivia_nm["Number of Installs"], trivia_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_nm1 = plt.scatter(simulation_nm["Number of Installs"], simulation_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_nm1 = plt.scatter(adventure_nm["Number of Installs"], adventure_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_nm1 = plt.scatter(puzzle_nm["Number of Installs"], puzzle_nm["Total Download Revenue ($)"], s=200, marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_nm1 = plt.scatter(card_nm["Number of Installs"], card_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_nm1 = plt.scatter(casual_nm["Number of Installs"], casual_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_nm1 = plt.scatter(strategy_nm["Number of Installs"], strategy_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_nm1 = plt.scatter(roleplay_nm["Number of Installs"], roleplay_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_nm1 = plt.scatter(word_nm["Number of Installs"], word_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Number of Installs", fontsize=30)
plt.ylabel("Total Download Revenue ($10 Millions)", fontsize=30)
plt.title("Installs Vs Revenue (No Minecraft)", fontsize=30)
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.savefig("Images/InstallsVsRevenueNM.png", bbox_inches="tight")

# %%
####Game Score Vs Revenue Scatter Plot (WithOUT Minecraft)
plt.figure(figsize=(20,12))
plt.rcParams['axes.facecolor'] = '#eaeaf2'
plt.grid(color='w')
arcade_nm = plt.scatter(arcade_nm["Game Score"], arcade_nm["Total Download Revenue ($)"], s=200, marker="o", label="Arcade Games", color="red", alpha=0.75)
sports_nm = plt.scatter(sports_nm["Game Score"], sports_nm["Total Download Revenue ($)"], s=200, marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_nm = plt.scatter(racing_nm["Game Score"], racing_nm["Total Download Revenue ($)"], s=200, marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_nm = plt.scatter(music_nm["Game Score"], music_nm["Total Download Revenue ($)"], s=200, marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_nm = plt.scatter(educational_nm["Game Score"], educational_nm["Total Download Revenue ($)"], s=200, marker="o", 
                        label="Educational Games", color="darkgreen", alpha=0.75)
board_nm = plt.scatter(board_nm["Game Score"], board_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_nm = plt.scatter(casino_nm["Game Score"], casino_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_nm = plt.scatter(action_nm["Game Score"], action_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_nm = plt.scatter(trivia_nm["Game Score"], trivia_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_nm = plt.scatter(simulation_nm["Game Score"], simulation_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_nm = plt.scatter(adventure_nm["Game Score"], adventure_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_nm = plt.scatter(puzzle_nm["Game Score"], puzzle_nm["Total Download Revenue ($)"], s=200, marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_nm = plt.scatter(card_nm["Game Score"], card_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_nm = plt.scatter(casual_nm["Game Score"], casual_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_nm = plt.scatter(strategy_nm["Game Score"], strategy_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_nm = plt.scatter(roleplay_nm["Game Score"], roleplay_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_nm = plt.scatter(word_nm["Game Score"], word_nm["Total Download Revenue ($)"], s=200, marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Game Score", fontsize=30)
plt.ylabel("Total Download Revenue ($10 Millions)", fontsize=30)
plt.title("Game Score Vs Revenue (No Minecraft)",  fontsize=30)
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.savefig("Images/GameScoreVsRevenueNM.png", bbox_inches="tight")
