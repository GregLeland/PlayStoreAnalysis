# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np
import requests
import csv
import play_scraper as gp
from pprint import pprint

# %%
categories = ["GAME_ACTION", "GAME_ADVENTURE",
              "GAME_ARCADE", "GAME_BOARD", 
              "GAME_CARD", "GAME_CASINO",
              "GAME_CASUAL", "GAME_EDUCATIONAL",
              "GAME_MUSIC",  "GAME_PUZZLE",
              "GAME_RACING", "GAME_ROLE_PLAYING",
              "GAME_SIMULATION", "GAME_SPORTS",
              "GAME_STRATEGY", "GAME_TRIVIA"]

game_category = []
game_list = []
for x in categories:
    paid_games = gp.collection(collection='TOP_PAID', category=x, results=25)
    #print(f' --')
    #print(f'   *** Getting information for games in the {x} category. ***')
    #print(f' --')
    for j in range (0, 25):
        game_info = paid_games[j]['app_id']
        title = paid_games[j]['title']
        game_category.append(x)
        game_list.append(game_info)
        #print(f'{j}. Getting the Game ID for {title}.')

# %%
#print(len(game_list))

# %%
i = 0
game_titles = []
game_scores = []
game_reviews = []
game_prices = []
game_installs = []
game_developers = []
game_urls = []

for game in game_list:
    game_details = gp.details(game_list[i])
    title_info = game_details['title']
    game_titles.append(title_info)
    game_scores.append(game_details['score'])
    game_reviews.append(game_details['reviews'])
    game_prices.append(game_details['price'])
    game_installs.append(game_details['installs'])
    game_developers.append(game_details['developer'])
    game_urls.append(game_details['url'])
    #print(f'Getting information for {title_info}.')
    i += 1
print(f'All done! The loop processed a total of {len(game_titles)} results.')
# Out:
# All done! The loop processed a total of 400 results.

# %%
games_master = {
    "Game Title": game_titles,
    "Game Category": game_category,
    "Game Score": game_scores,
    "Number of Reviews": game_reviews,
    "Price": game_prices,
    "Number of Installs": game_installs,
    "Developer": game_developers,
    "Play Store URL": game_urls
    
}
games_df = pd.DataFrame(games_master)
games_df.head(20)
# Out:
#                                           Game Title Game Category Game Score  \
# 0                      Grand Theft Auto: San Andreas   GAME_ACTION        4.3
# 1                            Five Nights at Freddy's   GAME_ACTION        4.6
# 2                        Five Nights at Freddy's: SL   GAME_ACTION        4.5
# 3                                      Hitman Sniper   GAME_ACTION        4.6
# 4                          Assassin's Creed Identity   GAME_ACTION        3.8
# 5                          Five Nights at Freddy's 4   GAME_ACTION        4.6
# 6                                     Space Marshals   GAME_ACTION        4.8
# 7                               Grand Theft Auto III   GAME_ACTION        4.0
# 8                     Call of Duty:Black Ops Zombies   GAME_ACTION        4.2
# 9             truTV Impractical Jokers Wheel of Doom   GAME_ACTION        4.3
# 10                            Teen Titans GO Figure!   GAME_ACTION        4.5
# 11                                        Real Steel   GAME_ACTION        4.1
# 12                         Five Nights at Freddy's 3   GAME_ACTION        4.7
# 13                                          Downwell   GAME_ACTION        4.7
# 14                              Bloons Supermonkey 2   GAME_ACTION        4.6
# 15                        Bully: Anniversary Edition   GAME_ACTION        4.5
# 16                        LEGO ® Marvel Super Heroes   GAME_ACTION        4.1
# 17                            LEGO® Star Wars™:  TCS   GAME_ACTION        3.7
# 18  Shadow of Death: Stickman Fighting - Dark Knight   GAME_ACTION        4.6
# 19                               GTA: Chinatown Wars   GAME_ACTION        4.3
#
#     Number of Reviews  Price Number of Installs  \
# 0              388018  $6.99         1,000,000+
# 1              103831  $2.99         1,000,000+
# 2               17376  $2.99           100,000+
# 3              592375  $0.99        10,000,000+
# 4               50035  $1.99           500,000+
# 5               21580  $2.99           100,000+
# 6                7950  $0.99            50,000+
# 7               96677  $4.99         1,000,000+
# 8               14008  $6.99           100,000+
# 9                 173  $2.99             5,000+
# 10               4582  $3.99            50,000+
# 11              26204  $0.99           500,000+
# 12              28213  $2.99           100,000+
# 13               4562  $2.99           100,000+
# 14              15586  $0.99           500,000+
# 15              13498  $6.99           100,000+
# 16              16464  $4.99           100,000+
# 17              16811  $6.99           100,000+
# 18              59077  $0.99         1,000,000+
# 19              25399  $4.99           100,000+
#
#                                           Developer  \
# 0                                    Rockstar Games
# 1                                     Scott Cawthon
# 2                                     Scott Cawthon
# 3                                   SQUARE ENIX Ltd
# 4                             Ubisoft Entertainment
# 5                                     Scott Cawthon
# 6                                         Pixelbite
# 7                                    Rockstar Games
# 8                       Activision Publishing, Inc.
# 9                                      truTVnetwork
# 10                                  Cartoon Network
# 11  Reliance Big Entertainment (UK) Private Limited
# 12                                    Scott Cawthon
# 13                                  DevolverDigital
# 14                                       ninja kiwi
# 15                                   Rockstar Games
# 16           Warner Bros. International Enterprises
# 17           Warner Bros. International Enterprises
# 18                               Zonmob Game Studio
# 19                                   Rockstar Games
#
#                                        Play Store URL
# 0   https://play.google.com/store/apps/details?id=...
# 1   https://play.google.com/store/apps/details?id=...
# 2   https://play.google.com/store/apps/details?id=...
# 3   https://play.google.com/store/apps/details?id=...
# 4   https://play.google.com/store/apps/details?id=...
# 5   https://play.google.com/store/apps/details?id=...
# 6   https://play.google.com/store/apps/details?id=...
# 7   https://play.google.com/store/apps/details?id=...
# 8   https://play.google.com/store/apps/details?id=...
# 9   https://play.google.com/store/apps/details?id=...
# 10  https://play.google.com/store/apps/details?id=...
# 11  https://play.google.com/store/apps/details?id=...
# 12  https://play.google.com/store/apps/details?id=...
# 13  https://play.google.com/store/apps/details?id=...
# 14  https://play.google.com/store/apps/details?id=...
# 15  https://play.google.com/store/apps/details?id=...
# 16  https://play.google.com/store/apps/details?id=...
# 17  https://play.google.com/store/apps/details?id=...
# 18  https://play.google.com/store/apps/details?id=...
# 19  https://play.google.com/store/apps/details?id=...

# %%
games_df['Number of Installs'] = games_df['Number of Installs'].str.replace('+', '')
games_df.head(50)
# Out:
#                                           Game Title   Game Category  \
# 0                      Grand Theft Auto: San Andreas     GAME_ACTION
# 1                            Five Nights at Freddy's     GAME_ACTION
# 2                        Five Nights at Freddy's: SL     GAME_ACTION
# 3                                      Hitman Sniper     GAME_ACTION
# 4                          Assassin's Creed Identity     GAME_ACTION
# 5                          Five Nights at Freddy's 4     GAME_ACTION
# 6                                     Space Marshals     GAME_ACTION
# 7                               Grand Theft Auto III     GAME_ACTION
# 8                     Call of Duty:Black Ops Zombies     GAME_ACTION
# 9             truTV Impractical Jokers Wheel of Doom     GAME_ACTION
# 10                            Teen Titans GO Figure!     GAME_ACTION
# 11                                        Real Steel     GAME_ACTION
# 12                         Five Nights at Freddy's 3     GAME_ACTION
# 13                                          Downwell     GAME_ACTION
# 14                              Bloons Supermonkey 2     GAME_ACTION
# 15                        Bully: Anniversary Edition     GAME_ACTION
# 16                        LEGO ® Marvel Super Heroes     GAME_ACTION
# 17                            LEGO® Star Wars™:  TCS     GAME_ACTION
# 18  Shadow of Death: Stickman Fighting - Dark Knight     GAME_ACTION
# 19                               GTA: Chinatown Wars     GAME_ACTION
# 20                               Battle of Vicksburg     GAME_ACTION
# 21                        PPSSPP Gold - PSP emulator     GAME_ACTION
# 22                                 Zombieville USA 2     GAME_ACTION
# 23                              Goat Simulator GoatZ     GAME_ACTION
# 24                                       Titan Quest     GAME_ACTION
# 25                                   Alien: Blackout  GAME_ADVENTURE
# 26                                         Terraria.  GAME_ADVENTURE
# 27                         Bendy and the Ink Machine  GAME_ADVENTURE
# 28                              THE GALAXY: SURVIVOR  GAME_ADVENTURE
# 29                      60 Seconds! Atomic Adventure  GAME_ADVENTURE
# 30                      Don't Starve: Pocket Edition  GAME_ADVENTURE
# 31                             LEGO® Jurassic World™  GAME_ADVENTURE
# 32                                    Angry Neighbor  GAME_ADVENTURE
# 33                           Octodad: Dadliest Catch  GAME_ADVENTURE
# 34                                    Portal Knights  GAME_ADVENTURE
# 35                                    Thickety Creek  GAME_ADVENTURE
# 36  Sonic Runners Adventure - Fast Action Platformer  GAME_ADVENTURE
# 37                                        Crashlands  GAME_ADVENTURE
# 38                                Castle of Illusion  GAME_ADVENTURE
# 39                           Draw a Stickman: EPIC 2  GAME_ADVENTURE
# 40                                   Survivalcraft 2  GAME_ADVENTURE
# 41                                  Rusty Lake Hotel  GAME_ADVENTURE
# 42                         Live or Die: Survival Pro  GAME_ADVENTURE
# 43                                 Rusty Lake: Roots  GAME_ADVENTURE
# 44                      LEGO Harry Potter: Years 1-4  GAME_ADVENTURE
# 45                         GTA: Liberty City Stories  GAME_ADVENTURE
# 46                      FINAL FANTASY IX for Android  GAME_ADVENTURE
# 47                                           CHUCHEL  GAME_ADVENTURE
# 48                         Don't Starve: Shipwrecked  GAME_ADVENTURE
# 49                                             LIMBO  GAME_ADVENTURE
#
#    Game Score  Number of Reviews   Price Number of Installs  \
# 0         4.3             388018   $6.99          1,000,000
# 1         4.6             103831   $2.99          1,000,000
# 2         4.5              17376   $2.99            100,000
# 3         4.6             592375   $0.99         10,000,000
# 4         3.8              50035   $1.99            500,000
# 5         4.6              21580   $2.99            100,000
# 6         4.8               7950   $0.99             50,000
# 7         4.0              96677   $4.99          1,000,000
# 8         4.2              14008   $6.99            100,000
# 9         4.3                173   $2.99              5,000
# 10        4.5               4582   $3.99             50,000
# 11        4.1              26204   $0.99            500,000
# 12        4.7              28213   $2.99            100,000
# 13        4.7               4562   $2.99            100,000
# 14        4.6              15586   $0.99            500,000
# 15        4.5              13498   $6.99            100,000
# 16        4.1              16464   $4.99            100,000
# 17        3.7              16811   $6.99            100,000
# 18        4.6              59077   $0.99          1,000,000
# 19        4.3              25399   $4.99            100,000
# 20        4.1                471   $0.99              5,000
# 21        4.3              11154   $4.99            100,000
# 22        4.6               1394   $0.99             50,000
# 23        4.1               7187   $4.99            100,000
# 24        4.5              11820   $7.99             50,000
# 25        4.0                493   $4.99              5,000
# 26        4.3             231449   $4.99          1,000,000
# 27        4.2               1094   $6.99             10,000
# 28        4.3               3315   $1.49             10,000
# 29        3.9               5736   $3.99            100,000
# 30        4.4              22332   $4.99            500,000
# 31        4.4              13705   $4.99            100,000
# 32        4.4               2898   $1.49             50,000
# 33        4.4               4426   $4.99            100,000
# 34        4.3               5604   $4.99             50,000
# 35        4.5                 78   $2.99              1,000
# 36        4.5               4531   $2.99             50,000
# 37        4.8              13221   $6.99            100,000
# 38        4.2              36586   $4.99            500,000
# 39        4.4               5444   $1.99            100,000
# 40        4.5               5425   $3.99            100,000
# 41        4.8               9012   $1.99            100,000
# 42        4.2              19354   $0.99          1,000,000
# 43        4.9               8182   $2.99            100,000
# 44        4.1               4927   $4.99            100,000
# 45        4.4              10243   $6.99             50,000
# 46        4.4               7411  $20.99            100,000
# 47        4.3                600   $4.99             10,000
# 48        4.1               2574   $4.99             50,000
# 49        4.7              43288   $4.99            500,000
#
#                                           Developer  \
# 0                                    Rockstar Games
# 1                                     Scott Cawthon
# 2                                     Scott Cawthon
# 3                                   SQUARE ENIX Ltd
# 4                             Ubisoft Entertainment
# 5                                     Scott Cawthon
# 6                                         Pixelbite
# 7                                    Rockstar Games
# 8                       Activision Publishing, Inc.
# 9                                      truTVnetwork
# 10                                  Cartoon Network
# 11  Reliance Big Entertainment (UK) Private Limited
# 12                                    Scott Cawthon
# 13                                  DevolverDigital
# 14                                       ninja kiwi
# 15                                   Rockstar Games
# 16           Warner Bros. International Enterprises
# 17           Warner Bros. International Enterprises
# 18                               Zonmob Game Studio
# 19                                   Rockstar Games
# 20                                 Thorium Game Lab
# 21                                   Henrik Rydgård
# 22                                      Mika Mobile
# 23                          Coffee Stain Publishing
# 24                                       HandyGames
# 25                                           D3 Go!
# 26                                    505 Games Srl
# 27                                Joey Drew Studios
# 28                                  Invictus Studio
# 29                                  Robot Gentleman
# 30                          Klei Entertainment Inc.
# 31           Warner Bros. International Enterprises
# 32                                  Invictus Studio
# 33                                     Young Horses
# 34                                    505 Games Srl
# 35                            Fire Maple Games, LLC
# 36                                         Gameloft
# 37                         Butterscotch Shenanigans
# 38                                           Disney
# 39                                         Hitcents
# 40                                Candy Rufus Games
# 41                                       Rusty Lake
# 42                          PRIDEGAMESSTUDIO OU PLC
# 43                                       Rusty Lake
# 44           Warner Bros. International Enterprises
# 45                                   Rockstar Games
# 46                             SQUARE ENIX Co.,Ltd.
# 47                                   Amanita Design
# 48                          Klei Entertainment Inc.
# 49                                         Playdead
#
#                                        Play Store URL
# 0   https://play.google.com/store/apps/details?id=...
# 1   https://play.google.com/store/apps/details?id=...
# 2   https://play.google.com/store/apps/details?id=...
# 3   https://play.google.com/store/apps/details?id=...
# 4   https://play.google.com/store/apps/details?id=...
# 5   https://play.google.com/store/apps/details?id=...
# 6   https://play.google.com/store/apps/details?id=...
# 7   https://play.google.com/store/apps/details?id=...
# 8   https://play.google.com/store/apps/details?id=...
# 9   https://play.google.com/store/apps/details?id=...
# 10  https://play.google.com/store/apps/details?id=...
# 11  https://play.google.com/store/apps/details?id=...
# 12  https://play.google.com/store/apps/details?id=...
# 13  https://play.google.com/store/apps/details?id=...
# 14  https://play.google.com/store/apps/details?id=...
# 15  https://play.google.com/store/apps/details?id=...
# 16  https://play.google.com/store/apps/details?id=...
# 17  https://play.google.com/store/apps/details?id=...
# 18  https://play.google.com/store/apps/details?id=...
# 19  https://play.google.com/store/apps/details?id=...
# 20  https://play.google.com/store/apps/details?id=...
# 21  https://play.google.com/store/apps/details?id=...
# 22  https://play.google.com/store/apps/details?id=...
# 23  https://play.google.com/store/apps/details?id=...
# 24  https://play.google.com/store/apps/details?id=...
# 25  https://play.google.com/store/apps/details?id=...
# 26  https://play.google.com/store/apps/details?id=...
# 27  https://play.google.com/store/apps/details?id=...
# 28  https://play.google.com/store/apps/details?id=...
# 29  https://play.google.com/store/apps/details?id=...
# 30  https://play.google.com/store/apps/details?id=...
# 31  https://play.google.com/store/apps/details?id=...
# 32  https://play.google.com/store/apps/details?id=...
# 33  https://play.google.com/store/apps/details?id=...
# 34  https://play.google.com/store/apps/details?id=...
# 35  https://play.google.com/store/apps/details?id=...
# 36  https://play.google.com/store/apps/details?id=...
# 37  https://play.google.com/store/apps/details?id=...
# 38  https://play.google.com/store/apps/details?id=...
# 39  https://play.google.com/store/apps/details?id=...
# 40  https://play.google.com/store/apps/details?id=...
# 41  https://play.google.com/store/apps/details?id=...
# 42  https://play.google.com/store/apps/details?id=...
# 43  https://play.google.com/store/apps/details?id=...
# 44  https://play.google.com/store/apps/details?id=...
# 45  https://play.google.com/store/apps/details?id=...
# 46  https://play.google.com/store/apps/details?id=...
# 47  https://play.google.com/store/apps/details?id=...
# 48  https://play.google.com/store/apps/details?id=...
# 49  https://play.google.com/store/apps/details?id=...

# %%
games_df['Game Category'].value_counts()
# Out:
# GAME_SIMULATION      25
# GAME_BOARD           25
# GAME_MUSIC           25
# GAME_STRATEGY        25
# GAME_PUZZLE          25
# GAME_ADVENTURE       25
# GAME_TRIVIA          25
# GAME_CASINO          25
# GAME_CASUAL          25
# GAME_ROLE_PLAYING    25
# GAME_ACTION          25
# GAME_SPORTS          25
# GAME_RACING          25
# GAME_ARCADE          25
# GAME_CARD            25
# GAME_EDUCATIONAL     25
# Name: Game Category, dtype: int64

# %%
#Get rid of dollar sign for easy data manipulation
games_df["Price"] = games_df["Price"].str.replace('$', '')
#convert column data type to float
games_df["Price"] =(games_df["Price"]).astype(float)

# %%
games_df["Number of Installs"] = games_df["Number of Installs"].str.replace(',', '')
#games_df["Number of Installs"] =

# %%
games_df["Revenue"] = games_df["Price"] * games_df["Number of Installs"]
games_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# TypeError: can't multiply sequence by non-int of type 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-b5c7be81f973> in <module>()
# ----> 1 games_df["Revenue"] = games_df["Price"] * games_df["Number of Installs"]
#       2 games_df.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(left, right)
#    1067             rvalues = rvalues.values
#    1068
# -> 1069         result = safe_na_op(lvalues, rvalues)
#    1070         return construct_result(left, result,
#    1071                                 index=left.index, name=res_name, dtype=None)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#    1031         try:
#    1032             with np.errstate(all='ignore'):
# -> 1033                 return na_op(lvalues, rvalues)
#    1034         except Exception:
#    1035             if is_object_dtype(lvalues):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1016                 result = np.empty(x.size, dtype=dtype)
#    1017                 mask = notna(x) & notna(y)
# -> 1018                 result[mask] = op(x[mask], com._values_from_object(y[mask]))
#    1019             else:
#    1020                 assert isinstance(x, np.ndarray)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
games_df['Revenue'].dtype

# %%
games_df.sort_values(by='Revenue', ascending=False)

# %%
#Modify DF to be sorted by revenue column
games_df = games_df.sort_values(by='Revenue', ascending=False)
games_df.head(50)

# %%
#Reset index to provide index numbers based on revenue
games_df = games_df.reset_index(drop=True)
games_df.head(50)
#Prelim conclusions: Top 50 games by revenue all made at least 995,000. 
#top 55 made at least 990,000.
#There are many games out there, meaning that the vast majority do not make..
#..the kind of revenue our 'Upper Mgmt' would consider to be consequential.

#Only 6 of the top 50 games have user ratings below 4.0, demonstrating..
#...that the 'game score' is a very important metric of a games impending..
#...success/failure. The lowest rated game in the 'Top 50 by revenue'..
#...has a game score of 3.3 and revenue of $1.6MM. This game is an anomaly. 
#To ensure that our project is approved, our beta test ratings would need..
#..to be at least 4.0.

# %%
#Top 50 by revenue truncated df 
top_revenue = pd.DataFrame(games_df.head(50))
#check new DF data types
top_revenue.dtypes
#convert column data type to float
top_revenue['Game Score'] = top_revenue['Game Score'].astype(float)
#check new DF data types
top_revenue.dtypes
#get average game rating in top 50 revenue df
top_revenue['Game Score'].mean()

#Prelim concl: Our beta testers would need us to give game ratings..
#..of at least 4.0. anything above 4.4 would be a very encouraging sign..
#...of the games likely success.

# %%
top_revenue['Price'].mean()
#Average price of top rev is $5.32 reflecting gamers appetite for apps..
#..that are more expensive than average play store paid app prices...
####[missing avg paid app price stat]#####3

top_revenue['Number of Installs'].mean()
#Average number of installs is close to a million (996,000). Minimum..
#..target downloads for our project would need to be at least 500,000,..
#..since the lowest num of installs in the DF is 500,000.

# %%
top_revenue['Game Category'].value_counts()
#The top 3 game sub categories are 'strategy' (7), 'arcade'(6) and..
#..'adventure'(6) games. Our game has much higher chance of success if..
#..it falls within one of these three sub-cats.
