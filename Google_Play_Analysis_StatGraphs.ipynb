# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
games_df = pd.read_csv("Games_df.csv")

# %%
games_df.dtypes
# Out:
# Unnamed: 0                      int64
# Game Title                     object
# Game Category                  object
# Game Score                    float64
# Number of Reviews               int64
# Price                         float64
# Number of Installs              int64
# Developer                      object
# Play Store URL                 object
# Total Download Revenue ($)    float64
# dtype: object

# %%
games_df
# Out:
#      Unnamed: 0                                        Game Title  \
# 0             0                     Grand Theft Auto: San Andreas
# 1             1                           Five Nights at Freddy's
# 2             2                       Five Nights at Freddy's: SL
# 3             3                                     Hitman Sniper
# 4             4                         Assassin's Creed Identity
# 5             5                         Five Nights at Freddy's 4
# 6             6                                    Space Marshals
# 7             7                    Call of Duty:Black Ops Zombies
# 8             8                              Grand Theft Auto III
# 9             9            truTV Impractical Jokers Wheel of Doom
# 10           10                            Teen Titans GO Figure!
# 11           11                                        Real Steel
# 12           12                         Five Nights at Freddy's 3
# 13           13                                          Downwell
# 14           14                              Bloons Supermonkey 2
# 15           15                        Bully: Anniversary Edition
# 16           16                            LEGO® Star Wars™:  TCS
# 17           17                        LEGO ® Marvel Super Heroes
# 18           18  Shadow of Death: Stickman Fighting - Dark Knight
# 19           19                               GTA: Chinatown Wars
# 20           20                               Battle of Vicksburg
# 21           21                        PPSSPP Gold - PSP emulator
# 22           22                                 Zombieville USA 2
# 23           23                              Goat Simulator GoatZ
# 24           24                                       Titan Quest
# 25           25                                   Alien: Blackout
# 26           26                                         Terraria.
# 27           27                         Bendy and the Ink Machine
# 28           28                              THE GALAXY: SURVIVOR
# 29           29                      60 Seconds! Atomic Adventure
# ..          ...                                               ...
# 370         370                          Papa's Cupcakeria To Go!
# 371         371                        Warhammer 40,000: Regicide
# 372         372                    Teeny Titans - Teen Titans Go!
# 373         373                    Rebuild 3: Gangs of Deadsville
# 374         374                       Organ Trail: Director's Cut
# 375         375                             Trivia Crack (No Ads)
# 376         376                                           Sporcle
# 377         377                                          BLeBRiTY
# 378         378                            The Jackbox Party Pack
# 379         379                          The Jackbox Party Pack 5
# 380         380                              Bible Bowl Prep 2019
# 381         381                          The Jackbox Party Pack 3
# 382         382                            The 7 Second Challenge
# 383         383                          The Jackbox Party Pack 2
# 384         384                               The Black Card Game
# 385         385                    4 Player Reactor (Multiplayer)
# 386         386                                    Pointless Quiz
# 387         387                          The Jackbox Party Pack 4
# 388         388    Quizoid Pro: Category Trivia with 5 Game modes
# 389         389                       Penny Dell Jumbo Crosswords
# 390         390                          Einstein™ Brain Training
# 391         391                                   Text Twist 2019
# 392         392                            Lets get wasted 18+ ;)
# 393         393                   SHAPE - the picture trivia quiz
# 394         394            QuizBash - Party Games in Your Pocket!
# 395         395                     The Ultimate Trivia Challenge
# 396         396                             Quizio PRO: Quiz game
# 397         397                               Wer Wird Millionär?
# 398         398                      The Office Fan Quiz (No Ads)
# 399         399                        HQ Trivia Helper Unlimited
#
#       Game Category  Game Score  Number of Reviews  Price  Number of Installs  \
# 0       GAME_ACTION         4.3             387897   6.99             1000000
# 1       GAME_ACTION         4.6             103826   2.99             1000000
# 2       GAME_ACTION         4.5              17369   2.99              100000
# 3       GAME_ACTION         4.6             592148   0.99            10000000
# 4       GAME_ACTION         3.8              50021   1.99              500000
# 5       GAME_ACTION         4.6              21580   2.99              100000
# 6       GAME_ACTION         4.8               7931   0.99               50000
# 7       GAME_ACTION         4.2              14006   6.99              100000
# 8       GAME_ACTION         4.0              96670   4.99             1000000
# 9       GAME_ACTION         4.3                170   2.99                5000
# 10      GAME_ACTION         4.5               4578   3.99               50000
# 11      GAME_ACTION         4.1              26201   0.99              500000
# 12      GAME_ACTION         4.7              28214   2.99              100000
# 13      GAME_ACTION         4.7               4561   2.99              100000
# 14      GAME_ACTION         4.6              15580   0.99              500000
# 15      GAME_ACTION         4.5              13488   6.99              100000
# 16      GAME_ACTION         3.7              16810   6.99              100000
# 17      GAME_ACTION         4.1              16461   4.99              100000
# 18      GAME_ACTION         4.6              59018   0.99             1000000
# 19      GAME_ACTION         4.3              25398   4.99              100000
# 20      GAME_ACTION         4.1                468   0.99                5000
# 21      GAME_ACTION         4.3              11153   4.99              100000
# 22      GAME_ACTION         4.6               1394   0.99               50000
# 23      GAME_ACTION         4.1               7187   4.99              100000
# 24      GAME_ACTION         4.5              11807   7.99               50000
# 25   GAME_ADVENTURE         4.0                468   4.99                5000
# 26   GAME_ADVENTURE         4.3             231424   4.99             1000000
# 27   GAME_ADVENTURE         4.2               1090   6.99               10000
# 28   GAME_ADVENTURE         4.3               3300   1.49               10000
# 29   GAME_ADVENTURE         3.9               5733   3.99              100000
# ..              ...         ...                ...    ...                 ...
# 370   GAME_STRATEGY         4.5               2140   1.99               50000
# 371   GAME_STRATEGY         4.2               4174   0.99               50000
# 372   GAME_STRATEGY         4.6              21671   3.99              100000
# 373   GAME_STRATEGY         4.6               4739   4.99               50000
# 374   GAME_STRATEGY         4.4               6420   2.99              100000
# 375     GAME_TRIVIA         4.5              61210   5.99              500000
# 376     GAME_TRIVIA         3.5               1507   1.99               50000
# 377     GAME_TRIVIA         4.3                459   0.99               10000
# 378     GAME_TRIVIA         4.3                 31  24.99                1000
# 379     GAME_TRIVIA         3.5                  2  29.99                 500
# 380     GAME_TRIVIA         NaN                  0   0.99                  50
# 381     GAME_TRIVIA         3.7                  9  24.99                1000
# 382     GAME_TRIVIA         4.1               1068   1.99               10000
# 383     GAME_TRIVIA         3.9                 11  24.99                1000
# 384     GAME_TRIVIA         1.6                  8   0.99                 100
# 385     GAME_TRIVIA         4.7               4375   2.49               50000
# 386     GAME_TRIVIA         3.9               4368   1.99               50000
# 387     GAME_TRIVIA         4.0                  4  24.99                1000
# 388     GAME_TRIVIA         4.6               1032   2.99               10000
# 389     GAME_TRIVIA         4.9                 22   9.99                 100
# 390     GAME_TRIVIA         4.2               1988   2.99               10000
# 391     GAME_TRIVIA         1.8                  5   2.49                  10
# 392     GAME_TRIVIA         5.0                  5   0.99                   5
# 393     GAME_TRIVIA         NaN                  0   1.49                  10
# 394     GAME_TRIVIA         5.0                 11   1.49                 100
# 395     GAME_TRIVIA         NaN                  0   4.99                  10
# 396     GAME_TRIVIA         4.0               1709   0.99              100000
# 397     GAME_TRIVIA         3.9               1249   2.49               50000
top_games = games_df.sort_values(by='Revenue', ascending=False)

# %%
new_df = top_games.iloc[2:]

# %%
new_df
# Out:
#      Unnamed: 0                              Game Title      Game Category  \
# 0             0           Grand Theft Auto: San Andreas        GAME_ACTION
# 8             8                    Grand Theft Auto III        GAME_ACTION
# 52           52             Grand Theft Auto: Vice City        GAME_ARCADE
# 26           26                               Terraria.     GAME_ADVENTURE
# 303         303                          Goat Simulator    GAME_SIMULATION
# 65           65                                 Worms 3        GAME_ARCADE
# 253         253              Need for Speed Most Wanted        GAME_RACING
# 232         232                         Monument Valley        GAME_PUZZLE
# 61           61          SuperRetro16 ( SNES Emulator )        GAME_ARCADE
# 375         375                   Trivia Crack (No Ads)        GAME_TRIVIA
# 103         103              Card Wars - Adventure Time          GAME_CARD
# 352         352                             Bloons TD 5      GAME_STRATEGY
# 1             1                 Five Nights at Freddy's        GAME_ACTION
# 350         350                             Bloons TD 6      GAME_STRATEGY
# 327         327                  NBA JAM  by EA SPORTS™        GAME_SPORTS
# 81           81                           Catan Classic         GAME_BOARD
# 38           38                      Castle of Illusion     GAME_ADVENTURE
# 30           30            Don't Starve: Pocket Edition     GAME_ADVENTURE
# 302         302                    Farming Simulator 18    GAME_SIMULATION
# 307         307      Infinite Flight - Flight Simulator    GAME_SIMULATION
# 46           46            FINAL FANTASY IX for Android     GAME_ADVENTURE
# 233         233                          The Room Three        GAME_PUZZLE
# 239         239                       Where's My Water?        GAME_PUZZLE
# 51           51                           Geometry Dash        GAME_ARCADE
# 326         326                              True Skate        GAME_SPORTS
# 230         230                            The Room Two        GAME_PUZZLE
# 54           54                       ePSXe for Android        GAME_ARCADE
# 282         282                       FINAL FANTASY VII  GAME_ROLE_PLAYING
# 101         101                                  Reigns          GAME_CARD
# 356         356               Five Nights at Freddy's 2      GAME_STRATEGY
# ..          ...                                     ...                ...
# 131         131                        Vintage Pachinko        GAME_CASINO
# 345         345                     College BBALL Coach        GAME_SPORTS
# 219         219                          Drum Pad Beats         GAME_MUSIC
# 214         214                 MC Lars: The Video Game         GAME_MUSIC
# 268         268             Outlaws - Sprint Car Racing        GAME_RACING
# 399         399              HQ Trivia Helper Unlimited        GAME_TRIVIA
# 208         208                   Beat Bugs: Sing-Along         GAME_MUSIC
# 145         145                    Baccarat Mastery Pro        GAME_CASINO
# 149         149                          Wild West Faro        GAME_CASINO
# 394         394  QuizBash - Party Games in Your Pocket!        GAME_TRIVIA
# 213         213               Caustic 3.2 Techno Pack 3         GAME_MUSIC
# 211         211            Caustic 3.2 DrumSynth Pack 2         GAME_MUSIC
# 142         142           Speed Rush Las Vegas VIP Slot        GAME_CASINO
# 212         212           Caustic 3.2 Tech House Pack 1         GAME_MUSIC
# 215         215            Frederic - Evil Strikes Back         GAME_MUSIC
# 384         384                     The Black Card Game        GAME_TRIVIA
# 220         220              Caustic 3.2 Minimal Pack 2         GAME_MUSIC
# 210         210               Caustic 3.2 HipHop Pack 2         GAME_MUSIC
# 395         395           The Ultimate Trivia Challenge        GAME_TRIVIA
# 144         144                               Best Hold        GAME_CASINO
# 380         380                    Bible Bowl Prep 2019        GAME_TRIVIA
# 138         138          Fun Slot Machine Las Vegas Pro        GAME_CASINO
# 206         206                              Sonar Beat         GAME_MUSIC
# 391         391                         Text Twist 2019        GAME_TRIVIA
# 398         398            The Office Fan Quiz (No Ads)        GAME_TRIVIA
# 140         140         Crock O'Gold Rainbow Slots PAID        GAME_CASINO
# 393         393         SHAPE - the picture trivia quiz        GAME_TRIVIA
# 224         224                              Meow Music         GAME_MUSIC
# 341         341                            Fish-o-niric        GAME_SPORTS
# 392         392                  Lets get wasted 18+ ;)        GAME_TRIVIA
#
#      Game Score  Number of Reviews  Price  Installs  \
# 0           4.3             387897   6.99   1000000
# 8           4.0              96670   4.99   1000000
# 52          4.3             132122   4.99   1000000
# 26          4.3             231424   4.99   1000000
# 303         4.3             100981   4.99   1000000
# 65          4.2              67904   4.99   1000000
# 253         3.9              44742   4.99   1000000
# 232         4.8             208449   3.99   1000000
# 61          4.3              38564   3.99   1000000
# 375         4.5              61210   5.99    500000
# 103         4.3             130157   2.99   1000000
# 352         4.6             192835   2.99   1000000
# 1           4.6             103826   2.99   1000000
# 350         4.7              48079   4.99    500000
# 327         4.3              56778   4.99    500000
# 81          3.9              25437   4.99    500000
# 38          4.2              36584   4.99    500000
# 30          4.4              22325   4.99    500000
# 302         4.5              25250   4.99    500000
# 307         4.3              57446   4.99    500000
# 46          4.4               7410  20.99    100000
# 233         4.9              86758   3.99    500000
# 239         4.7             189818   1.99   1000000
# 51          4.8             651477   1.99   1000000
# 326         4.4             134297   1.99   1000000
# 230         4.9             202024   1.99   1000000
# 54          4.5              35072   3.75    500000
# 282         3.3               7332  15.99    100000
# 101         4.7             142473   2.99    500000
# 356         4.6              75326   2.99    500000
# ..          ...                ...    ...       ...
# 131         4.0                 54   0.99      1000
# 345         4.2                223   0.99      1000
# 219         4.9                 13   7.99       100
# 214         4.9                 31   4.99       100
# 268         1.4                  5   3.49       100
# 399         1.9                 33   2.99       100
# 208         3.8                  5   1.99       100
# 145         4.7                  6   1.99       100
# 149         4.9                 23   1.49       100
# 394         5.0                 11   1.49       100
# 213         NaN                  0   1.49       100
# 211         NaN                  0   0.99       100
# 142         4.4                  9   0.99       100
# 212         5.0                  2   0.99       100
# 215         4.7                 18   0.99       100
# 384         1.6                  8   0.99       100
# 220         5.0                  2   0.99       100
# 210         3.0                  2   0.99       100
# 395         NaN                  0   4.99        10
# 144         5.0                  0   4.99        10
# 380         NaN                  0   0.99        50
# 138         4.5                 12   0.99        50
# 206         4.7                  3   2.49        10
# 391         1.8                  5   2.49        10
# 398         NaN                  0   2.49        10
# 140         NaN                  0   1.99        10
# 393         NaN                  0   1.49        10
# 224         5.0                  2   0.99        10
# 341         NaN                  0   0.99        10
# 392         5.0                  5   0.99         5
#
#                               Developer  \
# 0                        Rockstar Games
# 8                        Rockstar Games
# 52                       Rockstar Games
# 26                        505 Games Srl
# 303             Coffee Stain Publishing
# 65              Team 17 Digital Limited
# 253                     ELECTRONIC ARTS
# 232                         ustwo games
# 61                    Neutron Emulation
# 375                             Etermax
# 103                     Cartoon Network
# 352                          ninja kiwi
# 1                         Scott Cawthon
# 356  https://play.google.com/store/apps/details?id=...  1495000.00
# ..                                                 ...         ...
# 131  https://play.google.com/store/apps/details?id=...      990.00
# 345  https://play.google.com/store/apps/details?id=...      990.00
# 219  https://play.google.com/store/apps/details?id=...      799.00
# 214  https://play.google.com/store/apps/details?id=...      499.00
# 268  https://play.google.com/store/apps/details?id=...      349.00
# 399  https://play.google.com/store/apps/details?id=...      299.00
# 208  https://play.google.com/store/apps/details?id=...      199.00
# 145  https://play.google.com/store/apps/details?id=...      199.00
# 149  https://play.google.com/store/apps/details?id=...      149.00
# 394  https://play.google.com/store/apps/details?id=...      149.00
# 213  https://play.google.com/store/apps/details?id=...      149.00
# 211  https://play.google.com/store/apps/details?id=...       99.00
# 142  https://play.google.com/store/apps/details?id=...       99.00
# 212  https://play.google.com/store/apps/details?id=...       99.00
# 215  https://play.google.com/store/apps/details?id=...       99.00
# 384  https://play.google.com/store/apps/details?id=...       99.00
# 220  https://play.google.com/store/apps/details?id=...       99.00
# 210  https://play.google.com/store/apps/details?id=...       99.00
# 395  https://play.google.com/store/apps/details?id=...       49.90
# 144  https://play.google.com/store/apps/details?id=...       49.90
# 380  https://play.google.com/store/apps/details?id=...       49.50
# 138  https://play.google.com/store/apps/details?id=...       49.50
# 206  https://play.google.com/store/apps/details?id=...       24.90
# 391  https://play.google.com/store/apps/details?id=...       24.90
# 398  https://play.google.com/store/apps/details?id=...       24.90
# 140  https://play.google.com/store/apps/details?id=...       19.90
# 393  https://play.google.com/store/apps/details?id=...       14.90
# 224  https://play.google.com/store/apps/details?id=...        9.90
# 341  https://play.google.com/store/apps/details?id=...        9.90
# 392  https://play.google.com/store/apps/details?id=...        4.95
#
# [398 rows x 10 columns]

# %%
#extract top 25 games according to their revenue from df
top_games = top_games['Revenue'].nlargest(25).to_frame()
top_games = games_df.loc[top_games.index]

# %%
#show top_games data through a bar chart/ version 1
tick_location = np.arange(len(top_games))
rev1 = plt.bar(tick_location,top_games["Revenue"], align="center", color="tab:blue",label="revenue")
rev2 = plt.bar(tick_location,top_games["Installs"], align="center",color="orange",label="total download")
plt.xticks(tick_location,top_games["Game Title"], rotation=90)
plt.xticks()

plt.xlim(-1, len(top_games))
plt.title("Revenues Generated from Top 25 Paid Games")
plt.ylim(0,max(top_games["Revenue"]+5000000))
plt.ylabel("Total Download Revenue (10 million)")

plt.tight_layout()
plt.legend()
plt.savefig("Images/top_paid_games_boxplot.png")
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
#showing the data with a scatter plot

arcade = top_games.loc[top_games["Game Category"]=="GAME_ARCADE"]
sports = top_games.loc[top_games["Game Category"]=="GAME_SPORTS"]
racing = top_games.loc[top_games["Game Category"]=="GAME_RACING"]
music = top_games.loc[top_games["Game Category"]=="GAME_MUSIC"]
educational = top_games.loc[top_games["Game Category"]== "GAME_EDUCATIONAL"]
board = top_games.loc[top_games["Game Category"]=="GAME_BOARD"]
casino = top_games.loc[top_games["Game Category"]=="GAME_CASINO"]
action = top_games.loc[top_games["Game Category"]=="GAME_ACTION"]
trivia = top_games.loc[top_games["Game Category"]=="GAME_TRIVIA"]
simulation = top_games.loc[top_games["Game Category"]=="GAME_SIMULATION"]
adventure = top_games.loc[top_games["Game Category"]=="GAME_ADVENTURE"]
puzzle = top_games.loc[top_games["Game Category"]=="GAME_PUZZLE"]
card = top_games.loc[top_games["Game Category"]=="GAME_CARD"]
casual = top_games.loc[top_games["Game Category"]=="GAME_CASUAL"]
strategy = top_games.loc[top_games["Game Category"]=="GAME_STRATEGY"]                       
roleplay = top_games.loc[top_games["Game Category"]=="GAME_ROLE_PLAYING"]
word = top_games.loc[top_games["Game Category"]=="GAME_WORD"]

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Installs"], arcade["Price"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Installs"], sports["Price"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Installs"], racing["Price"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Installs"], music["Price"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Installs"], educational["Price"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Installs"], board["Price"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Installs"], casino["Price"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Installs"], action["Price"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Installs"], trivia["Price"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Installs"], simulation["Price"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Installs"], adventure["Price"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Installs"], puzzle["Price"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Installs"], card["Price"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Installs"], casual["Price"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Installs"], strategy["Price"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Installs"], roleplay["Price"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Installs"], word["Price"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Installs (10 million)")
plt.ylabel("Price/App ($)")
plt.title("Price vs. Install")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="best", bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.savefig("Images/PriceInstall.png")

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Installs"], arcade["Game Score"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Installs"], sports["Game Score"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Installs"], racing["Game Score"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Installs"], music["Game Score"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Installs"], educational["Game Score"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Installs"], board["Game Score"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Installs"], casino["Game Score"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Installs"], action["Game Score"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Installs"], trivia["Game Score"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Installs"], simulation["Game Score"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Installs"], adventure["Game Score"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Installs"], puzzle["Game Score"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Installs"], card["Game Score"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Installs"], casual["Game Score"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Installs"], strategy["Game Score"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Installs"], roleplay["Game Score"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Installs"], word["Game Score"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Installs (10 million)")
plt.ylabel("Game Rating")
plt.title("Rating vs. Install")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="best", bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()
plt.savefig("Images/RatingInstall.png")
# Out:
# /Users/emmanuelfabre/anaconda3/lib/python3.7/site-packages/matplotlib/tight_layout.py:182: UserWarning: The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   warnings.warn('The bottom and top margins cannot be made large '

# %%
price = games_df["Price"]

# %%
plt.boxplot(price,showmeans=True)
plt.grid()
plt.show()
plt.title("App Price Box Plot")
plt.ylabel("Prices ($)")
plt.xlabel("425 Top Games")
plt.tight_layout()
plt.savefig("Images/boxplot.png")
# Out:
# /Users/emmanuelfabre/anaconda3/lib/python3.7/site-packages/matplotlib/tight_layout.py:182: UserWarning: The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   warnings.warn('The bottom and top margins cannot be made large '

# %%
q1=np.percentile(price,25)
q3=np.percentile(price,75)

# %%
print(f"25% percentile of the avaiable data based on price is {q1}.")
print(f"75% percentile of the avaiable data based on price is {q3}.")
# Out:
# 25% percentile of the avaiable data based on price is 1.99.
# 75% percentile of the avaiable data based on price is 4.99.

# %%
iqr = (q3-q1)
print("interqurtile range:", iqr)
# Out:
# interqurtile range: 3.0

# %%
#find lower boundary
lower_broundary = q1 - (1.5*iqr)

#find upper boundary
upper_broundary = q3 + (1.5*iqr)

# %%
price[price<=lower_broundary]
# Out:
# Series([], Name: Price, dtype: float64)

# %%
price[price>=upper_broundary]
# Out:
# 46     20.99
# 88      9.99
# 133    34.99
# 135    19.99
# 141    14.00
# 146    15.00
# 276     9.99
# 280     9.99
# 281    19.99
# 282    15.99
# 285     9.99
# 286     9.99
# 306    11.99
# 357     9.99
# 359     9.99
# 365     9.99
# 378    24.99
# 379    29.99
# 381    24.99
# 383    24.99
# 387    24.99
# 389     9.99
# Name: Price, dtype: float64

# %%
new_df
# Out:
#      Unnamed: 0                              Game Title      Game Category  \
# 0             0           Grand Theft Auto: San Andreas        GAME_ACTION
# 8             8                    Grand Theft Auto III        GAME_ACTION
# 52           52             Grand Theft Auto: Vice City        GAME_ARCADE
# 26           26                               Terraria.     GAME_ADVENTURE
# 303         303                          Goat Simulator    GAME_SIMULATION
# 65           65                                 Worms 3        GAME_ARCADE
# 253         253              Need for Speed Most Wanted        GAME_RACING
# 232         232                         Monument Valley        GAME_PUZZLE
# 61           61          SuperRetro16 ( SNES Emulator )        GAME_ARCADE
# 375         375                   Trivia Crack (No Ads)        GAME_TRIVIA
# 103         103              Card Wars - Adventure Time          GAME_CARD
# 352         352                             Bloons TD 5      GAME_STRATEGY
# 1             1                 Five Nights at Freddy's        GAME_ACTION
# 350         350                             Bloons TD 6      GAME_STRATEGY
# 327         327                  NBA JAM  by EA SPORTS™        GAME_SPORTS
# 81           81                           Catan Classic         GAME_BOARD
# 38           38                      Castle of Illusion     GAME_ADVENTURE
# 30           30            Don't Starve: Pocket Edition     GAME_ADVENTURE
# 302         302                    Farming Simulator 18    GAME_SIMULATION
# 307         307      Infinite Flight - Flight Simulator    GAME_SIMULATION
# 46           46            FINAL FANTASY IX for Android     GAME_ADVENTURE
# 233         233                          The Room Three        GAME_PUZZLE
# 239         239                       Where's My Water?        GAME_PUZZLE
# 51           51                           Geometry Dash        GAME_ARCADE
# 326         326                              True Skate        GAME_SPORTS
# 230         230                            The Room Two        GAME_PUZZLE
# 54           54                       ePSXe for Android        GAME_ARCADE
# 282         282                       FINAL FANTASY VII  GAME_ROLE_PLAYING
# 101         101                                  Reigns          GAME_CARD
# 356         356               Five Nights at Freddy's 2      GAME_STRATEGY
# ..          ...                                     ...                ...
# 131         131                        Vintage Pachinko        GAME_CASINO
# 345         345                     College BBALL Coach        GAME_SPORTS
# 219         219                          Drum Pad Beats         GAME_MUSIC
# 214         214                 MC Lars: The Video Game         GAME_MUSIC
# 268         268             Outlaws - Sprint Car Racing        GAME_RACING
# 399         399              HQ Trivia Helper Unlimited        GAME_TRIVIA
# 208         208                   Beat Bugs: Sing-Along         GAME_MUSIC
# 145         145                    Baccarat Mastery Pro        GAME_CASINO
# 149         149                          Wild West Faro        GAME_CASINO
# 394         394  QuizBash - Party Games in Your Pocket!        GAME_TRIVIA
# 213         213               Caustic 3.2 Techno Pack 3         GAME_MUSIC
# 211         211            Caustic 3.2 DrumSynth Pack 2         GAME_MUSIC
# 142         142           Speed Rush Las Vegas VIP Slot        GAME_CASINO
# 212         212           Caustic 3.2 Tech House Pack 1         GAME_MUSIC
# 215         215            Frederic - Evil Strikes Back         GAME_MUSIC
# 384         384                     The Black Card Game        GAME_TRIVIA
# 220         220              Caustic 3.2 Minimal Pack 2         GAME_MUSIC
# 210         210               Caustic 3.2 HipHop Pack 2         GAME_MUSIC
# 395         395           The Ultimate Trivia Challenge        GAME_TRIVIA
# 144         144                               Best Hold        GAME_CASINO
# 380         380                    Bible Bowl Prep 2019        GAME_TRIVIA
# 138         138          Fun Slot Machine Las Vegas Pro        GAME_CASINO
# 206         206                              Sonar Beat         GAME_MUSIC
# 391         391                         Text Twist 2019        GAME_TRIVIA
# 398         398            The Office Fan Quiz (No Ads)        GAME_TRIVIA
# 140         140         Crock O'Gold Rainbow Slots PAID        GAME_CASINO
# 393         393         SHAPE - the picture trivia quiz        GAME_TRIVIA
# 224         224                              Meow Music         GAME_MUSIC
# 341         341                            Fish-o-niric        GAME_SPORTS
# 392         392                  Lets get wasted 18+ ;)        GAME_TRIVIA
#
#      Game Score  Number of Reviews  Price  Installs  \
# 0           4.3             387897   6.99   1000000
# 8           4.0              96670   4.99   1000000
# 52          4.3             132122   4.99   1000000
# 26          4.3             231424   4.99   1000000
# 303         4.3             100981   4.99   1000000
# 65          4.2              67904   4.99   1000000
# 253         3.9              44742   4.99   1000000
# 232         4.8             208449   3.99   1000000
# 61          4.3              38564   3.99   1000000
# 375         4.5              61210   5.99    500000
# 103         4.3             130157   2.99   1000000
# 352         4.6             192835   2.99   1000000
# 1           4.6             103826   2.99   1000000
# 350         4.7              48079   4.99    500000
# 327         4.3              56778   4.99    500000
# 81          3.9              25437   4.99    500000
# 38          4.2              36584   4.99    500000
# 30          4.4              22325   4.99    500000
# 302         4.5              25250   4.99    500000
# 307         4.3              57446   4.99    500000
# 46          4.4               7410  20.99    100000
# 233         4.9              86758   3.99    500000
# 239         4.7             189818   1.99   1000000
# 51          4.8             651477   1.99   1000000
# 326         4.4             134297   1.99   1000000
# 230         4.9             202024   1.99   1000000
# 54          4.5              35072   3.75    500000
# 282         3.3               7332  15.99    100000
# 101         4.7             142473   2.99    500000
# 356         4.6              75326   2.99    500000
# ..          ...                ...    ...       ...
# 131         4.0                 54   0.99      1000
# 345         4.2                223   0.99      1000
# 219         4.9                 13   7.99       100
# 214         4.9                 31   4.99       100
# 268         1.4                  5   3.49       100
# 399         1.9                 33   2.99       100
# 208         3.8                  5   1.99       100
# 145         4.7                  6   1.99       100
# 149         4.9                 23   1.49       100
# 394         5.0                 11   1.49       100
# 213         NaN                  0   1.49       100
# 211         NaN                  0   0.99       100
# 142         4.4                  9   0.99       100
# 212         5.0                  2   0.99       100
# 215         4.7                 18   0.99       100
# 384         1.6                  8   0.99       100
# 220         5.0                  2   0.99       100
# 210         3.0                  2   0.99       100
# 395         NaN                  0   4.99        10
# 144         5.0                  0   4.99        10
# 380         NaN                  0   0.99        50
# 138         4.5                 12   0.99        50
# 206         4.7                  3   2.49        10
# 391         1.8                  5   2.49        10
# 398         NaN                  0   2.49        10
# 140         NaN                  0   1.99        10
# 393         NaN                  0   1.49        10
# 224         5.0                  2   0.99        10
# 341         NaN                  0   0.99        10
# 392         5.0                  5   0.99         5
#
#                               Developer  \
# 0                        Rockstar Games
# 8                        Rockstar Games
# 52                       Rockstar Games
# 26                        505 Games Srl
# 303             Coffee Stain Publishing
# 65              Team 17 Digital Limited
# 253                     ELECTRONIC ARTS
# 282  https://play.google.com/store/apps/details?id=...  1599000.00
# 101  https://play.google.com/store/apps/details?id=...  1495000.00
# 356  https://play.google.com/store/apps/details?id=...  1495000.00
# ..                                                 ...         ...
# 131  https://play.google.com/store/apps/details?id=...      990.00
# 345  https://play.google.com/store/apps/details?id=...      990.00
# 219  https://play.google.com/store/apps/details?id=...      799.00
# 214  https://play.google.com/store/apps/details?id=...      499.00
# 268  https://play.google.com/store/apps/details?id=...      349.00
# 399  https://play.google.com/store/apps/details?id=...      299.00
# 208  https://play.google.com/store/apps/details?id=...      199.00
# 145  https://play.google.com/store/apps/details?id=...      199.00
# 149  https://play.google.com/store/apps/details?id=...      149.00
# 394  https://play.google.com/store/apps/details?id=...      149.00
# 213  https://play.google.com/store/apps/details?id=...      149.00
# 211  https://play.google.com/store/apps/details?id=...       99.00
# 142  https://play.google.com/store/apps/details?id=...       99.00
# 212  https://play.google.com/store/apps/details?id=...       99.00
# 215  https://play.google.com/store/apps/details?id=...       99.00
# 384  https://play.google.com/store/apps/details?id=...       99.00
# 220  https://play.google.com/store/apps/details?id=...       99.00
# 210  https://play.google.com/store/apps/details?id=...       99.00
# 395  https://play.google.com/store/apps/details?id=...       49.90
# 144  https://play.google.com/store/apps/details?id=...       49.90
# 380  https://play.google.com/store/apps/details?id=...       49.50
# 138  https://play.google.com/store/apps/details?id=...       49.50
# 206  https://play.google.com/store/apps/details?id=...       24.90
# 391  https://play.google.com/store/apps/details?id=...       24.90
# 398  https://play.google.com/store/apps/details?id=...       24.90
# 140  https://play.google.com/store/apps/details?id=...       19.90
# 393  https://play.google.com/store/apps/details?id=...       14.90
# 224  https://play.google.com/store/apps/details?id=...        9.90
# 341  https://play.google.com/store/apps/details?id=...        9.90
# 392  https://play.google.com/store/apps/details?id=...        4.95
#
# [398 rows x 10 columns]

# %%
stars2 = new_df[new_df['Game Score'] == 4.1]["Revenue"]
stars3 = new_df[new_df['Game Score'] == 4.2]["Revenue"]
stars4 = new_df[new_df['Game Score'] == 4.3]["Revenue"]
stars5 = new_df[new_df['Game Score'] == 4.4]["Revenue"]
stars6 = new_df[new_df['Game Score'] == 4.5]["Revenue"]
stars7 = new_df[new_df['Game Score'] == 4.6]["Revenue"]
stars8 = new_df[new_df['Game Score'] == 4.7]["Revenue"]
stars9 = new_df[new_df['Game Score'] == 4.8]["Revenue"]
stars10 = new_df[new_df['Game Score'] == 4.9]["Revenue"]

data_by_star = [stars2,stars3,stars4,stars5,stars6,stars7,stars8,stars9,stars10]

# %%
plt.figure(figsize=(20,10))
plt.rcParams['axes.facecolor'] = '#eaeaf2'
plt.boxplot(data_by_star, showmeans=True)
plt.title('Game Score')
plt.xlabel('Number of Stars (4.1-4.9)')
plt.ylabel('Revenue ($)')
plt.savefig('Images/revenueboxplot.png')
plt.grid(color='w')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1998.8889418413623">

# %%
#slicing data based on game score and revenue
stars2 = new_df[new_df['Game Score'] == 4.1]["Revenue"]
stars3 = new_df[new_df['Game Score'] == 4.2]["Revenue"]
stars4 = new_df[new_df['Game Score'] == 4.3]["Revenue"]
stars5 = new_df[new_df['Game Score'] == 4.4]["Revenue"]
stars6 = new_df[new_df['Game Score'] == 4.5]["Revenue"]
stars7 = new_df[new_df['Game Score'] == 4.6]["Revenue"]
stars8 = new_df[new_df['Game Score'] == 4.7]["Revenue"]
stars9 = new_df[new_df['Game Score'] == 4.8]["Revenue"]
stars10 = new_df[new_df['Game Score'] == 4.9]["Revenue"]
stars11 = new_df[new_df['Game Score'] == 5.0]["Revenue"]

data_by_star = [stars2,stars3,stars4,stars5,stars6,stars7,stars8,stars9,stars10,stars11]

# %%
#boxplot based on the revenue and game score
plt.figure(figsize=(20,10))
plt.rcParams['axes.facecolor'] = '#eaeaf2'
plt.boxplot(data_by_star, showmeans=True)
plt.title('Game Score')
plt.xlabel('Number of Stars (4.1-5.0)')
plt.ylabel('Total Revenue ($)')
plt.savefig('Images/revenueboxplot.png')
plt.grid(color='w')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1998.8889418413623">

# %%
#slicing data based on game score and app price
stars2 = new_df[new_df['Game Score'] == 4.1]["Price"]
stars3 = new_df[new_df['Game Score'] == 4.2]["Price"]
stars4 = new_df[new_df['Game Score'] == 4.3]["Price"]
stars5 = new_df[new_df['Game Score'] == 4.4]["Price"]
stars6 = new_df[new_df['Game Score'] == 4.5]["Price"]
stars7 = new_df[new_df['Game Score'] == 4.6]["Price"]
stars8 = new_df[new_df['Game Score'] == 4.7]["Price"]
stars9 = new_df[new_df['Game Score'] == 4.8]["Price"]
stars10 = new_df[new_df['Game Score'] == 4.9]["Price"]
stars11 = new_df[new_df['Game Score'] == 5.0]["Price"]

data_by_star = [stars2,stars3,stars4,stars5,stars6,stars7,stars8,stars9,stars10,stars11]

# %%
#boxplot based on the price and game score
plt.figure(figsize=(20,10))
plt.rcParams['axes.facecolor'] = '#eaeaf2'
plt.boxplot(data_by_star, showmeans=True)
plt.title('Game Score')
plt.xlabel('Number of Stars (4.1-5.0)')
plt.ylabel('Price ($)')
plt.savefig('Images/priceboxplot.png')
plt.grid(color='w')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1998.8889418413623">

# %%
#slicing data based on game score and Installs
stars2 = new_df[new_df['Game Score'] == 4.1]["Installs"]
stars3 = new_df[new_df['Game Score'] == 4.2]["Installs"]
stars4 = new_df[new_df['Game Score'] == 4.3]["Installs"]
stars5 = new_df[new_df['Game Score'] == 4.4]["Installs"]
stars6 = new_df[new_df['Game Score'] == 4.5]["Installs"]
stars7 = new_df[new_df['Game Score'] == 4.6]["Installs"]
stars8 = new_df[new_df['Game Score'] == 4.7]["Installs"]
stars9 = new_df[new_df['Game Score'] == 4.8]["Installs"]
stars10 = new_df[new_df['Game Score'] == 4.9]["Installs"]
stars11 = new_df[new_df['Game Score'] == 5.0]["Installs"]

data_by_star = [stars2,stars3,stars4,stars5,stars6,stars7,stars8,stars9,stars10,stars11]

# %%
#boxplot based on the install and game score
plt.figure(figsize=(20,10))
plt.rcParams['axes.facecolor'] = '#eaeaf2'
plt.boxplot(data_by_star, showmeans=True)
plt.title('Game Score')
plt.xlabel('Number of Stars (4.1-5.0)')
plt.ylabel('Number of Installs')
plt.savefig('Images/dlboxplot2.png')
plt.grid(color='w')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1998.8889418413623">
