# %%
# %matplotlib inline
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np
import requests
import csv
import play_scraper as gp
from pprint import pprint

# %%
# a complete list of categories for the google play store
categories = ["GAME_ACTION", "GAME_ADVENTURE",
              "GAME_ARCADE", "GAME_BOARD", 
              "GAME_CARD", "GAME_CASINO",
              "GAME_CASUAL", "GAME_EDUCATIONAL",
              "GAME_MUSIC",  "GAME_PUZZLE",
              "GAME_RACING", "GAME_ROLE_PLAYING",
              "GAME_SIMULATION", "GAME_SPORTS",
              "GAME_STRATEGY", "GAME_TRIVIA",
              "GAME_WORD"]

# Empty lists to put the game id (and game category for later).
game_category = []
game_list = []

# Grabs a list of the top 25 paid games in each category.
for x in categories:
    paid_games = gp.collection(collection='TOP_PAID', category=x, results=25)
    print(f' --')
    print(f'   *** Getting information for games in the {x} category. ***')
    print(f' --')
    for j in range (0, 25):
        game_info = paid_games[j]['app_id']
        title = paid_games[j]['title']
        game_category.append(x)
        game_list.append(game_info)
        print(f'{j}. Getting the Game ID for {title}.')
print(f' --')
print(f'All done! The loop collected a total of {len(game_list)} game titles.')
print(f' --')
# Out:
#  --
#    *** Getting information for games in the GAME_ACTION category. ***
#  --
# 0. Getting the Game ID for Grand Theft Auto: San Andreas.
# 1. Getting the Game ID for Five Nights at Freddy's.
# 2. Getting the Game ID for Hitman Sniper.
# 3. Getting the Game ID for Five Nights at Freddy's: SL.
# 4. Getting the Game ID for Assassin's Creed Identity.
# 5. Getting the Game ID for Grand Theft Auto III.
# 6. Getting the Game ID for Call of Duty:Black Ops Zombies.
# 7. Getting the Game ID for Five Nights at Freddy's 4.
# 8. Getting the Game ID for Space Marshals.
# 9. Getting the Game ID for truTV Impractical Jokers Wheel of Doom.
# 10. Getting the Game ID for Real Steel.
# 11. Getting the Game ID for Downwell.
# 12. Getting the Game ID for Teen Titans GO Figure!.
# 13. Getting the Game ID for Five Nights at Freddy's 3.
# 14. Getting the Game ID for Bloons Supermonkey 2.
# 15. Getting the Game ID for GTA: Chinatown Wars.
# 16. Getting the Game ID for Shadow of Death: Stickman Fighting - Dark Knight.
# 17. Getting the Game ID for Bully: Anniversary Edition.
# 18. Getting the Game ID for Zombieville USA 2.
# 19. Getting the Game ID for LEGO ® Marvel Super Heroes.
# 20. Getting the Game ID for PPSSPP Gold - PSP emulator.
# 21. Getting the Game ID for BACKFIRE.
# 22. Getting the Game ID for LEGO® Star Wars™:  TCS.
# 23. Getting the Game ID for Battle of Vicksburg.
# 24. Getting the Game ID for Oddworld: Stranger's Wrath.
#  --
#    *** Getting information for games in the GAME_ADVENTURE category. ***
#  --
# 0. Getting the Game ID for Alien: Blackout.
# 1. Getting the Game ID for Terraria..
# 2. Getting the Game ID for Bendy and the Ink Machine.
# 3. Getting the Game ID for THE GALAXY: SURVIVOR.
# 4. Getting the Game ID for Don't Starve: Pocket Edition.
# 5. Getting the Game ID for 60 Seconds! Atomic Adventure.
# 6. Getting the Game ID for Live or Die: Survival Pro.
# 7. Getting the Game ID for Portal Knights.
# 8. Getting the Game ID for LEGO® Jurassic World™.
# 9. Getting the Game ID for Octodad: Dadliest Catch.
# 10. Getting the Game ID for Angry Neighbor.
# 11. Getting the Game ID for Sonic Runners Adventure - Fast Action Platformer.
# 12. Getting the Game ID for Crashlands.
# 13. Getting the Game ID for Rusty Lake Hotel.
# 14. Getting the Game ID for Castle of Illusion.
# 15. Getting the Game ID for Bury me, my Love.
# 16. Getting the Game ID for Rusty Lake: Roots.
# 17. Getting the Game ID for Thickety Creek.
# 18. Getting the Game ID for 7Days - Decide your story.
# 19. Getting the Game ID for Draw a Stickman: EPIC 2.
# 20. Getting the Game ID for GTA: Liberty City Stories.
# 21. Getting the Game ID for Survivalcraft 2.
# 22. Getting the Game ID for FINAL FANTASY IX for Android.
# 23. Getting the Game ID for Rusty Lake Paradise.
# 24. Getting the Game ID for CHUCHEL.
#  --
#    *** Getting information for games in the GAME_ARCADE category. ***
#  --
# 0. Getting the Game ID for Minecraft.
# 1. Getting the Game ID for Geometry Dash.
# 2. Getting the Game ID for Ding Dong XL.
# 3. Getting the Game ID for Grand Theft Auto: Vice City.
# 4. Getting the Game ID for ePSXe for Android.
# 5. Getting the Game ID for Fruit Ninja Classic.
# 6. Getting the Game ID for My OldBoy! - GBC Emulator.
# 7. Getting the Game ID for Pocket God™.
# 8. Getting the Game ID for Max Payne Mobile.
# 9. Getting the Game ID for Vector Full.
# 10. Getting the Game ID for SuperRetro16 ( SNES Emulator ).
# 11. Getting the Game ID for Peace, Death!.
# 12. Getting the Game ID for Retro NES Pro - NES Emulator.
# 13. Getting the Game ID for Retro N64 Pro - N64 Emulator.
# 14. Getting the Game ID for Ms. PAC-MAN.
# 15. Getting the Game ID for METAL SLUG 3.
# 16. Getting the Game ID for The Impossible Game.
# 17. Getting the Game ID for Worms 3.
# 18. Getting the Game ID for PAC-MAN Championship Edition DX.
# 19. Getting the Game ID for Fowlst.
# 20. Getting the Game ID for Robot Unicorn Attack.
# 21. Getting the Game ID for Ridiculous Fishing.
# 22. Getting the Game ID for Marvel Pinball.
# 23. Getting the Game ID for holedown.
# 24. Getting the Game ID for Backflip Madness.
#  --
#    *** Getting information for games in the GAME_BOARD category. ***
#  --
# 0. Getting the Game ID for The Game of Life.
# 1. Getting the Game ID for Clue.
# 2. Getting the Game ID for Legends of Andor – The King’s Secret.
# 3. Getting the Game ID for Ticket to Ride.
# 4. Getting the Game ID for Catan Classic.
# 5. Getting the Game ID for Carcassonne: Official Board Game -Tiles & Tactics.
# 6. Getting the Game ID for Pandemic: The Board Game.
# 7. Getting the Game ID for Chess.
# 8. Getting the Game ID for Twice as clever.
# 9. Getting the Game ID for Splendor.
# 10. Getting the Game ID for Hasbro's BATTLESHIP.
# 11. Getting the Game ID for Ganz schön clever.
# 12. Getting the Game ID for Through the Ages.
# 13. Getting the Game ID for D&D Lords of Waterdeep.
# 14. Getting the Game ID for Race for the Galaxy.
# 15. Getting the Game ID for Small World 2.
# 16. Getting the Game ID for Backgammon.
# 17. Getting the Game ID for Talisman.
# 18. Getting the Game ID for Sentinels of the Multiverse.
# 19. Getting the Game ID for Go.
# 20. Getting the Game ID for Tokaido™.
# 21. Getting the Game ID for Mysterium: A Psychic Clue Game.
# 22. Getting the Game ID for Galaxy Trucker.
# 23. Getting the Game ID for Smash Up - The Shufflebuilding Game.
# 24. Getting the Game ID for Stratego® Single Player.
#  --
#    *** Getting information for games in the GAME_CARD category. ***
#  --
# 0. Getting the Game ID for Exploding Kittens® - Official.
# 1. Getting the Game ID for Reigns.
# 2. Getting the Game ID for Skip-Bo™.
# 3. Getting the Game ID for Card Wars - Adventure Time.
# 4. Getting the Game ID for Reigns: Game of Thrones.
# 5. Getting the Game ID for Solitaire+.
# 6. Getting the Game ID for Reigns: Her Majesty.
# 7. Getting the Game ID for Meteorfall: Journeys.
# 8. Getting the Game ID for Blackbird.
# 9. Getting the Game ID for Card Quest.
# 10. Getting the Game ID for Decked Builder.
# 11. Getting the Game ID for Phase 10.
# 12. Getting the Game ID for Cribbage Pro Online!.
# 13. Getting the Game ID for SET Mania.
# 14. Getting the Game ID for Kemono Mahjong.
# 15. Getting the Game ID for Spades.
# 16. Getting the Game ID for Spider Solitaire+.
# 17. Getting the Game ID for Patch Tarot.
# 18. Getting the Game ID for Solitaire MegaPack.
# 19. Getting the Game ID for Solitaire Collection Premium.
# 20. Getting the Game ID for FreeCell Solitaire+.
# 21. Getting the Game ID for Cribbage With Grandpas.
# 22. Getting the Game ID for Gin Rummy.
# 23. Getting the Game ID for PokerCruncher - Advanced - Poker Odds Calculator.
# 24. Getting the Game ID for Munchkin Level Counter.
#  --
#    *** Getting information for games in the GAME_CASINO category. ***
#  --
# 0. Getting the Game ID for VIP Slots Club ★ VIP Casino.
# 1. Getting the Game ID for Card Counter.
# 2. Getting the Game ID for Craps Trainer Pro.
# 3. Getting the Game ID for Top Money 💵 Slots (PREMIUM).
# 4. Getting the Game ID for Pokertrainer.
# 5. Getting the Game ID for Cleopatra Keno.
# 6. Getting the Game ID for Ultimate X Poker.
# 7. Getting the Game ID for Vintage Pachinko.
# 8. Getting the Game ID for Blackjack Verite Games.
# 9. Getting the Game ID for Cleopatra Keno.
# 10. Getting the Game ID for Super Times Pay Poker.
# 11. Getting the Game ID for MEGA Money Slots PAID.
# 12. Getting the Game ID for Multi-Card Keno.
# 13. Getting the Game ID for Wild West Faro.
# 14. Getting the Game ID for Caveman Keno.
# 15. Getting the Game ID for Scratch-a-Lotto Scratch Card Lottery PAID.
# 16. Getting the Game ID for Fun Slot Machine Las Vegas Pro.
# 17. Getting the Game ID for Zeus Epic Slots Machine Pro.
# 18. Getting the Game ID for Crock O'Gold Rainbow Slots PAID.
# 19. Getting the Game ID for Blackjack Verite Drills.
# 20. Getting the Game ID for Learn Pro Blackjack Trainer - Casino Odds Strategy.
# 21. Getting the Game ID for Roulette Statistics and Prediction - European.
# 22. Getting the Game ID for Play Perfect Video Poker Pro+.
# 23. Getting the Game ID for Baccarat Mastery Pro.
# 24. Getting the Game ID for Carnival Fiesta Slots PAID.
#  --
#    *** Getting information for games in the GAME_CASUAL category. ***
#  --
# 0. Getting the Game ID for Let's Create! Pottery.
# 1. Getting the Game ID for Game Dev Story.
# 2. Getting the Game ID for Tamagotchi Classic - Gen1.
# 3. Getting the Game ID for Jazza's Arty Games.
# 4. Getting the Game ID for Hidden Folks.
# 5. Getting the Game ID for FINAL FANTASY.
# 6. Getting the Game ID for Meme Soundboard PRO 2019.
# 7. Getting the Game ID for My PlayHome : Play Home Doll House.
# 8. Getting the Game ID for My PlayHome Hospital.
# 9. Getting the Game ID for Little Inferno.
# 10. Getting the Game ID for My PlayHome Stores.
# 11. Getting the Game ID for Wedding Dash Deluxe.
# 12. Getting the Game ID for My PlayHome School.
# 13. Getting the Game ID for Fieldrunners 2.
# 14. Getting the Game ID for Sand! Premium.
# 15. Getting the Game ID for Fieldrunners HD.
# 16. Getting the Game ID for SpongeBob Diner Dash Deluxe.
# 17. Getting the Game ID for supertype.
# 18. Getting the Game ID for SpongeBob's Game Frenzy.
# 19. Getting the Game ID for Brink of Consciousness (Full).
# 20. Getting the Game ID for Haunted Hotel: Death Sentence (Full).
# 21. Getting the Game ID for Burger Shop 2 Deluxe.
# 22. Getting the Game ID for Virtual Families.
# 23. Getting the Game ID for Hotel Dash Deluxe.
# 24. Getting the Game ID for Zip Zap.
#  --
#    *** Getting information for games in the GAME_EDUCATIONAL category. ***
#  --
# 0. Getting the Game ID for Teach Your Monster to Read - Phonics and Reading.
# 1. Getting the Game ID for Wonderland : Peter Pan.
# 2. Getting the Game ID for Toca Blocks.
# 3. Getting the Game ID for Toca Boo.
# 4. Getting the Game ID for Explore Daniel's Neighborhood.
# 5. Getting the Game ID for Toca Lab: Plants.
# 6. Getting the Game ID for My Town : Hospital.
# 7. Getting the Game ID for Learn to Read with Tommy Turtle.
# 8. Getting the Game ID for My Town : Airport.
# 9. Getting the Game ID for Peppa Pig: Holiday.
# 10. Getting the Game ID for My City : Office.
# 11. Getting the Game ID for Daniel Tiger's Stop & Go Potty.
# 12. Getting the Game ID for Toca Mystery House.
# 13. Getting the Game ID for My Town : Best Friends' House.
# 14. Getting the Game ID for Second Grade Learning Games.
# 15. Getting the Game ID for Wonderland : Little Mermaid.
# 16. Getting the Game ID for BRIO World - Railway.
# 17. Getting the Game ID for Dr. Panda Restaurant 2.
# 18. Getting the Game ID for My City : Dentist visit.
# 19. Getting the Game ID for Stack the States® 2.
# 20. Getting the Game ID for My City : Home.
# 21. Getting the Game ID for Numberblocks - Hide and Seek.
# 22. Getting the Game ID for My Town : Grandparents.
# 23. Getting the Game ID for My Town : School.
# 24. Getting the Game ID for PAW Patrol Air and Sea Adventures.
#  --
#    *** Getting information for games in the GAME_MUSIC category. ***
#  --
# 0. Getting the Game ID for Cytus II.
# 1. Getting the Game ID for Incredibox.
# 2. Getting the Game ID for Lowriders Comeback 2: Cruising.
# 3. Getting the Game ID for Muse Dash.
# 4. Getting the Game ID for Note Rush: Learn to Read Music.
# 5. Getting the Game ID for Sonar Beat.
# 6. Getting the Game ID for My Singing Monsters Composer.
# 7. Getting the Game ID for Learn Music Notes.
# 8. Getting the Game ID for Wonder Parade.
# 9. Getting the Game ID for Piano Flashcards.
# 10. Getting the Game ID for Drum Pad Beats.
# 11. Getting the Game ID for Crayola DJ.
# 12. Getting the Game ID for Black Metal Man.
# 13. Getting the Game ID for Caustic 3.2 Techno Pack 3.
# 14. Getting the Game ID for Note Fighter Unlimited.
# 15. Getting the Game ID for Meow Music.
# 16. Getting the Game ID for Learn Music Notes [Teacher Edition].
# 17. Getting the Game ID for Caustic 3.2 Minimal Pack 2.
# 18. Getting the Game ID for Dark Witch Music: Rudymical♪.
# 19. Getting the Game ID for A Dance of Fire and Ice.
# 20. Getting the Game ID for Hangman Beatles Trivia.
# 21. Getting the Game ID for Beat Beat Vocaloid.
# 22. Getting the Game ID for Die For Metal.
# 23. Getting the Game ID for Caustic 3.2 Synth Elements Pack 4.
# 24. Getting the Game ID for Melody Maker XD.
#  --
#    *** Getting information for games in the GAME_PUZZLE category. ***
#  --
# 0. Getting the Game ID for Scribblenauts Remix.
# 1. Getting the Game ID for The Room.
# 2. Getting the Game ID for Scribblenauts Unlimited.
# 3. Getting the Game ID for The Room: Old Sins.
# 4. Getting the Game ID for Florence.
# 5. Getting the Game ID for Agent A: A puzzle in disguise.
# 6. Getting the Game ID for The Room Two.
# 7. Getting the Game ID for The House of Da Vinci.
# 8. Getting the Game ID for The Room Three.
# 9. Getting the Game ID for Monument Valley.
# 10. Getting the Game ID for Bridge Constructor Portal.
# 11. Getting the Game ID for Monument Valley 2.
# 12. Getting the Game ID for Hitman GO.
# 13. Getting the Game ID for Where's My Water?.
# 14. Getting the Game ID for Lara Croft GO.
# 15. Getting the Game ID for Doodle God™.
# 16. Getting the Game ID for Doodle God™ HD.
# 17. Getting the Game ID for Legacy 3 - The Hidden Relic.
# 18. Getting the Game ID for Cut the Rope GOLD.
# 19. Getting the Game ID for Human Resource Machine.
# 20. Getting the Game ID for Doodle Devil™ HD.
# 21. Getting the Game ID for Gorogoa.
# 22. Getting the Game ID for Please, Don't Touch Anything.
# 23. Getting the Game ID for Scalak.
# 24. Getting the Game ID for Deus Ex GO.
#  --
#    *** Getting information for games in the GAME_RACING category. ***
#  --
# 0. Getting the Game ID for Bike Race Pro by T. F. Games.
# 1. Getting the Game ID for Real Drift Car Racing.
# 2. Getting the Game ID for Earn to Die.
# 3. Getting the Game ID for Need for Speed Most Wanted.
# 4. Getting the Game ID for Rush Rally 2.
# 5. Getting the Game ID for Riptide GP: Renegade.
# 6. Getting the Game ID for Motorsport Manager Mobile 3.
# 7. Getting the Game ID for TRAIL CLIMB.
# 8. Getting the Game ID for Dirt Trackin.
# 9. Getting the Game ID for PJ Masks: Racing Heroes.
# 10. Getting the Game ID for Need for Speed Hot Pursuit.
# 11. Getting the Game ID for Draw Rider Plus.
# 12. Getting the Game ID for Bike Mayhem Mountain Racing.
# 13. Getting the Game ID for Ricky Carmichael's Motocross.
# 14. Getting the Game ID for Riptide GP2.
# 15. Getting the Game ID for Dirt Trackin Sprint Cars.
# 16. Getting the Game ID for Reckless Racing 3.
# 17. Getting the Game ID for F1 2016.
# 18. Getting the Game ID for Outlaws - Sprint Car Racing.
# 19. Getting the Game ID for ULTRA4 Offroad Racing.
# 20. Getting the Game ID for Drag Racing 3D.
# 21. Getting the Game ID for Dirt Racing Mobile 3D.
# 22. Getting the Game ID for Absolute Drift.
# 23. Getting the Game ID for Riptide GP.
# 24. Getting the Game ID for Jet Car Stunts.
#  --
#    *** Getting information for games in the GAME_ROLE_PLAYING category. ***
#  --
# 0. Getting the Game ID for Doom & Destiny Advanced.
# 1. Getting the Game ID for Evoland.
# 2. Getting the Game ID for Star Wars™: KOTOR.
# 3. Getting the Game ID for EvoCreo.
# 4. Getting the Game ID for Monster Hunter Stories.
# 5. Getting the Game ID for Attack the Light.
# 6. Getting the Game ID for Alter Ego.
# 7. Getting the Game ID for Neverwinter Nights: Enhanced Edition.
# 8. Getting the Game ID for FINAL FANTASY VII.
# 9. Getting the Game ID for Doom & Destiny.
# 10. Getting the Game ID for Baldur's Gate: Enhanced Edition.
# 11. Getting the Game ID for CHRONO TRIGGER (Upgrade Ver.).
# 12. Getting the Game ID for DRAGON QUEST.
# 13. Getting the Game ID for Day R Premium.
# 14. Getting the Game ID for 80 Days.
# 15. Getting the Game ID for Evoland 2.
# 16. Getting the Game ID for Rogue Hearts.
# 17. Getting the Game ID for Pocket Rogues: Ultimate.
# 18. Getting the Game ID for The Bard's Tale.
# 19. Getting the Game ID for ICEY.
# 20. Getting the Game ID for Battleheart Legacy.
# 21. Getting the Game ID for A Dark Room ®.
# 22. Getting the Game ID for Goat Simulator MMO Simulator.
# 23. Getting the Game ID for Guild of Dungeoneering.
# 24. Getting the Game ID for FINAL FANTASY VI.
#  --
#    *** Getting information for games in the GAME_SIMULATION category. ***
#  --
# 0. Getting the Game ID for Mini Metro.
# 1. Getting the Game ID for Poly Bridge.
# 2. Getting the Game ID for Game Dev Tycoon.
# 3. Getting the Game ID for Farming Simulator 18.
# 4. Getting the Game ID for Pocket City.
# 5. Getting the Game ID for Goat Simulator.
# 6. Getting the Game ID for FINAL FANTASY TACTICS : WotL.
# 7. Getting the Game ID for Infinite Flight - Flight Simulator.
# 8. Getting the Game ID for Project Highrise.
# 9. Getting the Game ID for Getting Over It with Bennett Foddy.
# 10. Getting the Game ID for Goat Simulator Payday.
# 11. Getting the Game ID for Pocket Aquarium.
# 12. Getting the Game ID for Youtubers Life: Gaming Channel.
# 13. Getting the Game ID for Farming Simulator 16.
# 14. Getting the Game ID for Goat Simulator Waste of Space.
# 15. Getting the Game ID for One Hour One Life for Mobile.
# 16. Getting the Game ID for Construction Simulator 2.
# 17. Getting the Game ID for SimplePlanes.
# 18. Getting the Game ID for Farming USA 2.
# 19. Getting the Game ID for SPACEPLAN.
# 20. Getting the Game ID for My Child Lebensborn.
# 21. Getting the Game ID for Truck Simulator PRO 2.
# 22. Getting the Game ID for Townsmen Premium.
# 23. Getting the Game ID for 911 Operator.
# 24. Getting the Game ID for Construction Simulator 2014.
#  --
#    *** Getting information for games in the GAME_SPORTS category. ***
#  --
# 0. Getting the Game ID for NBA 2K19.
# 1. Getting the Game ID for True Skate.
# 2. Getting the Game ID for NBA JAM  by EA SPORTS™.
# 3. Getting the Game ID for Football Manager 2019 Mobile.
# 4. Getting the Game ID for WWE 2K.
# 5. Getting the Game ID for Skater.
# 6. Getting the Game ID for Clay Hunt PRO.
# 7. Getting the Game ID for Flick Golf!.
# 8. Getting the Game ID for Dude Perfect.
# 9. Getting the Game ID for Duck Life: Space.
# 10. Getting the Game ID for Pool Break Pro 3D Billiards Snooker Carrom.
# 11. Getting the Game ID for OK Golf.
# 12. Getting the Game ID for Ice Fishing Derby Premium.
# 13. Getting the Game ID for MLB Manager 2018.
# 14. Getting the Game ID for College BBALL Coach.
# 15. Getting the Game ID for Pro Strategy Football 2018.
# 16. Getting the Game ID for Sumotori Dreams.
# 17. Getting the Game ID for R.B.I. Baseball 18.
# 18. Getting the Game ID for Pumped BMX 3.
# 19. Getting the Game ID for Home Run High.
# 20. Getting the Game ID for Desert Golfing.
# 21. Getting the Game ID for Pumped BMX 2.
# 22. Getting the Game ID for Flick Kick Field Goal.
# 23. Getting the Game ID for CN Superstar Soccer: Goal!!!.
# 24. Getting the Game ID for Duck Life: Retro Pack.
#  --
#    *** Getting information for games in the GAME_STRATEGY category. ***
#  --
# 0. Getting the Game ID for Bloons TD 6.
# 1. Getting the Game ID for Bloons TD 5.
# 2. Getting the Game ID for Kingdom Rush Vengeance.
# 3. Getting the Game ID for Papa's Freezeria To Go!.
# 4. Getting the Game ID for Rusted Warfare - RTS Strategy.
# 5. Getting the Game ID for The Escapists: Prison Escape.
# 6. Getting the Game ID for Five Nights at Freddy's 2.
# 7. Getting the Game ID for ROME: Total War.
# 8. Getting the Game ID for Age of Civilizations II.
# 9. Getting the Game ID for Civilization Revolution 2.
# 10. Getting the Game ID for First Strike: Final Hour.
# 11. Getting the Game ID for Papa's Scooperia To Go!.
# 12. Getting the Game ID for Kingdom Rush Frontiers.
# 13. Getting the Game ID for Papa's Burgeria To Go!.
# 14. Getting the Game ID for Dungeon Maker.
# 15. Getting the Game ID for XCOM®: Enemy Within.
# 16. Getting the Game ID for Papa's Pizzeria To Go!.
# 17. Getting the Game ID for Papa's Pancakeria To Go!.
# 18. Getting the Game ID for Uciana.
# 19. Getting the Game ID for Door Kickers.
# 20. Getting the Game ID for Kingdom Rush Origins.
# 21. Getting the Game ID for Papa's Taco Mia To Go!.
# 22. Getting the Game ID for Organ Trail: Director's Cut.
# 23. Getting the Game ID for Papa's Cupcakeria To Go!.
# 24. Getting the Game ID for Slay.
#  --
#    *** Getting information for games in the GAME_TRIVIA category. ***
#  --
# 0. Getting the Game ID for Trivia Crack (No Ads).
# 1. Getting the Game ID for Sporcle.
# 2. Getting the Game ID for BLeBRiTY.
# 3. Getting the Game ID for The 7 Second Challenge.
# 4. Getting the Game ID for Bible Bowl Prep 2019.
# 5. Getting the Game ID for The Jackbox Party Pack 3.
# 6. Getting the Game ID for The Jackbox Party Pack.
# 7. Getting the Game ID for The Jackbox Party Pack 5.
# 8. Getting the Game ID for Penny Dell Jumbo Crosswords.
# 9. Getting the Game ID for Quizoid Pro: Category Trivia with 5 Game modes.
# 10. Getting the Game ID for The Office Fan Quiz (No Ads).
# 11. Getting the Game ID for Wer Wird Millionär?.
# 12. Getting the Game ID for Pointless Quiz.
# 13. Getting the Game ID for HQ Trivia Helper Unlimited.
# 14. Getting the Game ID for IQ Test.
# 15. Getting the Game ID for The Jackbox Party Pack 4.
# 16. Getting the Game ID for The Black Card Game.
# 17. Getting the Game ID for Classic Rock Quiz (Ad Free).
# 18. Getting the Game ID for 4 Player Reactor (Multiplayer).
# 19. Getting the Game ID for The Jackbox Party Pack 2.
# 20. Getting the Game ID for Einstein™ Brain Training.
# 21. Getting the Game ID for Shopkins: Who's Next?.
# 22. Getting the Game ID for Lets get wasted 18+ ;).
# 23. Getting the Game ID for Just Riddles - Ad Free.
# 24. Getting the Game ID for Millionaire 2019 Quiz Premium.
#  --
#    *** Getting information for games in the GAME_WORD category. ***
#  --
# 0. Getting the Game ID for Word Games PRO - 61 in 1.
# 1. Getting the Game ID for Classic Words Plus.
# 2. Getting the Game ID for Wordfeud.
# 3. Getting the Game ID for Draw Something.
# 4. Getting the Game ID for Logic Puzzles - Brain Fun.
# 5. Getting the Game ID for Adult Charades!.
# 6. Getting the Game ID for Crossword.
# 7. Getting the Game ID for Word Master - Pro.
# 8. Getting the Game ID for Text Twister Pro 2018.
# 9. Getting the Game ID for CrossWords 10 Pro.
# 10. Getting the Game ID for Jumbline 2.
# 11. Getting the Game ID for Ruzzle.
# 12. Getting the Game ID for The Game Gal's Word Generator.
# 13. Getting the Game ID for Dropwords 2.
# 14. Getting the Game ID for Guess & Find PRO.
# 15. Getting the Game ID for GUESSTURES - Charades Game (No Ads).
# 16. Getting the Game ID for Spelling Words for 2nd Grade.
# 17. Getting the Game ID for Fill it ins crosswords PRO- no Ads, Word fit games.
# 18. Getting the Game ID for Acrostics Crossword Puzzles.
# 19. Getting the Game ID for Word Breaker Full.
# 20. Getting the Game ID for Word Fit Puzzle +.
# 21. Getting the Game ID for Word Chess PRO.
# 22. Getting the Game ID for Stories Gone Mad Full.
# 23. Getting the Game ID for Cryptic Crossword.
# 24. Getting the Game ID for 英雄坛说X.
#  --
# All done! The loop collected a total of 425 game titles.
#  --

# %%
print(len(game_list))
# Out:
# 425

# %%
# Empty lists to store the information we want
game_titles = []
game_scores = []
game_reviews = []
game_prices = []
game_installs = []
game_developers = []
game_urls = []

# Loops through the game id's that we gathered in the loop above and puts it into the lists we created 
i = 0
for game in game_list:
    game_details = gp.details(game_list[i])
    title_info = game_details['title']
    game_titles.append(title_info)
    game_scores.append(game_details['score'])
    game_reviews.append(game_details['reviews'])
    game_prices.append(game_details['price'])
    game_installs.append(game_details['installs'])
    game_developers.append(game_details['developer'])
    game_urls.append(game_details['url'])
    print(f'Getting information for {title_info}.')
    i += 1
print(f'All done! The loop processed a total of {len(game_titles)} results.')
# Out:
# Getting information for Grand Theft Auto: San Andreas.
# Getting information for Five Nights at Freddy's.
# Getting information for Hitman Sniper.
# Getting information for Five Nights at Freddy's: SL.
# Getting information for Assassin's Creed Identity.
# Getting information for Grand Theft Auto III.
# Getting information for Call of Duty:Black Ops Zombies.
# Getting information for Five Nights at Freddy's 4.
# Getting information for Space Marshals.
# Getting information for truTV Impractical Jokers Wheel of Doom.
# Getting information for Real Steel.
# Getting information for Downwell.
# Getting information for Teen Titans GO Figure!.
# Getting information for Five Nights at Freddy's 3.
# Getting information for Bloons Supermonkey 2.
# Getting information for GTA: Chinatown Wars.
# Getting information for Shadow of Death: Stickman Fighting - Dark Knight.
# Getting information for Bully: Anniversary Edition.
# Getting information for Zombieville USA 2.
# Getting information for LEGO ® Marvel Super Heroes.
# Getting information for PPSSPP Gold - PSP emulator.
# Getting information for BACKFIRE.
# Getting information for LEGO® Star Wars™:  TCS.
# Getting information for Battle of Vicksburg.
# Getting information for Oddworld: Stranger's Wrath.
# Getting information for Alien: Blackout.
# Getting information for Terraria..
# Getting information for Bendy and the Ink Machine.
# Getting information for THE GALAXY: SURVIVOR.
# Getting information for Don't Starve: Pocket Edition.
# Getting information for 60 Seconds! Atomic Adventure.
# Getting information for Live or Die: Survival Pro.
# Getting information for Portal Knights.
# Getting information for LEGO® Jurassic World™.
# Getting information for Octodad: Dadliest Catch.
# Getting information for Angry Neighbor.
# Getting information for Sonic Runners Adventure - Fast Action Platformer.
# Getting information for Crashlands.
# Getting information for Rusty Lake Hotel.
# Getting information for Castle of Illusion.
# Getting information for Bury me, my Love.
# Getting information for Rusty Lake: Roots.
# Getting information for Thickety Creek.
# Getting information for 7Days - Decide your story.
# Getting information for Draw a Stickman: EPIC 2.
# Getting information for GTA: Liberty City Stories.
# Getting information for Survivalcraft 2.
# Getting information for FINAL FANTASY IX for Android.
# Getting information for Rusty Lake Paradise.
# Getting information for CHUCHEL.
# Getting information for Minecraft.
# Getting information for Geometry Dash.
# Getting information for Ding Dong XL.
# Getting information for Grand Theft Auto: Vice City.
# Getting information for ePSXe for Android.
# Getting information for Fruit Ninja Classic.
# Getting information for My OldBoy! - GBC Emulator.
# Getting information for Pocket God™.
# Getting information for Max Payne Mobile.
# Getting information for Vector Full.
# Getting information for SuperRetro16 ( SNES Emulator ).
# Getting information for Peace, Death!.
# Getting information for Retro NES Pro - NES Emulator.
# Getting information for Retro N64 Pro - N64 Emulator.
# Getting information for Ms. PAC-MAN.
# Getting information for METAL SLUG 3.
# Getting information for The Impossible Game.
# Getting information for Worms 3.
# Getting information for PAC-MAN Championship Edition DX.
# Getting information for Fowlst.
# Getting information for Robot Unicorn Attack.
# Getting information for Ridiculous Fishing.
# Getting information for Marvel Pinball.
# Getting information for holedown.
# Getting information for Backflip Madness.
# Getting information for The Game of Life.
# Getting information for Clue.
# Getting information for Legends of Andor – The King’s Secret.
# Getting information for Ticket to Ride.
# Getting information for Catan Classic.
# Getting information for Carcassonne: Official Board Game -Tiles & Tactics.
# Getting information for Pandemic: The Board Game.
# Getting information for Chess.
# Getting information for Twice as clever.
# Getting information for Splendor.
# Getting information for Hasbro's BATTLESHIP.
# Getting information for Ganz schön clever.
# Getting information for Through the Ages.
# Getting information for D&D Lords of Waterdeep.
# Getting information for Race for the Galaxy.
# Getting information for Small World 2.
# Getting information for Backgammon.
# Getting information for Talisman.
# Getting information for Sentinels of the Multiverse.
# Getting information for Go.
# Getting information for Tokaido™.
# Getting information for Mysterium: A Psychic Clue Game.
# Getting information for Galaxy Trucker.
# Getting information for Smash Up - The Shufflebuilding Game.
# Getting information for Stratego® Single Player.
# Getting information for Exploding Kittens® - Official.
# Getting information for Reigns.
# Getting information for Skip-Bo™.
# Getting information for Card Wars - Adventure Time.
# Getting information for Reigns: Game of Thrones.
# Getting information for Solitaire+.
# Getting information for Reigns: Her Majesty.
# Getting information for Meteorfall: Journeys.
# Getting information for Blackbird.
# Getting information for Card Quest.
# Getting information for Decked Builder.
# Getting information for Phase 10.
# Getting information for Cribbage Pro Online!.
# Getting information for SET Mania.
# Getting information for Kemono Mahjong.
# Getting information for Spades.
# Getting information for Spider Solitaire+.
# Getting information for Patch Tarot.
# Getting information for Solitaire MegaPack.
# Getting information for Solitaire Collection Premium.
# Getting information for FreeCell Solitaire+.
# Getting information for Cribbage With Grandpas.
# Getting information for Gin Rummy.
# Getting information for PokerCruncher - Advanced - Poker Odds Calculator.
# Getting information for Munchkin Level Counter.
# Getting information for VIP Slots Club ★ VIP Casino.
# Getting information for Card Counter.
# Getting information for Craps Trainer Pro.
# Getting information for Top Money 💵 Slots (PREMIUM).
# Getting information for Pokertrainer.
# Getting information for Cleopatra Keno.
# Getting information for Ultimate X Poker.
# Getting information for Vintage Pachinko.
# Getting information for Blackjack Verite Games.
# Getting information for Cleopatra Keno.
# Getting information for Super Times Pay Poker.
# Getting information for MEGA Money Slots PAID.
# Getting information for Multi-Card Keno.
# Getting information for Wild West Faro.
# Getting information for Caveman Keno.
# Getting information for Scratch-a-Lotto Scratch Card Lottery PAID.
# Getting information for Fun Slot Machine Las Vegas Pro.
# Getting information for Zeus Epic Slots Machine Pro.
# Getting information for Crock O'Gold Rainbow Slots PAID.
# Getting information for Blackjack Verite Drills.
# Getting information for Learn Pro Blackjack Trainer - Casino Odds Strategy.
# Getting information for Roulette Statistics and Prediction - European.
# Getting information for Play Perfect Video Poker Pro+.
# Getting information for Baccarat Mastery Pro.
# Getting information for Carnival Fiesta Slots PAID.
# Getting information for Let's Create! Pottery.
# Getting information for Game Dev Story.
# Getting information for Tamagotchi Classic - Gen1.
# Getting information for Jazza's Arty Games.
# Getting information for Hidden Folks.
# Getting information for FINAL FANTASY.
# Getting information for Meme Soundboard PRO 2019.
# Getting information for My PlayHome : Play Home Doll House.
# Getting information for My PlayHome Hospital.
# Getting information for Little Inferno.
# Getting information for My PlayHome Stores.
# Getting information for Wedding Dash Deluxe.
# Getting information for My PlayHome School.
# Getting information for Fieldrunners 2.
# Getting information for Sand! Premium.
# Getting information for Fieldrunners HD.
# Getting information for SpongeBob Diner Dash Deluxe.
# Getting information for supertype.
# Getting information for SpongeBob's Game Frenzy.
# Getting information for Brink of Consciousness (Full).
# Getting information for Haunted Hotel: Death Sentence (Full).
# Getting information for Burger Shop 2 Deluxe.
# Getting information for Virtual Families.
# Getting information for Hotel Dash Deluxe.
# Getting information for Zip Zap.
# Getting information for Teach Your Monster to Read - Phonics and Reading.
# Getting information for Wonderland : Peter Pan.
# Getting information for Toca Blocks.
# Getting information for Toca Boo.
# Getting information for Explore Daniel's Neighborhood.
# Getting information for Toca Lab: Plants.
# Getting information for My Town : Hospital.
# Getting information for Learn to Read with Tommy Turtle.
# Getting information for My Town : Airport.
# Getting information for Peppa Pig: Holiday.
# Getting information for My City : Office.
# Getting information for Daniel Tiger's Stop & Go Potty.
# Getting information for Toca Mystery House.
# Getting information for My Town : Best Friends' House.
# Getting information for Second Grade Learning Games.
# Getting information for Wonderland : Little Mermaid.
# Getting information for BRIO World - Railway.
# Getting information for Dr. Panda Restaurant 2.
# Getting information for My City : Dentist visit.
# Getting information for Stack the States® 2.
# Getting information for My City : Home.
# Getting information for Numberblocks - Hide and Seek.
# Getting information for My Town : Grandparents.
# Getting information for My Town : School.
# Getting information for PAW Patrol Air and Sea Adventures.
# Getting information for Cytus II.
# Getting information for Incredibox.
# Getting information for Lowriders Comeback 2: Cruising.
# Getting information for Muse Dash.
# Getting information for Note Rush: Learn to Read Music.
# Getting information for Sonar Beat.
# Getting information for My Singing Monsters Composer.
# Getting information for Learn Music Notes.
# Getting information for Wonder Parade.
# Getting information for Piano Flashcards.
# Getting information for Drum Pad Beats.
# Getting information for Crayola DJ.
# Getting information for Black Metal Man.
# Getting information for Caustic 3.2 Techno Pack 3.
# Getting information for Note Fighter Unlimited.
# Getting information for Meow Music.
# Getting information for Learn Music Notes [Teacher Edition].
# Getting information for Caustic 3.2 Minimal Pack 2.
# Getting information for Dark Witch Music: Rudymical♪.
# Getting information for A Dance of Fire and Ice.
# Getting information for Hangman Beatles Trivia.
# Getting information for Beat Beat Vocaloid.
# Getting information for Die For Metal.
# Getting information for Caustic 3.2 Synth Elements Pack 4.
# Getting information for Melody Maker XD.
# Getting information for Scribblenauts Remix.
# Getting information for The Room.
# Getting information for Scribblenauts Unlimited.
# Getting information for The Room: Old Sins.
# Getting information for Florence.
# Getting information for Agent A: A puzzle in disguise.
# Getting information for The Room Two.
# Getting information for The House of Da Vinci.
# Getting information for The Room Three.
# Getting information for Monument Valley.
# Getting information for Bridge Constructor Portal.
# Getting information for Monument Valley 2.
# Getting information for Hitman GO.
# Getting information for Where's My Water?.
# Getting information for Lara Croft GO.
# Getting information for Doodle God™.
# Getting information for Doodle God™ HD.
# Getting information for Legacy 3 - The Hidden Relic.
# Getting information for Cut the Rope GOLD.
# Getting information for Human Resource Machine.
# Getting information for Doodle Devil™ HD.
# Getting information for Gorogoa.
# Getting information for Please, Don't Touch Anything.
# Getting information for Scalak.
# Getting information for Deus Ex GO.
# Getting information for Bike Race Pro by T. F. Games.
# Getting information for Real Drift Car Racing.
# Getting information for Earn to Die.
# Getting information for Need for Speed Most Wanted.
# Getting information for Rush Rally 2.
# Getting information for Riptide GP: Renegade.
# Getting information for Motorsport Manager Mobile 3.
# Getting information for TRAIL CLIMB.
# Getting information for Dirt Trackin.
# Getting information for PJ Masks: Racing Heroes.
# Getting information for Need for Speed Hot Pursuit.
# Getting information for Draw Rider Plus.
# Getting information for Bike Mayhem Mountain Racing.
# Getting information for Ricky Carmichael's Motocross.
# Getting information for Riptide GP2.
# Getting information for Dirt Trackin Sprint Cars.
# Getting information for Reckless Racing 3.
# Getting information for F1 2016.
# Getting information for Outlaws - Sprint Car Racing.
# Getting information for ULTRA4 Offroad Racing.
# Getting information for Drag Racing 3D.
# Getting information for Dirt Racing Mobile 3D.
# Getting information for Absolute Drift.
# Getting information for Riptide GP.
# Getting information for Jet Car Stunts.
# Getting information for Doom & Destiny Advanced.
# Getting information for Evoland.
# Getting information for Star Wars™: KOTOR.
# Getting information for EvoCreo.
# Getting information for Monster Hunter Stories.
# Getting information for Attack the Light.
# Getting information for Alter Ego.
# Getting information for Neverwinter Nights: Enhanced Edition.
# Getting information for FINAL FANTASY VII.
# Getting information for Doom & Destiny.
# Getting information for Baldur's Gate: Enhanced Edition.
# Getting information for CHRONO TRIGGER (Upgrade Ver.).
# Getting information for DRAGON QUEST.
# Getting information for Day R Premium.
# Getting information for 80 Days.
# Getting information for Evoland 2.
# Getting information for Rogue Hearts.
# Getting information for Pocket Rogues: Ultimate.
# Getting information for The Bard's Tale.
# Getting information for ICEY.
# Getting information for Battleheart Legacy.
# Getting information for A Dark Room ®.
# Getting information for Goat Simulator MMO Simulator.
# Getting information for Guild of Dungeoneering.
# Getting information for FINAL FANTASY VI.
# Getting information for Mini Metro.
# Getting information for Poly Bridge.
# Getting information for Game Dev Tycoon.
# Getting information for Farming Simulator 18.
# Getting information for Pocket City.
# Getting information for Goat Simulator.
# Getting information for FINAL FANTASY TACTICS : WotL.
# Getting information for Infinite Flight - Flight Simulator.
# Getting information for Project Highrise.
# Getting information for Getting Over It with Bennett Foddy.
# Getting information for Goat Simulator Payday.
# Getting information for Pocket Aquarium.
# Getting information for Youtubers Life: Gaming Channel.
# Getting information for Farming Simulator 16.
# Getting information for Goat Simulator Waste of Space.
# Getting information for One Hour One Life for Mobile.
# Getting information for Construction Simulator 2.
# Getting information for SimplePlanes.
# Getting information for Farming USA 2.
# Getting information for SPACEPLAN.
# Getting information for My Child Lebensborn.
# Getting information for Truck Simulator PRO 2.
# Getting information for Townsmen Premium.
# Getting information for 911 Operator.
# Getting information for Construction Simulator 2014.
# Getting information for NBA 2K19.
# Getting information for True Skate.
# Getting information for NBA JAM  by EA SPORTS™.
# Getting information for Football Manager 2019 Mobile.
# Getting information for WWE 2K.
# Getting information for Skater.
# Getting information for Clay Hunt PRO.
# Getting information for Flick Golf!.
# Getting information for Dude Perfect.
# Getting information for Duck Life: Space.
# Getting information for Pool Break Pro 3D Billiards Snooker Carrom.
# Getting information for OK Golf.
# Getting information for Ice Fishing Derby Premium.
# Getting information for MLB Manager 2018.
# Getting information for College BBALL Coach.
# Getting information for Pro Strategy Football 2018.
# Getting information for Sumotori Dreams.
# Getting information for R.B.I. Baseball 18.
# Getting information for Pumped BMX 3.
# Getting information for Home Run High.
# Getting information for Desert Golfing.
# Getting information for Pumped BMX 2.
# Getting information for Flick Kick Field Goal.
# Getting information for CN Superstar Soccer: Goal!!!.
# Getting information for Duck Life: Retro Pack.
# Getting information for Bloons TD 6.
# Getting information for Bloons TD 5.
# Getting information for Kingdom Rush Vengeance.
# Getting information for Papa's Freezeria To Go!.
# Getting information for Rusted Warfare - RTS Strategy.
# Getting information for The Escapists: Prison Escape.
# Getting information for Five Nights at Freddy's 2.
# Getting information for ROME: Total War.
# Getting information for Age of Civilizations II.
# Getting information for Civilization Revolution 2.
# Getting information for First Strike: Final Hour.
# Getting information for Papa's Scooperia To Go!.
# Getting information for Kingdom Rush Frontiers.
# Getting information for Papa's Burgeria To Go!.
# Getting information for Dungeon Maker.
# Getting information for XCOM®: Enemy Within.
# Getting information for Papa's Pizzeria To Go!.
# Getting information for Papa's Pancakeria To Go!.
# Getting information for Uciana.
# Getting information for Door Kickers.
# Getting information for Kingdom Rush Origins.
# Getting information for Papa's Taco Mia To Go!.
# Getting information for Organ Trail: Director's Cut.
# Getting information for Papa's Cupcakeria To Go!.
# Getting information for Slay.
# Getting information for Trivia Crack (No Ads).
# Getting information for Sporcle.
# Getting information for BLeBRiTY.
# Getting information for The 7 Second Challenge.
# Getting information for Bible Bowl Prep 2019.
# Getting information for The Jackbox Party Pack 3.
# Getting information for The Jackbox Party Pack.
# Getting information for The Jackbox Party Pack 5.
# Getting information for Penny Dell Jumbo Crosswords.
# Getting information for Quizoid Pro: Category Trivia with 5 Game modes.
# Getting information for The Office Fan Quiz (No Ads).
# Getting information for Wer Wird Millionär?.
# Getting information for Pointless Quiz.
# Getting information for HQ Trivia Helper Unlimited.
# Getting information for IQ Test.
# Getting information for The Jackbox Party Pack 4.
# Getting information for The Black Card Game.
# Getting information for Classic Rock Quiz (Ad Free).
# Getting information for 4 Player Reactor (Multiplayer).
# Getting information for The Jackbox Party Pack 2.
# Getting information for Einstein™ Brain Training.
# Getting information for Shopkins: Who's Next?.
# Getting information for Lets get wasted 18+ ;).
# Getting information for Just Riddles - Ad Free.
# Getting information for Millionaire 2019 Quiz Premium.
# Getting information for Word Games PRO - 61 in 1.
# Getting information for Classic Words Plus.
# Getting information for Wordfeud.
# Getting information for Draw Something.
# Getting information for Logic Puzzles - Brain Fun.
# Getting information for Adult Charades!.
# Getting information for Crossword.
# Getting information for Word Master - Pro.
# Getting information for Text Twister Pro 2018.
# Getting information for CrossWords 10 Pro.
# Getting information for Jumbline 2.
# Getting information for Ruzzle.
# Getting information for The Game Gal's Word Generator.
# Getting information for Dropwords 2.
# Getting information for Guess & Find PRO.
# Getting information for GUESSTURES - Charades Game (No Ads).
# Getting information for Spelling Words for 2nd Grade.
# Getting information for Fill it ins crosswords PRO- no Ads, Word fit games.
# Getting information for Acrostics Crossword Puzzles.
# Getting information for Word Breaker Full.
# Getting information for Word Fit Puzzle +.
# Getting information for Word Chess PRO.
# Getting information for Stories Gone Mad Full.
# Getting information for Cryptic Crossword.
# Getting information for 英雄坛说X.
# All done! The loop processed a total of 425 results.

# %%
# Combines the lists above into a nice, tidy data frame
games_master = {
    "Game Title": game_titles,
    "Game Category": game_category,
    "Game Score": game_scores,
    "Number of Reviews": game_reviews,
    "Price": game_prices,
    "Number of Installs": game_installs,
    "Developer": game_developers,
    "Play Store URL": game_urls
    
}
games_df = pd.DataFrame(games_master)
games_df.head(50)
# Out:
#                                           Game Title   Game Category  \
# 0                      Grand Theft Auto: San Andreas     GAME_ACTION
# 1                            Five Nights at Freddy's     GAME_ACTION
# 2                                      Hitman Sniper     GAME_ACTION
# 3                        Five Nights at Freddy's: SL     GAME_ACTION
# 4                          Assassin's Creed Identity     GAME_ACTION
# 5                               Grand Theft Auto III     GAME_ACTION
# 6                     Call of Duty:Black Ops Zombies     GAME_ACTION
# 7                          Five Nights at Freddy's 4     GAME_ACTION
# 8                                     Space Marshals     GAME_ACTION
# 9             truTV Impractical Jokers Wheel of Doom     GAME_ACTION
# 10                                        Real Steel     GAME_ACTION
# 11                                          Downwell     GAME_ACTION
# 12                            Teen Titans GO Figure!     GAME_ACTION
# 13                         Five Nights at Freddy's 3     GAME_ACTION
# 14                              Bloons Supermonkey 2     GAME_ACTION
# 15                               GTA: Chinatown Wars     GAME_ACTION
# 16  Shadow of Death: Stickman Fighting - Dark Knight     GAME_ACTION
# 17                        Bully: Anniversary Edition     GAME_ACTION
# 18                                 Zombieville USA 2     GAME_ACTION
# 19                        LEGO ® Marvel Super Heroes     GAME_ACTION
# 20                        PPSSPP Gold - PSP emulator     GAME_ACTION
# 21                                          BACKFIRE     GAME_ACTION
# 22                            LEGO® Star Wars™:  TCS     GAME_ACTION
# 23                               Battle of Vicksburg     GAME_ACTION
# 24                        Oddworld: Stranger's Wrath     GAME_ACTION
# 25                                   Alien: Blackout  GAME_ADVENTURE
# 26                                         Terraria.  GAME_ADVENTURE
# 27                         Bendy and the Ink Machine  GAME_ADVENTURE
# 28                              THE GALAXY: SURVIVOR  GAME_ADVENTURE
# 29                      Don't Starve: Pocket Edition  GAME_ADVENTURE
# 30                      60 Seconds! Atomic Adventure  GAME_ADVENTURE
# 31                         Live or Die: Survival Pro  GAME_ADVENTURE
# 32                                    Portal Knights  GAME_ADVENTURE
# 33                             LEGO® Jurassic World™  GAME_ADVENTURE
# 34                           Octodad: Dadliest Catch  GAME_ADVENTURE
# 35                                    Angry Neighbor  GAME_ADVENTURE
# 36  Sonic Runners Adventure - Fast Action Platformer  GAME_ADVENTURE
# 37                                        Crashlands  GAME_ADVENTURE
# 38                                  Rusty Lake Hotel  GAME_ADVENTURE
# 39                                Castle of Illusion  GAME_ADVENTURE
# 40                                  Bury me, my Love  GAME_ADVENTURE
# 41                                 Rusty Lake: Roots  GAME_ADVENTURE
# 42                                    Thickety Creek  GAME_ADVENTURE
# 43                         7Days - Decide your story  GAME_ADVENTURE
# 44                           Draw a Stickman: EPIC 2  GAME_ADVENTURE
# 45                         GTA: Liberty City Stories  GAME_ADVENTURE
# 46                                   Survivalcraft 2  GAME_ADVENTURE
# 47                      FINAL FANTASY IX for Android  GAME_ADVENTURE
# 48                               Rusty Lake Paradise  GAME_ADVENTURE
# 49                                           CHUCHEL  GAME_ADVENTURE
#
#    Game Score  Number of Reviews   Price Number of Installs  \
# 0         4.3             387549   $6.99         1,000,000+
# 1         4.6             103812   $2.99         1,000,000+
# 2         4.6             591529   $0.99        10,000,000+
# 3         4.5              17345   $2.99           100,000+
# 4         3.8              49980   $1.99           500,000+
# 5         4.0              96654   $4.99         1,000,000+
# 6         4.2              13999   $6.99           100,000+
# 7         4.6              21568   $2.99           100,000+
# 8         4.8               7894   $0.99            50,000+
# 9         4.3                161   $2.99             5,000+
# 10        4.1              26187   $0.99           500,000+
# 11        4.7               4559   $2.99           100,000+
# 12        4.5               4561   $3.99            50,000+
# 13        4.7              28213   $2.99           100,000+
# 14        4.6              15580   $0.99           500,000+
# 15        4.3              25395   $4.99           100,000+
# 16        4.6              58893   $0.99         1,000,000+
# 17        4.5              13466   $6.99           100,000+
# 18        4.6               1393   $0.99            50,000+
# 19        4.1              16454   $4.99           100,000+
# 20        4.3              11149   $4.99           100,000+
# 21        4.9                 23   $2.99               100+
# 22        3.7              16798   $6.99           100,000+
# 23        4.1                466   $0.99             5,000+
# 24        4.5              28587   $2.99           100,000+
# 25        4.0                372   $4.99             5,000+
# 26        4.3             231311   $4.99         1,000,000+
# 27        4.2               1069   $6.99            10,000+
# 28        4.3               3260   $1.49            10,000+
# 29        4.4              22296   $4.99           500,000+
# 30        3.9               5719   $3.99           100,000+
# 31        4.2              19180   $0.99         1,000,000+
# 32        4.3               5571   $4.99            50,000+
# 33        4.4              13688   $4.99           100,000+
# 34        4.4               4421   $4.99           100,000+
# 35        4.4               2876   $1.49            50,000+
# 36        4.6               4521   $2.99            50,000+
# 37        4.8              13216   $6.99           100,000+
# 38        4.8               8999   $1.99           100,000+
# 39        4.2              36578   $4.99           500,000+
# 40        4.4                752   $2.99            10,000+
# 41        4.9               8172   $2.99           100,000+
# 42        4.5                 73   $2.99             1,000+
# 43        4.8               1051   $2.99            10,000+
# 44        4.4               5445   $1.99           100,000+
# 45        4.4              10203   $6.99            50,000+
# 46        4.5               5423   $3.99           100,000+
# 47        4.4               7405  $20.99           100,000+
# 48        4.8               4106   $2.99            50,000+
# 49        4.3                594   $4.99            10,000+
#
#                                           Developer  \
# 0                                    Rockstar Games
# 1                                     Scott Cawthon
# 2                                   SQUARE ENIX Ltd
# 3                                     Scott Cawthon
# 4                             Ubisoft Entertainment
# 5                                    Rockstar Games
# 6                       Activision Publishing, Inc.
# 7                                     Scott Cawthon
# 8                                         Pixelbite
# 9                                      truTVnetwork
# 10  Reliance Big Entertainment (UK) Private Limited
# 11                                  DevolverDigital
# 12                                  Cartoon Network
# 13                                    Scott Cawthon
# 14                                       ninja kiwi
# 15                                   Rockstar Games
# 16                               Zonmob Game Studio
# 17                                   Rockstar Games
# 18                                      Mika Mobile
# 19           Warner Bros. International Enterprises
# 20                                   Henrik Rydgård
# 21                                        GRYN SQYD
# 22           Warner Bros. International Enterprises
# 23                                 Thorium Game Lab
# 24                         Oddworld Inhabitants Inc
# 25                                           D3 Go!
# 26                                    505 Games Srl
# 27                                Joey Drew Studios
# 28                                  Invictus Studio
# 29                          Klei Entertainment Inc.
# 30                                  Robot Gentleman
# 31                          PRIDEGAMESSTUDIO OU PLC
# 32                                    505 Games Srl
# 33           Warner Bros. International Enterprises
# 34                                     Young Horses
# 35                                  Invictus Studio
# 36                                         Gameloft
# 37                         Butterscotch Shenanigans
# 38                                       Rusty Lake
# 39                                           Disney
# 40                                         Playdius
# 41                                       Rusty Lake
# 42                            Fire Maple Games, LLC
# 43                             Buff Studio Co.,Ltd.
# 44                                         Hitcents
# 45                                   Rockstar Games
# 46                                Candy Rufus Games
# 47                             SQUARE ENIX Co.,Ltd.
# 48                                       Rusty Lake
# 49                                   Amanita Design
#
#                                        Play Store URL
# 0   https://play.google.com/store/apps/details?id=...
# 1   https://play.google.com/store/apps/details?id=...
# 2   https://play.google.com/store/apps/details?id=...
# 3   https://play.google.com/store/apps/details?id=...
# 4   https://play.google.com/store/apps/details?id=...
# 5   https://play.google.com/store/apps/details?id=...
# 6   https://play.google.com/store/apps/details?id=...
# 7   https://play.google.com/store/apps/details?id=...
# 8   https://play.google.com/store/apps/details?id=...
# 9   https://play.google.com/store/apps/details?id=...
# 10  https://play.google.com/store/apps/details?id=...
# 11  https://play.google.com/store/apps/details?id=...
# 12  https://play.google.com/store/apps/details?id=...
# 13  https://play.google.com/store/apps/details?id=...
# 14  https://play.google.com/store/apps/details?id=...
# 15  https://play.google.com/store/apps/details?id=...
# 16  https://play.google.com/store/apps/details?id=...
# 17  https://play.google.com/store/apps/details?id=...
# 18  https://play.google.com/store/apps/details?id=...
# 19  https://play.google.com/store/apps/details?id=...
# 20  https://play.google.com/store/apps/details?id=...
# 21  https://play.google.com/store/apps/details?id=...
# 22  https://play.google.com/store/apps/details?id=...
# 23  https://play.google.com/store/apps/details?id=...
# 24  https://play.google.com/store/apps/details?id=...
# 25  https://play.google.com/store/apps/details?id=...
# 26  https://play.google.com/store/apps/details?id=...
# 27  https://play.google.com/store/apps/details?id=...
# 28  https://play.google.com/store/apps/details?id=...
# 29  https://play.google.com/store/apps/details?id=...
# 30  https://play.google.com/store/apps/details?id=...
# 31  https://play.google.com/store/apps/details?id=...
# 32  https://play.google.com/store/apps/details?id=...
# 33  https://play.google.com/store/apps/details?id=...
# 34  https://play.google.com/store/apps/details?id=...
# 35  https://play.google.com/store/apps/details?id=...
# 36  https://play.google.com/store/apps/details?id=...
# 37  https://play.google.com/store/apps/details?id=...
# 38  https://play.google.com/store/apps/details?id=...
# 39  https://play.google.com/store/apps/details?id=...
# 40  https://play.google.com/store/apps/details?id=...
# 41  https://play.google.com/store/apps/details?id=...
# 42  https://play.google.com/store/apps/details?id=...
# 43  https://play.google.com/store/apps/details?id=...
# 44  https://play.google.com/store/apps/details?id=...
# 45  https://play.google.com/store/apps/details?id=...
# 46  https://play.google.com/store/apps/details?id=...
# 47  https://play.google.com/store/apps/details?id=...
# 48  https://play.google.com/store/apps/details?id=...
# 49  https://play.google.com/store/apps/details?id=...

# %%
# check the data types
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425 entries, 0 to 424
# Data columns (total 8 columns):
# Game Title            425 non-null object
# Game Category         425 non-null object
# Game Score            420 non-null object
# Number of Reviews     425 non-null int64
# Price                 425 non-null object
# Number of Installs    425 non-null object
# Developer             425 non-null object
# Play Store URL        425 non-null object
# dtypes: int64(1), object(7)
# memory usage: 26.6+ KB

# %%
# Cleans up and formats the data
games_df['Number of Installs'] = games_df['Number of Installs'].str.replace('+', '')
games_df['Number of Installs'] = games_df['Number of Installs'].str.replace(',', '')
games_df['Number of Installs'] = pd.to_numeric(games_df['Number of Installs'], errors='coerce')
games_df['Game Score'] = pd.to_numeric(games_df['Game Score'], errors='coerce')
games_df['Price'] = games_df['Price'].str.replace('$', '')
games_df['Price'] = pd.to_numeric(games_df['Price'], errors='coerce')
games_df.head()
# Out:
#                       Game Title Game Category  Game Score  Number of Reviews  \
# 0  Grand Theft Auto: San Andreas   GAME_ACTION         4.3             387549
# 1        Five Nights at Freddy's   GAME_ACTION         4.6             103812
# 2                  Hitman Sniper   GAME_ACTION         4.6             591529
# 3    Five Nights at Freddy's: SL   GAME_ACTION         4.5              17345
# 4      Assassin's Creed Identity   GAME_ACTION         3.8              49980
#
#    Price  Number of Installs              Developer  \
# 0   6.99             1000000         Rockstar Games
# 1   2.99             1000000          Scott Cawthon
# 2   0.99            10000000        SQUARE ENIX Ltd
# 3   2.99              100000          Scott Cawthon
# 4   1.99              500000  Ubisoft Entertainment
#
#                                       Play Store URL
# 0  https://play.google.com/store/apps/details?id=...
# 1  https://play.google.com/store/apps/details?id=...
# 2  https://play.google.com/store/apps/details?id=...
# 3  https://play.google.com/store/apps/details?id=...
# 4  https://play.google.com/store/apps/details?id=...

# %%
games_df["Total Download Revenue ($)"] = games_df["Price"]*games_df["Number of Installs"]

# %%
games_df.dtypes
# Out:
# Game Title                     object
# Game Category                  object
# Game Score                    float64
# Number of Reviews               int64
# Price                         float64
# Number of Installs              int64
# Developer                      object
# Play Store URL                 object
# Total Download Revenue ($)    float64
# dtype: object

# %%
#segregating the data by category from main DF

arcade_game = games_df.loc[games_df["Game Category"]=="GAME_ARCADE"]
sports_game = games_df.loc[games_df["Game Category"]=="GAME_SPORTS"]
racing_game = games_df.loc[games_df["Game Category"]=="GAME_RACING"]
music_game = games_df.loc[games_df["Game Category"]=="GAME_MUSIC"]
educational_game = games_df.loc[games_df["Game Category"]== "GAME_EDUCATIONAL"]
board_game = games_df.loc[games_df["Game Category"]=="GAME_BOARD"]
casino_game = games_df.loc[games_df["Game Category"]=="GAME_CASINO"]
action_game = games_df.loc[games_df["Game Category"]=="GAME_ACTION"]
trivia_game = games_df.loc[games_df["Game Category"]=="GAME_TRIVIA"]
simulation_game = games_df.loc[games_df["Game Category"]=="GAME_SIMULATION"]
adventure_game = games_df.loc[games_df["Game Category"]=="GAME_ADVENTURE"]
puzzle_game = games_df.loc[games_df["Game Category"]=="GAME_PUZZLE"]
card_game = games_df.loc[games_df["Game Category"]=="GAME_CARD"]
casual_game = games_df.loc[games_df["Game Category"]=="GAME_CASUAL"]
strategy_game = games_df.loc[games_df["Game Category"]=="GAME_STRATEGY"]                       
roleplay_game = games_df.loc[games_df["Game Category"]=="GAME_ROLE_PLAYING"]
word_game = games_df.loc[games_df["Game Category"]=="GAME_WORD"]

# %%
# Although action game and arcade games receive similar amount of dls, arcade games receives 3x of
# total revenue. Therefore, based on the finding from Greg's group_sums and game_inst_sums DFs,
# it appears arcade_game generates most of the revenue out of all sub-catergories. The analysis from here will be
# focusing on arcade catergory only.

arcade_game = arcade_game.sort_values(by='Total Download Revenue ($)', ascending=False)

# %%
arcade_game
# Out:
#                          Game Title Game Category  Game Score  \
# 50                        Minecraft   GAME_ARCADE         4.5
# 67                          Worms 3   GAME_ARCADE         4.2
# 53      Grand Theft Auto: Vice City   GAME_ARCADE         4.3
# 60   SuperRetro16 ( SNES Emulator )   GAME_ARCADE         4.3
# 51                    Geometry Dash   GAME_ARCADE         4.8
# 54                ePSXe for Android   GAME_ARCADE         4.5
# 55              Fruit Ninja Classic   GAME_ARCADE         4.3
# 59                      Vector Full   GAME_ARCADE         4.2
# 66              The Impossible Game   GAME_ARCADE         4.1
# 74                 Backflip Madness   GAME_ARCADE         4.3
# 57                      Pocket God™   GAME_ARCADE         3.7
# 64                      Ms. PAC-MAN   GAME_ARCADE         4.3
# 56        My OldBoy! - GBC Emulator   GAME_ARCADE         4.6
# 58                 Max Payne Mobile   GAME_ARCADE         4.2
# 65                     METAL SLUG 3   GAME_ARCADE         3.7
# 71               Ridiculous Fishing   GAME_ARCADE         4.5
# 61                    Peace, Death!   GAME_ARCADE         4.7
# 70             Robot Unicorn Attack   GAME_ARCADE         3.9
# 72                   Marvel Pinball   GAME_ARCADE         3.9
# 73                         holedown   GAME_ARCADE         4.5
# 68  PAC-MAN Championship Edition DX   GAME_ARCADE         4.5
# 52                     Ding Dong XL   GAME_ARCADE         4.8
# 69                           Fowlst   GAME_ARCADE         4.8
# 63     Retro N64 Pro - N64 Emulator   GAME_ARCADE         4.5
# 62     Retro NES Pro - NES Emulator   GAME_ARCADE         4.7
#
#     Number of Reviews  Price  Number of Installs  \
# 50            2594843   6.99            10000000
# 67              67900   4.99             1000000
# 53             132070   4.99             1000000
# 60              38553   3.99             1000000
# 51             651321   1.99             1000000
# 54              35051   3.75              500000
# 55              85893   0.99             1000000
# 59              35915   0.99              500000
# 66              19824   0.99              500000
# 74              26427   0.99              500000
# 57              30427   0.99              500000
# 64               5519   3.99              100000
# 56               5104   3.99              100000
# 58              31033   2.99              100000
# 65              14165   2.99              100000
# 71              13836   2.49              100000
# 61               5556   0.99              100000
# 70              11348   0.99              100000
# 72               8500   0.99              100000
# 73                387   3.99               10000
# 68               1887   1.99               10000
# 52                144   0.99                5000
# 69                142   0.99                5000
# 63                167   2.99                1000
# 62                191   2.99                1000
#
#                                   Developer  \
# 50                                   Mojang
# 67                  Team 17 Digital Limited
# 53                           Rockstar Games
# 60                        Neutron Emulation
# 51                             RobTop Games
# 54                      epsxe software s.l.
# 55                        Halfbrick Studios
# 59                                    NEKKI
# 66                                FlukeDude
# 74                          Gamesoul Studio
# 57                       Bolt Creative, Inc
# 64  BANDAI NAMCO Entertainment America Inc.
# 56                            Fast Emulator
# 58                           Rockstar Games
# 65                          SNK CORPORATION
# 71                                 Vlambeer
# 61                                AZAMATIKA
# 70                       [adult swim] games
# 72                              Zen Studios
# 73                         grapefrukt games
# 68  BANDAI NAMCO Entertainment America Inc.
# 52                     Nickervision Studios
# 69                           Thomas K Young
# 63                     Retro Game Emulators
# 62                     Retro Game Emulators
#
#                                        Play Store URL  \
# 50  https://play.google.com/store/apps/details?id=...
# 67  https://play.google.com/store/apps/details?id=...
# 53  https://play.google.com/store/apps/details?id=...
# 60  https://play.google.com/store/apps/details?id=...
# 51  https://play.google.com/store/apps/details?id=...
# 54  https://play.google.com/store/apps/details?id=...
# 55  https://play.google.com/store/apps/details?id=...
# 59  https://play.google.com/store/apps/details?id=...
# 66  https://play.google.com/store/apps/details?id=...
# 74  https://play.google.com/store/apps/details?id=...
# 57  https://play.google.com/store/apps/details?id=...
# 64  https://play.google.com/store/apps/details?id=...
# 56  https://play.google.com/store/apps/details?id=...
# 58  https://play.google.com/store/apps/details?id=...
# 65  https://play.google.com/store/apps/details?id=...
# 71  https://play.google.com/store/apps/details?id=...
# 61  https://play.google.com/store/apps/details?id=...
# 70  https://play.google.com/store/apps/details?id=...
# 72  https://play.google.com/store/apps/details?id=...
# 73  https://play.google.com/store/apps/details?id=...
# 68  https://play.google.com/store/apps/details?id=...
# 52  https://play.google.com/store/apps/details?id=...
# 69  https://play.google.com/store/apps/details?id=...
# 63  https://play.google.com/store/apps/details?id=...
# 62  https://play.google.com/store/apps/details?id=...
#
#     Total Download Revenue ($)
# 50                  69900000.0
# 67                   4990000.0
# 53                   4990000.0
# 60                   3990000.0
# 51                   1990000.0
# 54                   1875000.0
# 55                    990000.0
# 59                    495000.0
# 66                    495000.0
# 74                    495000.0
# 57                    495000.0
# 64                    399000.0
# 56                    399000.0
# 58                    299000.0
# 65                    299000.0
# 71                    249000.0
# 61                     99000.0
# 70                     99000.0
# 72                     99000.0
# 73                     39900.0
# 68                     19900.0
# 52                      4950.0
# 69                      4950.0
# 63                      2990.0
# 62                      2990.0

# %%
#bar cart by revenue.
tick_location = np.arange(len(arcade_game))
plt.bar(tick_location,arcade_game["Total Download Revenue ($)"], align="center")
plt.xticks(tick_location,arcade_game["Game Title"], rotation=90)
plt.xticks()
plt.title("Revenues Generated from Top 25 Paid Arcade Games")
plt.xlim(-1, len(arcade_game)-1)
plt.ylim(0,max(arcade_game["Total Download Revenue ($)"]+5000000))
plt.ylabel("Total Download Revenue (million)")
plt.tight_layout()

# %%
#bar cart by # of dl.
tick_location = np.arange(len(arcade_game))
plt.bar(tick_location,arcade_game["Number of Installs"], align="center")
plt.xticks(tick_location,arcade_game["Game Title"], rotation=90)
plt.xlim(-1, len(arcade_game)-1)
plt.ylim(0,max(arcade_game["Number of Installs"]+500000))
plt.ylabel("Number of Installs (10 millions)")
plt.title("Number of Download of Top 25 Paid Arcade Games")
plt.tight_layout()

# %%
# in comparsion, let's extract 3 top paid games from each catergory
top_games = games_df.groupby('Game Category', group_keys=False).apply(lambda x: x.nlargest(3, 'Total Download Revenue ($)'))

# %%
top_games = top_games.sort_values(by='Total Download Revenue ($)', ascending=False)
top_games
# Out:
#                                            Game Title      Game Category  \
# 50                                          Minecraft        GAME_ARCADE
# 2                                       Hitman Sniper        GAME_ACTION
# 0                       Grand Theft Auto: San Andreas        GAME_ACTION
# 305                                    Goat Simulator    GAME_SIMULATION
# 53                        Grand Theft Auto: Vice City        GAME_ARCADE
# 67                                            Worms 3        GAME_ARCADE
# 26                                          Terraria.     GAME_ADVENTURE
# 5                                Grand Theft Auto III        GAME_ACTION
# 253                        Need for Speed Most Wanted        GAME_RACING
# 234                                   Monument Valley        GAME_PUZZLE
# 375                             Trivia Crack (No Ads)        GAME_TRIVIA
# 351                                       Bloons TD 5      GAME_STRATEGY
# 103                        Card Wars - Adventure Time          GAME_CARD
# 403                                    Draw Something          GAME_WORD
# 307                Infinite Flight - Flight Simulator    GAME_SIMULATION
# 350                                       Bloons TD 6      GAME_STRATEGY
# 327                            NBA JAM  by EA SPORTS™        GAME_SPORTS
# 303                              Farming Simulator 18    GAME_SIMULATION
# 411                                            Ruzzle          GAME_WORD
# 79                                      Catan Classic         GAME_BOARD
# 39                                 Castle of Illusion     GAME_ADVENTURE
# 29                       Don't Starve: Pocket Edition     GAME_ADVENTURE
# 233                                    The Room Three        GAME_PUZZLE
# 231                                      The Room Two        GAME_PUZZLE
# 326                                        True Skate        GAME_SPORTS
# 299                                  FINAL FANTASY VI  GAME_ROLE_PLAYING
# 283                                 FINAL FANTASY VII  GAME_ROLE_PLAYING
# 293                                   The Bard's Tale  GAME_ROLE_PLAYING
# 356                         Five Nights at Freddy's 2      GAME_STRATEGY
# 101                                            Reigns          GAME_CARD
# 75                                   The Game of Life         GAME_BOARD
# 252                                       Earn to Die        GAME_RACING
# 151                                    Game Dev Story        GAME_CASUAL
# 264                                       Riptide GP2        GAME_RACING
# 155                                     FINAL FANTASY        GAME_CASUAL
# 328                      Football Manager 2019 Mobile        GAME_SPORTS
# 402                                          Wordfeud          GAME_WORD
# 175  Teach Your Monster to Read - Phonics and Reading   GAME_EDUCATIONAL
# 150                             Let's Create! Pottery        GAME_CASUAL
# 111                                          Phase 10          GAME_CARD
# 78                                     Ticket to Ride         GAME_BOARD
# 199                 PAW Patrol Air and Sea Adventures   GAME_EDUCATIONAL
# 177                                       Toca Blocks   GAME_EDUCATIONAL
# 201                                        Incredibox         GAME_MUSIC
# 200                                          Cytus II         GAME_MUSIC
# 203                                         Muse Dash         GAME_MUSIC
# 386                               Wer Wird Millionär?        GAME_TRIVIA
# 393                    4 Player Reactor (Multiplayer)        GAME_TRIVIA
# 127                                 Craps Trainer Pro        GAME_CASINO
# 133                            Blackjack Verite Games        GAME_CASINO
# 134                                    Cleopatra Keno        GAME_CASINO
#
#      Game Score  Number of Reviews  Price  Number of Installs  \
# 50          4.5            2594843   6.99            10000000
# 2           4.6             591529   0.99            10000000
# 0           4.3             387549   6.99             1000000
# 305         4.3             100965   4.99             1000000
# 53          4.3             132070   4.99             1000000
# 67          4.2              67900   4.99             1000000
# 26          4.3             231311   4.99             1000000
# 5           4.0              96654   4.99             1000000
# 253         3.9              44740   4.99             1000000
# 234         4.8             208408   3.99             1000000
# 375         4.5              61192   5.99              500000
# 351         4.6             192819   2.99             1000000
# 103         4.3             130148   2.99             1000000
# 403         4.0              83901   2.99             1000000
# 307         4.3              57411   4.99              500000
# 350         4.7              47983   4.99              500000
# 327         4.3              56776   4.99              500000
# 303         4.5              25211   4.99              500000
# 411         4.4              37556   4.99              500000
# 79          3.9              25434   4.99              500000
# 39          4.2              36578   4.99              500000
# 29          4.4              22296   4.99              500000
# 233         4.9              86704   3.99              500000
# 231         4.9             201955   1.99             1000000
# 326         4.4             134269   1.99             1000000
# 299         4.4              24658  15.99              100000
# 283         3.3               7327  15.99              100000
# 293         4.6              68763   2.99              500000
# 356         4.6              75319   2.99              500000
# 101         4.7             142471   2.99              500000
# 75          4.4              23453   2.99              500000
# 252         4.5              78898   1.49             1000000
# 151         4.6              61929   2.49              500000
# 264         4.6              37226   1.99              500000
# 155         3.9               7732   7.99              100000
# 328         4.0               7529   6.99              100000
# 402         4.6              79797   4.99              100000
# 175         4.4                784   4.99              100000
# 150         4.6              27517   4.99              100000
# 111         4.2              35681   4.99              100000
# 78          4.2              12723   4.99              100000
# 199         3.9               1997   3.99              100000
# 177         4.4               5876   3.99              100000
# 201         4.8               4581   3.99               50000
# 200         4.7              28458   1.99              100000
# 203         4.7               7435   2.99               50000
# 386         3.9               1249   2.49               50000
# 393         4.7               4375   2.49               50000
# 127         4.0                340   4.99               10000
# 133         4.2                 23  34.99                 500
# 134         4.5                671   1.99                5000
#
#                                   Developer  \
# 50                                   Mojang
# 2                           SQUARE ENIX Ltd
# 0                            Rockstar Games
# 305                 Coffee Stain Publishing
# 53                           Rockstar Games
# 67                  Team 17 Digital Limited
# 26                            505 Games Srl
# 5                            Rockstar Games
# 253                         ELECTRONIC ARTS
# 234                             ustwo games
# 375                                 Etermax
# 351                              ninja kiwi
# 103                         Cartoon Network
# 403                                   Zynga
# 307                     Infinite Flight LLC
# 350                              ninja kiwi
# 327                         ELECTRONIC ARTS
# 303                         GIANTS Software
# 411                         MAG Interactive
# 79                                      USM
# 39                                   Disney
# 29                  Klei Entertainment Inc.
# 233                         Fireproof Games
# 231                         Fireproof Games
# 326                               True Axis
# 299                    SQUARE ENIX Co.,Ltd.
# 283                    SQUARE ENIX Co.,Ltd.
# 293                    inXile entertainment
# 356                           Scott Cawthon
# 101                         DevolverDigital
# 75                    Marmalade Game Studio
# 252                             Not Doppler
# 151                       Kairosoft Co.,Ltd
# 264                             Vector Unit
# 155                    SQUARE ENIX Co.,Ltd.
# 328                                    SEGA
# 402                          Bertheussen IT
# 175             Teach Monster Games Limited
# 150                         Infinite Dreams
# 111                              Magmic Inc
# 78                          Asmodee Digital
# 199                             Nickelodeon
# 177                               Toca Boca
# 201                          So Far So Good
# 200            Rayark International Limited
# 203                            X.D. Network
# 386  Sony Pictures Television UK Rights Ltd
# 393                       cool cherry trees
# 127                           E7Systems.com
# 133              QFIT (Norman Wattenberger)
# 134                           Game Lab Apps
#
#                                         Play Store URL  \
# 50   https://play.google.com/store/apps/details?id=...
# 2    https://play.google.com/store/apps/details?id=...
# 0    https://play.google.com/store/apps/details?id=...
# 305  https://play.google.com/store/apps/details?id=...
# 53   https://play.google.com/store/apps/details?id=...
# 67   https://play.google.com/store/apps/details?id=...
# 26   https://play.google.com/store/apps/details?id=...
# 5    https://play.google.com/store/apps/details?id=...
# 253  https://play.google.com/store/apps/details?id=...
# 234  https://play.google.com/store/apps/details?id=...
# 375  https://play.google.com/store/apps/details?id=...
# 351  https://play.google.com/store/apps/details?id=...
# 103  https://play.google.com/store/apps/details?id=...
# 403  https://play.google.com/store/apps/details?id=...
# 307  https://play.google.com/store/apps/details?id=...
# 350  https://play.google.com/store/apps/details?id=...
# 327  https://play.google.com/store/apps/details?id=...
# 303  https://play.google.com/store/apps/details?id=...
# 411  https://play.google.com/store/apps/details?id=...
# 79   https://play.google.com/store/apps/details?id=...
# 39   https://play.google.com/store/apps/details?id=...
# 29   https://play.google.com/store/apps/details?id=...
# 233  https://play.google.com/store/apps/details?id=...
# 231  https://play.google.com/store/apps/details?id=...
# 326  https://play.google.com/store/apps/details?id=...
# 299  https://play.google.com/store/apps/details?id=...
# 283  https://play.google.com/store/apps/details?id=...
# 293  https://play.google.com/store/apps/details?id=...
# 356  https://play.google.com/store/apps/details?id=...
# 101  https://play.google.com/store/apps/details?id=...
# 75   https://play.google.com/store/apps/details?id=...
# 252  https://play.google.com/store/apps/details?id=...
# 151  https://play.google.com/store/apps/details?id=...
# 264  https://play.google.com/store/apps/details?id=...
# 155  https://play.google.com/store/apps/details?id=...
# 328  https://play.google.com/store/apps/details?id=...
# 402  https://play.google.com/store/apps/details?id=...
# 175  https://play.google.com/store/apps/details?id=...
# 150  https://play.google.com/store/apps/details?id=...
# 111  https://play.google.com/store/apps/details?id=...
# 78   https://play.google.com/store/apps/details?id=...
# 199  https://play.google.com/store/apps/details?id=...
# 177  https://play.google.com/store/apps/details?id=...
# 201  https://play.google.com/store/apps/details?id=...
# 200  https://play.google.com/store/apps/details?id=...
# 203  https://play.google.com/store/apps/details?id=...
# 386  https://play.google.com/store/apps/details?id=...
# 393  https://play.google.com/store/apps/details?id=...
# 127  https://play.google.com/store/apps/details?id=...
# 133  https://play.google.com/store/apps/details?id=...
# 134  https://play.google.com/store/apps/details?id=...
#
#      Total Download Revenue ($)
# 50                   69900000.0
# 2                     9900000.0
# 0                     6990000.0
# 305                   4990000.0
# 53                    4990000.0
# 67                    4990000.0
# 26                    4990000.0
# 5                     4990000.0
# 253                   4990000.0
# 234                   3990000.0
# 375                   2995000.0
# 351                   2990000.0
# 103                   2990000.0
# 403                   2990000.0
# 307                   2495000.0
# 350                   2495000.0
# 327                   2495000.0
# 303                   2495000.0
# 411                   2495000.0
# 79                    2495000.0
# 39                    2495000.0
# 29                    2495000.0
# 233                   1995000.0
# 231                   1990000.0
# 326                   1990000.0
# 299                   1599000.0
# 283                   1599000.0
# 293                   1495000.0
# 356                   1495000.0
# 101                   1495000.0
# 75                    1495000.0
# 252                   1490000.0
# 151                   1245000.0
# 264                    995000.0
# 155                    799000.0
# 328                    699000.0
# 402                    499000.0
# 175                    499000.0
# 150                    499000.0
# 111                    499000.0
# 78                     499000.0
# 199                    399000.0
# 177                    399000.0
# 201                    199500.0
# 200                    199000.0
# 203                    149500.0
# 386                    124500.0
# 393                    124500.0
# 127                     49900.0
# 133                     17495.0
# 134                      9950.0

# %%
#showing the data with a scatter plot

arcade = top_games.loc[top_games["Game Category"]=="GAME_ARCADE"]
sports = top_games.loc[top_games["Game Category"]=="GAME_SPORTS"]
racing = top_games.loc[top_games["Game Category"]=="GAME_RACING"]
music = top_games.loc[top_games["Game Category"]=="GAME_MUSIC"]
educational = top_games.loc[top_games["Game Category"]== "GAME_EDUCATIONAL"]
board = top_games.loc[top_games["Game Category"]=="GAME_BOARD"]
casino = top_games.loc[top_games["Game Category"]=="GAME_CASINO"]
action = top_games.loc[top_games["Game Category"]=="GAME_ACTION"]
trivia = top_games.loc[top_games["Game Category"]=="GAME_TRIVIA"]
simulation = top_games.loc[top_games["Game Category"]=="GAME_SIMULATION"]
adventure = top_games.loc[top_games["Game Category"]=="GAME_ADVENTURE"]
puzzle = top_games.loc[top_games["Game Category"]=="GAME_PUZZLE"]
card = top_games.loc[top_games["Game Category"]=="GAME_CARD"]
casual = top_games.loc[top_games["Game Category"]=="GAME_CASUAL"]
strategy = top_games.loc[top_games["Game Category"]=="GAME_STRATEGY"]                       
roleplay = top_games.loc[top_games["Game Category"]=="GAME_ROLE_PLAYING"]
word = top_games.loc[top_games["Game Category"]=="GAME_WORD"]

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Number of Installs"], arcade["Total Download Revenue ($)"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Number of Installs"], sports["Total Download Revenue ($)"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Number of Installs"], racing["Total Download Revenue ($)"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Number of Installs"], music["Total Download Revenue ($)"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Number of Installs"], educational["Total Download Revenue ($)"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Number of Installs"], board["Total Download Revenue ($)"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Number of Installs"], casino["Total Download Revenue ($)"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Number of Installs"], action["Total Download Revenue ($)"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Number of Installs"], trivia["Total Download Revenue ($)"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Number of Installs"], simulation["Total Download Revenue ($)"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Number of Installs"], adventure["Total Download Revenue ($)"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Number of Installs"], puzzle["Total Download Revenue ($)"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Number of Installs"], card["Total Download Revenue ($)"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Number of Installs"], casual["Total Download Revenue ($)"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Number of Installs"], strategy["Total Download Revenue ($)"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Number of Installs"], roleplay["Total Download Revenue ($)"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Number of Installs"], word["Total Download Revenue ($)"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Number of Installs")
plt.ylabel("Total Download Revenue ($10 Millions)")
plt.title("Top Paid Games")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Number of Installs"], arcade["Price"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Number of Installs"], sports["Price"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Number of Installs"], racing["Price"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Number of Installs"], music["Price"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Number of Installs"], educational["Price"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Number of Installs"], board["Price"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Number of Installs"], casino["Price"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Number of Installs"], action["Price"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Number of Installs"], trivia["Price"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Number of Installs"], simulation["Price"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Number of Installs"], adventure["Price"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Number of Installs"], puzzle["Price"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Number of Installs"], card["Price"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Number of Installs"], casual["Price"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Number of Installs"], strategy["Price"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Number of Installs"], roleplay["Price"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Number of Installs"], word["Price"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Number of Installs")
plt.ylabel("Price")
plt.title("Downloads Vs. Price")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Price"], arcade["Total Download Revenue ($)"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Price"], sports["Total Download Revenue ($)"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Price"], racing["Total Download Revenue ($)"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Price"], music["Total Download Revenue ($)"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Price"], educational["Total Download Revenue ($)"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Price"], board["Total Download Revenue ($)"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Price"], casino["Total Download Revenue ($)"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Price"], action["Total Download Revenue ($)"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Price"], trivia["Total Download Revenue ($)"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Price"], simulation["Total Download Revenue ($)"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Price"], adventure["Total Download Revenue ($)"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Price"], puzzle["Total Download Revenue ($)"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Price"], card["Total Download Revenue ($)"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Price"], casual["Total Download Revenue ($)"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Price"], strategy["Total Download Revenue ($)"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Price"], roleplay["Total Download Revenue ($)"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Price"], word["Total Download Revenue ($)"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Price")
plt.ylabel("Total Download Revenue ($10 Millions)")
plt.title("Price to Revenue")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Game Score"], arcade["Total Download Revenue ($)"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Game Score"], sports["Total Download Revenue ($)"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Game Score"], racing["Total Download Revenue ($)"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Game Score"], music["Total Download Revenue ($)"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Game Score"], educational["Total Download Revenue ($)"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Game Score"], board["Total Download Revenue ($)"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Game Score"], casino["Total Download Revenue ($)"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Game Score"], action["Total Download Revenue ($)"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Game Score"], trivia["Total Download Revenue ($)"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Game Score"], simulation["Total Download Revenue ($)"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Game Score"], adventure["Total Download Revenue ($)"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Game Score"], puzzle["Total Download Revenue ($)"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Game Score"], card["Total Download Revenue ($)"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Game Score"], casual["Total Download Revenue ($)"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Game Score"], strategy["Total Download Revenue ($)"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Game Score"], roleplay["Total Download Revenue ($)"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Game Score"], word["Total Download Revenue ($)"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Game Score")
plt.ylabel("Total Download Revenue ($10 Millions)")
plt.title("Game Score Vs Revenue")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Game Score"], arcade["Number of Reviews"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Game Score"], sports["Number of Reviews"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Game Score"], racing["Number of Reviews"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Game Score"], music["Number of Reviews"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Game Score"], educational["Number of Reviews"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Game Score"], board["Number of Reviews"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Game Score"], casino["Number of Reviews"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Game Score"], action["Number of Reviews"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Game Score"], trivia["Number of Reviews"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Game Score"], simulation["Number of Reviews"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Game Score"], adventure["Number of Reviews"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Game Score"], puzzle["Number of Reviews"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Game Score"], card["Number of Reviews"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Game Score"], casual["Number of Reviews"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Game Score"], strategy["Number of Reviews"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Game Score"], roleplay["Number of Reviews"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Game Score"], word["Number of Reviews"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Game Score")
plt.ylabel("Number of Reviews")
plt.title("Game Score Vs Reviews")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
##Scatter plots based on 'Games_df'###

#showing the data with a scatter plot

arcade = games_df.loc[games_df["Game Category"]=="GAME_ARCADE"]
sports = games_df.loc[games_df["Game Category"]=="GAME_SPORTS"]
racing = games_df.loc[games_df["Game Category"]=="GAME_RACING"]
music = games_df.loc[games_df["Game Category"]=="GAME_MUSIC"]
educational = games_df.loc[games_df["Game Category"]== "GAME_EDUCATIONAL"]
board = games_df.loc[games_df["Game Category"]=="GAME_BOARD"]
casino = games_df.loc[games_df["Game Category"]=="GAME_CASINO"]
action = games_df.loc[games_df["Game Category"]=="GAME_ACTION"]
trivia = games_df.loc[games_df["Game Category"]=="GAME_TRIVIA"]
simulation = games_df.loc[games_df["Game Category"]=="GAME_SIMULATION"]
adventure = games_df.loc[games_df["Game Category"]=="GAME_ADVENTURE"]
puzzle = games_df.loc[games_df["Game Category"]=="GAME_PUZZLE"]
card = games_df.loc[games_df["Game Category"]=="GAME_CARD"]
casual = games_df.loc[games_df["Game Category"]=="GAME_CASUAL"]
strategy = games_df.loc[games_df["Game Category"]=="GAME_STRATEGY"]                       
roleplay = games_df.loc[games_df["Game Category"]=="GAME_ROLE_PLAYING"]
word = games_df.loc[games_df["Game Category"]=="GAME_WORD"]

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Number of Installs"], arcade["Total Download Revenue ($)"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Number of Installs"], sports["Total Download Revenue ($)"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Number of Installs"], racing["Total Download Revenue ($)"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Number of Installs"], music["Total Download Revenue ($)"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Number of Installs"], educational["Total Download Revenue ($)"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Number of Installs"], board["Total Download Revenue ($)"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Number of Installs"], casino["Total Download Revenue ($)"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Number of Installs"], action["Total Download Revenue ($)"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Number of Installs"], trivia["Total Download Revenue ($)"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Number of Installs"], simulation["Total Download Revenue ($)"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Number of Installs"], adventure["Total Download Revenue ($)"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Number of Installs"], puzzle["Total Download Revenue ($)"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Number of Installs"], card["Total Download Revenue ($)"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Number of Installs"], casual["Total Download Revenue ($)"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Number of Installs"], strategy["Total Download Revenue ($)"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Number of Installs"], roleplay["Total Download Revenue ($)"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Number of Installs"], word["Total Download Revenue ($)"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Number of Installs")
plt.ylabel("Total Download Revenue ($10 Millions)")
plt.title("All Games")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Number of Installs"], arcade["Price"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Number of Installs"], sports["Price"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Number of Installs"], racing["Price"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Number of Installs"], music["Price"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Number of Installs"], educational["Price"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Number of Installs"], board["Price"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Number of Installs"], casino["Price"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Number of Installs"], action["Price"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Number of Installs"], trivia["Price"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Number of Installs"], simulation["Price"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Number of Installs"], adventure["Price"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Number of Installs"], puzzle["Price"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Number of Installs"], card["Price"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Number of Installs"], casual["Price"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Number of Installs"], strategy["Price"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Number of Installs"], roleplay["Price"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Number of Installs"], word["Price"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Number of Installs")
plt.ylabel("Price")
plt.title("Downloads Vs. Price (All Games)")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Price"], arcade["Total Download Revenue ($)"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Price"], sports["Total Download Revenue ($)"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Price"], racing["Total Download Revenue ($)"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Price"], music["Total Download Revenue ($)"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Price"], educational["Total Download Revenue ($)"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Price"], board["Total Download Revenue ($)"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Price"], casino["Total Download Revenue ($)"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Price"], action["Total Download Revenue ($)"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Price"], trivia["Total Download Revenue ($)"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Price"], simulation["Total Download Revenue ($)"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Price"], adventure["Total Download Revenue ($)"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Price"], puzzle["Total Download Revenue ($)"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Price"], card["Total Download Revenue ($)"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Price"], casual["Total Download Revenue ($)"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Price"], strategy["Total Download Revenue ($)"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Price"], roleplay["Total Download Revenue ($)"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Price"], word["Total Download Revenue ($)"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Price")
plt.ylabel("Total Download Revenue ($10 Millions)")
plt.title("Price to Revenue (All Games)")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Game Score"], arcade["Total Download Revenue ($)"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Game Score"], sports["Total Download Revenue ($)"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Game Score"], racing["Total Download Revenue ($)"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Game Score"], music["Total Download Revenue ($)"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Game Score"], educational["Total Download Revenue ($)"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Game Score"], board["Total Download Revenue ($)"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Game Score"], casino["Total Download Revenue ($)"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Game Score"], action["Total Download Revenue ($)"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Game Score"], trivia["Total Download Revenue ($)"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Game Score"], simulation["Total Download Revenue ($)"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Game Score"], adventure["Total Download Revenue ($)"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Game Score"], puzzle["Total Download Revenue ($)"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Game Score"], card["Total Download Revenue ($)"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Game Score"], casual["Total Download Revenue ($)"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Game Score"], strategy["Total Download Revenue ($)"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Game Score"], roleplay["Total Download Revenue ($)"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Game Score"], word["Total Download Revenue ($)"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Game Score")
plt.ylabel("Total Download Revenue ($10 Millions)")
plt.title("Game Score Vs Revenue (All Games)")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))
plt.show()
plt.savefig("GameScoreVsRevenue.png")

# %%
#building scatter plots for each category
arcade_p = plt.scatter(arcade["Game Score"], arcade["Number of Reviews"], marker="o"
                       , label="Arcade Games", color="red", alpha=0.75)
sports_p = plt.scatter(sports["Game Score"], sports["Number of Reviews"], marker="o",
                        label="Sports Games", color="blue", alpha=0.75)
racing_p = plt.scatter(racing["Game Score"], racing["Number of Reviews"], marker="o",
                        label="Racing Games", color="yellow", alpha=0.75)
music_p = plt.scatter(music["Game Score"], music["Number of Reviews"], marker="o",
                        label="Music Games", color="green", alpha=0.75)
educational_p = plt.scatter(educational["Game Score"], educational["Number of Reviews"],
                            marker="o",label="Educational Games", color="darkgreen", alpha=0.75)
board_p = plt.scatter(board["Game Score"], board["Number of Reviews"], marker="o",
                       label="Board Games", color="lightblue", alpha=0.75)
casino_p = plt.scatter(casino["Game Score"], casino["Number of Reviews"], marker="o",
                       label="Casino Games", color="pink", alpha=0.75)
action_p = plt.scatter(action["Game Score"], action["Number of Reviews"], marker="o",
                       label="Action Games", color="hotpink", alpha=0.75)
trivia_p = plt.scatter(trivia["Game Score"], trivia["Number of Reviews"], marker="o",
                       label="Trivia Games", color="grey", alpha=0.75)
simulation_p = plt.scatter(simulation["Game Score"], simulation["Number of Reviews"], marker="o",
                       label="Simulation Games", color="black", alpha=0.75)
adventure_p = plt.scatter(adventure["Game Score"], adventure["Number of Reviews"], marker="o",
                       label="Adenture Games", color="purple", alpha=0.75)
puzzle_p = plt.scatter(puzzle["Game Score"], puzzle["Number of Reviews"], marker="o",
                        label="Puzzle Games", color="white", edgecolor="black",alpha=0.75)
card_p = plt.scatter(card["Game Score"], card["Number of Reviews"], marker="o",
                       label="Card Games", color="orange", alpha=0.75)
casual_p = plt.scatter(casual["Game Score"], casual["Number of Reviews"], marker="o",
                       label="Casual Games", color="blue",edgecolor="red", alpha=0.75)
strategy_p = plt.scatter(strategy["Game Score"], strategy["Number of Reviews"], marker="o",
                       label="Strategic Games", color="green", edgecolor="lightblue", alpha=0.75)
roleplay_p = plt.scatter(roleplay["Game Score"], roleplay["Number of Reviews"], marker="o",
                       label="Roleplay Games", color="yellow", edgecolor="purple", alpha=0.75)
word_p = plt.scatter(word["Game Score"], word["Number of Reviews"], marker="o",
                       label="Word Games", color="skyblue", alpha=0.75)

#labeling the graph
plt.xlabel("Game Score")
plt.ylabel("Number of Reviews")
plt.title("Game Score Vs Reviews (All Games)")
#plt.legend((arcade_p,sports_p,racing_p,music_p,educational_p,board_p,casino_p,action_p,trivia_p,simulation_p,
           #adventure_p,puzzle_p,card_p,casual_p,strategy_p,roleplay_p,word_p),
           #("Arcade","Sports","Racing","Music","Education","Board","Casino","Action","Trivia","Simulation",
           #"Adventure","Puzzle","Card","Casual","Strategic","Roleplay","Word"))
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# %%
##########################

# %%
######Line Charts########
games_df.head(70)
# Out:
#                                           Game Title   Game Category  \
# 0                      Grand Theft Auto: San Andreas     GAME_ACTION
# 1                            Five Nights at Freddy's     GAME_ACTION
# 2                                      Hitman Sniper     GAME_ACTION
# 3                        Five Nights at Freddy's: SL     GAME_ACTION
# 4                          Assassin's Creed Identity     GAME_ACTION
# 5                               Grand Theft Auto III     GAME_ACTION
# 6                     Call of Duty:Black Ops Zombies     GAME_ACTION
# 7                          Five Nights at Freddy's 4     GAME_ACTION
# 8                                     Space Marshals     GAME_ACTION
# 9             truTV Impractical Jokers Wheel of Doom     GAME_ACTION
# 10                                        Real Steel     GAME_ACTION
# 11                                          Downwell     GAME_ACTION
# 12                            Teen Titans GO Figure!     GAME_ACTION
# 13                         Five Nights at Freddy's 3     GAME_ACTION
# 14                              Bloons Supermonkey 2     GAME_ACTION
# 15                               GTA: Chinatown Wars     GAME_ACTION
# 16  Shadow of Death: Stickman Fighting - Dark Knight     GAME_ACTION
# 17                        Bully: Anniversary Edition     GAME_ACTION
# 18                                 Zombieville USA 2     GAME_ACTION
# 19                        LEGO ® Marvel Super Heroes     GAME_ACTION
# 20                        PPSSPP Gold - PSP emulator     GAME_ACTION
# 21                                          BACKFIRE     GAME_ACTION
# 22                            LEGO® Star Wars™:  TCS     GAME_ACTION
# 23                               Battle of Vicksburg     GAME_ACTION
# 24                        Oddworld: Stranger's Wrath     GAME_ACTION
# 25                                   Alien: Blackout  GAME_ADVENTURE
# 26                                         Terraria.  GAME_ADVENTURE
# 27                         Bendy and the Ink Machine  GAME_ADVENTURE
# 28                              THE GALAXY: SURVIVOR  GAME_ADVENTURE
# 29                      Don't Starve: Pocket Edition  GAME_ADVENTURE
# ..                                               ...             ...
# 40                                  Bury me, my Love  GAME_ADVENTURE
# 41                                 Rusty Lake: Roots  GAME_ADVENTURE
# 42                                    Thickety Creek  GAME_ADVENTURE
# 43                         7Days - Decide your story  GAME_ADVENTURE
# 44                           Draw a Stickman: EPIC 2  GAME_ADVENTURE
# 45                         GTA: Liberty City Stories  GAME_ADVENTURE
# 46                                   Survivalcraft 2  GAME_ADVENTURE
# 47                      FINAL FANTASY IX for Android  GAME_ADVENTURE
# 48                               Rusty Lake Paradise  GAME_ADVENTURE
# 49                                           CHUCHEL  GAME_ADVENTURE
# 50                                         Minecraft     GAME_ARCADE
# 51                                     Geometry Dash     GAME_ARCADE
# 52                                      Ding Dong XL     GAME_ARCADE
# 53                       Grand Theft Auto: Vice City     GAME_ARCADE
# 54                                 ePSXe for Android     GAME_ARCADE
# 55                               Fruit Ninja Classic     GAME_ARCADE
# 56                         My OldBoy! - GBC Emulator     GAME_ARCADE
# 57                                       Pocket God™     GAME_ARCADE
# 58                                  Max Payne Mobile     GAME_ARCADE
# 59                                       Vector Full     GAME_ARCADE
# 60                    SuperRetro16 ( SNES Emulator )     GAME_ARCADE
# 61                                     Peace, Death!     GAME_ARCADE
# 62                      Retro NES Pro - NES Emulator     GAME_ARCADE
# 63                      Retro N64 Pro - N64 Emulator     GAME_ARCADE
# 64                                       Ms. PAC-MAN     GAME_ARCADE
# 65                                      METAL SLUG 3     GAME_ARCADE
# 66                               The Impossible Game     GAME_ARCADE
# 67                                           Worms 3     GAME_ARCADE
# 68                   PAC-MAN Championship Edition DX     GAME_ARCADE
# 69                                            Fowlst     GAME_ARCADE
#
#     Game Score  Number of Reviews  Price  Number of Installs  \
# 0          4.3             387549   6.99             1000000
# 1          4.6             103812   2.99             1000000
# 2          4.6             591529   0.99            10000000
# 3          4.5              17345   2.99              100000
# 4          3.8              49980   1.99              500000
# 5          4.0              96654   4.99             1000000
# 6          4.2              13999   6.99              100000
# 7          4.6              21568   2.99              100000
# 8          4.8               7894   0.99               50000
# 9          4.3                161   2.99                5000
# 10         4.1              26187   0.99              500000
# 11         4.7               4559   2.99              100000
# 12         4.5               4561   3.99               50000
# 13         4.7              28213   2.99              100000
# 14         4.6              15580   0.99              500000
# 15         4.3              25395   4.99              100000
# 16         4.6              58893   0.99             1000000
# 17         4.5              13466   6.99              100000
# 18         4.6               1393   0.99               50000
# 19         4.1              16454   4.99              100000
# 20         4.3              11149   4.99              100000
# 21         4.9                 23   2.99                 100
# 22         3.7              16798   6.99              100000
# 23         4.1                466   0.99                5000
# 24         4.5              28587   2.99              100000
# 25         4.0                372   4.99                5000
# 26         4.3             231311   4.99             1000000
# 27         4.2               1069   6.99               10000
# 28         4.3               3260   1.49               10000
# 29         4.4              22296   4.99              500000
# ..         ...                ...    ...                 ...
# 40         4.4                752   2.99               10000
# 41         4.9               8172   2.99              100000
# 42         4.5                 73   2.99                1000
# 43         4.8               1051   2.99               10000
# 44         4.4               5445   1.99              100000
# 45         4.4              10203   6.99               50000
# 46         4.5               5423   3.99              100000
# 47         4.4               7405  20.99              100000
# 48         4.8               4106   2.99               50000
# 49         4.3                594   4.99               10000
# 50         4.5            2594843   6.99            10000000
# 51         4.8             651321   1.99             1000000
# 52         4.8                144   0.99                5000
# 53         4.3             132070   4.99             1000000
# 54         4.5              35051   3.75              500000
# 55         4.3              85893   0.99             1000000
# 56         4.6               5104   3.99              100000
# 57         3.7              30427   0.99              500000
# 58         4.2              31033   2.99              100000
# 59         4.2              35915   0.99              500000
# 60         4.3              38553   3.99             1000000
# 61         4.7               5556   0.99              100000
# 62         4.7                191   2.99                1000
# 63         4.5                167   2.99                1000
# 64         4.3               5519   3.99              100000
# 65         3.7              14165   2.99              100000
# 66         4.1              19824   0.99              500000
# 67         4.2              67900   4.99             1000000
# 68         4.5               1887   1.99               10000
# 69         4.8                142   0.99                5000
#
#                                           Developer  \
# 0                                    Rockstar Games
# 1                                     Scott Cawthon
# 2                                   SQUARE ENIX Ltd
# 3                                     Scott Cawthon
# 4                             Ubisoft Entertainment
# 5                                    Rockstar Games
# 6                       Activision Publishing, Inc.
# 7                                     Scott Cawthon
# 8                                         Pixelbite
# 9                                      truTVnetwork
# 10  Reliance Big Entertainment (UK) Private Limited
# 11                                  DevolverDigital
# 12                                  Cartoon Network
# 13                                    Scott Cawthon
# 14                                       ninja kiwi
# 15                                   Rockstar Games
# 16                               Zonmob Game Studio
# 17                                   Rockstar Games
# 18                                      Mika Mobile
# 19           Warner Bros. International Enterprises
# 20                                   Henrik Rydgård
# 21                                        GRYN SQYD
# 22           Warner Bros. International Enterprises
# 23                                 Thorium Game Lab
# 24                         Oddworld Inhabitants Inc
# 25                                           D3 Go!
# 26                                    505 Games Srl
# 27                                Joey Drew Studios
# 28                                  Invictus Studio
# 29                          Klei Entertainment Inc.
# ..                                              ...
# 40                                         Playdius
# 41                                       Rusty Lake
# 42                            Fire Maple Games, LLC
# 43                             Buff Studio Co.,Ltd.
# 44                                         Hitcents
# 45                                   Rockstar Games
# 46                                Candy Rufus Games
# 47                             SQUARE ENIX Co.,Ltd.
# 48                                       Rusty Lake
# 49                                   Amanita Design
# 50                                           Mojang
# 51                                     RobTop Games
# 52                             Nickervision Studios
# 53                                   Rockstar Games
# 54                              epsxe software s.l.
# 55                                Halfbrick Studios
# 56                                    Fast Emulator
# 57                               Bolt Creative, Inc
# 58                                   Rockstar Games
# 59                                            NEKKI
# 60                                Neutron Emulation
# 61                                        AZAMATIKA
# 62                             Retro Game Emulators
# 63                             Retro Game Emulators
# 64          BANDAI NAMCO Entertainment America Inc.
# 65                                  SNK CORPORATION
# 66                                        FlukeDude
# 67                          Team 17 Digital Limited
# 68          BANDAI NAMCO Entertainment America Inc.
# 69                                   Thomas K Young
#
#                                        Play Store URL  \
# 0   https://play.google.com/store/apps/details?id=...
# 1   https://play.google.com/store/apps/details?id=...
# 2   https://play.google.com/store/apps/details?id=...
# 3   https://play.google.com/store/apps/details?id=...
# 4   https://play.google.com/store/apps/details?id=...
# 5   https://play.google.com/store/apps/details?id=...
# 6   https://play.google.com/store/apps/details?id=...
# 7   https://play.google.com/store/apps/details?id=...
# 8   https://play.google.com/store/apps/details?id=...
# 9   https://play.google.com/store/apps/details?id=...
# 10  https://play.google.com/store/apps/details?id=...
# 11  https://play.google.com/store/apps/details?id=...
# 12  https://play.google.com/store/apps/details?id=...
# 13  https://play.google.com/store/apps/details?id=...
# 14  https://play.google.com/store/apps/details?id=...
# 15  https://play.google.com/store/apps/details?id=...
# 16  https://play.google.com/store/apps/details?id=...
# 17  https://play.google.com/store/apps/details?id=...
# 18  https://play.google.com/store/apps/details?id=...
# 19  https://play.google.com/store/apps/details?id=...
# 20  https://play.google.com/store/apps/details?id=...
# 21  https://play.google.com/store/apps/details?id=...
# 22  https://play.google.com/store/apps/details?id=...
# 23  https://play.google.com/store/apps/details?id=...
# 24  https://play.google.com/store/apps/details?id=...
# 25  https://play.google.com/store/apps/details?id=...
# 26  https://play.google.com/store/apps/details?id=...
# 27  https://play.google.com/store/apps/details?id=...
# 28  https://play.google.com/store/apps/details?id=...
# 29  https://play.google.com/store/apps/details?id=...
# ..                                                ...
# 40  https://play.google.com/store/apps/details?id=...
# 41  https://play.google.com/store/apps/details?id=...
# 42  https://play.google.com/store/apps/details?id=...
# 43  https://play.google.com/store/apps/details?id=...
# 44  https://play.google.com/store/apps/details?id=...
# 45  https://play.google.com/store/apps/details?id=...
# 46  https://play.google.com/store/apps/details?id=...
# 47  https://play.google.com/store/apps/details?id=...
# 48  https://play.google.com/store/apps/details?id=...
# 49  https://play.google.com/store/apps/details?id=...
# 50  https://play.google.com/store/apps/details?id=...
# 51  https://play.google.com/store/apps/details?id=...
# 52  https://play.google.com/store/apps/details?id=...
# 53  https://play.google.com/store/apps/details?id=...
# 54  https://play.google.com/store/apps/details?id=...
# 55  https://play.google.com/store/apps/details?id=...
# 56  https://play.google.com/store/apps/details?id=...
# 57  https://play.google.com/store/apps/details?id=...
# 58  https://play.google.com/store/apps/details?id=...
# 59  https://play.google.com/store/apps/details?id=...
# 60  https://play.google.com/store/apps/details?id=...
# 61  https://play.google.com/store/apps/details?id=...
# 62  https://play.google.com/store/apps/details?id=...
# 63  https://play.google.com/store/apps/details?id=...
# 64  https://play.google.com/store/apps/details?id=...
# 65  https://play.google.com/store/apps/details?id=...
# 66  https://play.google.com/store/apps/details?id=...
# 67  https://play.google.com/store/apps/details?id=...
# 68  https://play.google.com/store/apps/details?id=...
# 69  https://play.google.com/store/apps/details?id=...
#
#     Total Download Revenue ($)
# 0                    6990000.0
# 1                    2990000.0
# 2                    9900000.0
# 3                     299000.0
# 4                     995000.0
# 5                    4990000.0
# 6                     699000.0
# 7                     299000.0
# 8                      49500.0
# 9                      14950.0
# 10                    495000.0
# 11                    299000.0
# 12                    199500.0
# 13                    299000.0
# 14                    495000.0
# 15                    499000.0
# 16                    990000.0
# 17                    699000.0
# 18                     49500.0
# 19                    499000.0
# 20                    499000.0
# 21                       299.0
# 22                    699000.0
# 23                      4950.0
# 24                    299000.0
# 25                     24950.0
# 26                   4990000.0
# 27                     69900.0
# 28                     14900.0
# 29                   2495000.0
# ..                         ...
# 40                     29900.0
# 41                    299000.0
# 42                      2990.0
# 43                     29900.0
# 44                    199000.0
# 45                    349500.0
# 46                    399000.0
# 47                   2099000.0
# 48                    149500.0
# 49                     49900.0
# 50                  69900000.0
# 51                   1990000.0
# 52                      4950.0
# 53                   4990000.0
# 54                   1875000.0
# 55                    990000.0
# 56                    399000.0
# 57                    495000.0
# 58                    299000.0
# 59                    495000.0
# 60                   3990000.0
# 61                     99000.0
# 62                      2990.0
# 63                      2990.0
# 64                    399000.0
# 65                    299000.0
# 66                    495000.0
# 67                   4990000.0
# 68                     19900.0
# 69                      4950.0
#
# [70 rows x 9 columns]

# %%
# Line graph 'Game Score' Vs 'Revenue'. 
####MESSY LOOKING####
#Below is with Minecraft
#games_df.plot(x='Game Score', y='Total Download Revenue ($)')
#Below is withOUT Minecraft
games_df.drop([50]).plot(x='Game Score', y='Total Download Revenue ($)')

# %%
# Line graph 'Price' Vs 'Revenue'
#Below is with Minecraft
#games_df.plot(x='Price', y='Total Download Revenue ($)')
#Below is withOUT Minecraft
games_df.drop([50]).plot(x='Price', y='Total Download Revenue ($)')

# %%
###Stacked chart

arcade = games_df.loc[games_df["Game Category"]=="GAME_ARCADE"]
sports = games_df.loc[games_df["Game Category"]=="GAME_SPORTS"]
racing = games_df.loc[games_df["Game Category"]=="GAME_RACING"]
music = games_df.loc[games_df["Game Category"]=="GAME_MUSIC"]
educational = games_df.loc[games_df["Game Category"]== "GAME_EDUCATIONAL"]
board = games_df.loc[games_df["Game Category"]=="GAME_BOARD"]
casino = games_df.loc[games_df["Game Category"]=="GAME_CASINO"]
action = games_df.loc[games_df["Game Category"]=="GAME_ACTION"]
trivia = games_df.loc[games_df["Game Category"]=="GAME_TRIVIA"]
simulation = games_df.loc[games_df["Game Category"]=="GAME_SIMULATION"]
adventure = games_df.loc[games_df["Game Category"]=="GAME_ADVENTURE"]
puzzle = games_df.loc[games_df["Game Category"]=="GAME_PUZZLE"]
card = games_df.loc[games_df["Game Category"]=="GAME_CARD"]
casual = games_df.loc[games_df["Game Category"]=="GAME_CASUAL"]
strategy = games_df.loc[games_df["Game Category"]=="GAME_STRATEGY"]                       
roleplay = games_df.loc[games_df["Game Category"]=="GAME_ROLE_PLAYING"]
word = games_df.loc[games_df["Game Category"]=="GAME_WORD"]




x = range(0, 1)
#x= games_df['Price']
y1 = arcade['Total Download Revenue ($)']
y2= sports['Total Download Revenue ($)']
y3 = racing['Total Download Revenue ($)']
plt.stackplot(x, y1, y2, y3)
#df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
#df.plot.area()
# Out:
# [<matplotlib.collections.PolyCollection at 0x11ca22c88>,
#  <matplotlib.collections.PolyCollection at 0x11ca226a0>,
#  <matplotlib.collections.PolyCollection at 0x11c008128>]
